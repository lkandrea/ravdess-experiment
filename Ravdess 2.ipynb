# %% [markdown]
# # Prepare Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display as idisplay
import os
import sys
import errno
import random
import shutil
import fnmatch
import tensorflow as tf

from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input, Softmax
from keras_preprocessing.image import ImageDataGenerator
from keras.engine.saving import model_from_json
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils.vis_utils import plot_model

from sklearn.metrics import classification_report, confusion_matrix

from google.colab import files
from google.colab import drive

from pathlib import Path

# %%
drive.mount('/content/gdrive', force_remount=True)
iemocap = "gdrive/My Drive/Public/IEMOCAP_full_release"
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # GPU Utilization

# %%
print("GPU Name: ", tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# GPU Name:  /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# # Transform Function
# 1. Get every audio by filename
# 2. Take the label from txt file
# 3. Convert Audio into Image
# 4. Iterate for 5 sessions

# %%
def getLabel(path, name):
  label_file = open(path, 'r')
  label_lines = label_file.readlines()

  line = [line for line in label_lines if name in line]
  line = line[0].replace(";", ":")
  label = line.split(":")[1]

  return label

def checkAndCreateDirectory(filename):
  if not os.path.exists(os.path.dirname(filename)):
    try:
        os.makedirs(os.path.dirname(filename))
    except OSError as exc: # Guard against race condition
        print(exc.errno)
        if exc.errno != errno.EEXIST:
            raise

def saveImage(path_audio, path_output, audio_name, label):
  audio_name = path_audio + audio_name + '.wav'
  audio_file, sample_rate = librosa.load(audio_name)

  # Tweak: Sample Rate
  # S = librosa.feature.mfcc(y=audio_file, sr=sample_rate) # Default 22_500
  S = librosa.feature.mfcc(y=audio_file, sr=48000)

  # TODO: Parameter MFCC, number of coefficient, Normalization
  # asd
  
  # Get Duration
  duration = librosa.get_duration(y=audio_file, sr=sample_rate)
  print(duration)

  # Plot into image
  # librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
  # librosa.display.specshow(librosa.power_to_db(S))
  # librosa.display.specshow(S)
  
  # Save into file
  # filename = path_output + label + "/" + audio_name + '.png'
  # checkAndCreateDirectory(filename)

  # plt.gca().set_axis_off()
  # plt.savefig(filename, dpi=100, bbox_inches='tight',pad_inches=0)
  # plt.show()
  # plt.clf()
  # plt.close('all')

def readAudioList(path_label, path_audio, path_output, recording, audio_list):
  print("Progress.. Audio ")

  for audio_name in audio_list:
    print(audio_name[-4:], end=' ')
    recordings = [file.name for file in os.scandir(path_audio)]
    
    label_file = [file.name for file in os.scandir(path_label) if recording in file.name]
    label_file = [filename for filename in label_file if '.txt' in filename][0]
    label_title = getLabel(path_label + label_file, audio_name)

    saveImage(path_audio, path_output, audio_name, label_title)

def deleteExtensions(audio_name):
  return audio_name.replace(".wav", "")

def transformAllSessions():
  sessions = ["3"]

  for session in sessions:
    print("\nProgress.. Session " + session)

    path_output = '/content/test/Session' + session + '/categorical/'
    path_audio = iemocap + '/Session' + session + '/sentences/wav/'
    path_label = iemocap + '/Session' + session + '/dialog/EmoEvaluation/Categorical/'

    recordings = [file.name for file in os.scandir(path_audio)]
    recordings.sort()

    for recording in recordings:
      print("\n\nProgress.. Recording " + recording + "\n")

      path_audio = iemocap + '/Session' + session + '/sentences/wav/'
      path_audio = path_audio + recording + "/"

      audio_list = [file.name for file in os.scandir(path_audio) if ".pk" not in file.name]
      audio_list = list(map(deleteExtensions, audio_list))
      audio_list.sort()
      
      readAudioList(path_label, path_audio, path_output, recording, audio_list)

def downloadLocalData():
  # !zip -r /content/test.zip /content/test
  files.download("/content/test.zip")

def clearLocalFolder():
  # !ls test
  # !rm -rf test
  # !rm test.zip

# clearLocalFolder()
# transformAllSessions()
# downloadLocalData()

# %% [markdown]
# # Retrieve data
# Classification, 998 images of:
# - Neutral state
# - Happiness
# - Anger
# - Sadness

# %%
def clearData():
  # !rm -rf "mfcc/train"
  # !rm -rf "mfcc/test"
  # !rm -rf "spectogram/test"
  # !rm -rf "spectogram/test"
  # !rm -rf "/content/content"

def splitData(path_input, path_output, category, filenames):
  sourcePath = path_input + "/" + category
  splitPercentage = int((len(filenames)+1) * .80)
  
  trainPath = path_output + "/train/" + category
  trainData = filenames[:splitPercentage]

  for trainFile in trainData:
    checkAndCreateDirectory(trainPath + "/" + trainFile)
    shutil.copyfile(sourcePath + "/" + trainFile, trainPath + "/" + trainFile)

  testPath = path_output + "/test/" + category
  testData = filenames[splitPercentage:]
  checkAndCreateDirectory(testPath)

  for testFile in testData:
    checkAndCreateDirectory(testPath + "/" + testFile)
    shutil.copyfile(sourcePath + "/" + testFile, testPath + "/" + testFile)

def getRandomData(feature):
  dataset = iemocap + "/Images/"
  categories = ["Neutral state", "Happiness", "Anger", "Sadness"]

  for category in categories:
    path = dataset + feature + "/" + category
    filenames = random.sample(os.listdir(path), 998)
    splitData(dataset + feature, feature, category, filenames)

def exportDataset():
  # !zip -r mfcc/mfcc.zip mfcc
  shutil.copyfile("mfcc/mfcc.zip", iemocap + "/Images/export/mfcc.zip")

  # !zip -r spectogram/spectogram.zip spectogram
  shutil.copyfile("spectogram/spectogram.zip", iemocap + "/Images/export/spectogram.zip")

def importDataset():
  # shutil.copyfile(iemocap + "/Images/export/mfcc.zip", "mfcc.zip")
  # !unzip mfcc.zip

  shutil.copyfile(iemocap + "/Images/export/spectogram.zip", "spectogram.zip")
  # !unzip spectogram.zip

def importDurationed():
  shutil.copyfile(iemocap + "/Images/export/duration_second.zip", "duration_second.zip")
  # !unzip duration_second.zip

  categories = ["neu", "hap", "ang", "sad"]

  for category in categories:
    path = "/content/content/transformed_image/" + category
    filenames = random.sample(os.listdir(path), 156)
    splitData("/content/content/transformed_image", "mfcc", category, filenames)

# clearData()
# getRandomData("mfcc")
# getRandomData("spectogram")

# exportDataset()
# importDataset()
# importDurationed()

# %% [markdown]
# # Preprocess

# %%
def save_model(model, filename):
  checkAndCreateDirectory("model/test.txt")
  with open("model/" + filename + ".json", "w") as json_file:
    model_json = model.to_json()
    json_file.write(model_json)

def load_model(struct, weight):
  json_file = open("model/" + struct + ".json", "r")
  loaded_model_json = json_file.read()
  json_file.close()

  loaded_model = model_from_json(loaded_model_json)
  loaded_model.load_weights("model/" + weight + ".hdf5")
  loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  return loaded_model

def load_data_mfcc():
  data_generator = ImageDataGenerator(validation_split=0.25)
  train_data = data_generator.flow_from_directory(
      directory="mfcc/train/",
      class_mode="categorical",
      subset="training",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )

  validation_data = data_generator.flow_from_directory(
      directory="mfcc/train/",
      class_mode="categorical",
      subset="validation",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )

  return train_data, validation_data

# def load_data_spectogram():
#   data_generator = ImageDataGenerator(validation_split=0.3)
#   train_data = data_generator.flow_from_directory(
#       directory="spectogram/train/",
#       class_mode="categorical",
#       subset="training",
#       batch_size=1,
#       shuffle=True,
#       target_size=(256, 256)
#   )
    
#   x_train = []
#   y_train = []

#   for i in range(train_data.__len__()):
#     a, b = train_data.next()
#     x_train.append(a[0])
#     y_train.append(b[0])

#   x_train = np.array(x_train)
#   y_train = np.array(y_train)


#   validation_data = data_generator.flow_from_directory(
#       directory="spectogram/train/",
#       class_mode="categorical",
#       subset="validation",
#       batch_size=1,
#       shuffle=True,
#       target_size=(256, 256)
#   )

#   x_val = []
#   y_val = []

#   for i in range(validation_data.__len__()):
#     a, b = validation_data.next()
#     x_val.append(a[0])
#     y_val.append(b[0])

#   x_val = np.array(x_val)
#   y_val = np.array(y_val)

#   return x_train, y_train, x_val, y_val

train_data, validation_data = load_data_mfcc()
# spectogram_x_train, spectogram_y_train, spectogram_x_val, spectogram_y_val = load_data_spectogram()
# Out:
# Found 376 images belonging to 4 classes.
# Found 124 images belonging to 4 classes.

# %% [markdown]
# # Model

# %%
def plot_result(model, history):
  # list all data in history
  print(history.history.keys())

  # summarize history for accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

def build_convolution(model):
  model = Conv2D(32, kernel_size=3, strides=2)(model)
  model = Conv2D(64, kernel_size=3, strides=2)(model)

  return model

def build_model():

  mfcc_input = Input(shape=(256, 256, 3))
  mfcc_model = build_convolution(mfcc_input)

  # spectogram_input = Input(shape=(256, 256, 3))
  # spectogram_model = build_convolution(spectogram_input)

  # result_model = Sequential()
  # eff = tf.keras.applications.EfficientNetB3(
  #     weights=None,
  #     input_shape=(256,256,3)
  # )
  
  # result_model.add(eff)
  # result_model.add(Flatten())
  # result_model.add(Dense(4, activation='softmax'))

  # result_model = Concatenate()([mfcc_model])
  result_model = Flatten()(mfcc_model)

  result_model = Dense(128)(result_model)
  result_model = Dense(64)(result_model)
  result_model = Dense(32)(result_model)

  result_model = Dense(4, activation='softmax')(result_model)
  result_model = Model(inputs=[mfcc_input], outputs=[result_model])

  result_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  save_model(result_model, "struct_model")
  result_model.summary()
  plot_model(result_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

  return result_model

def get_model():
  if os.path.isfile("/content/model/struct_model.json"):
    lastCheckpoint = sorted(Path("/content/model").iterdir(), key=os.path.getmtime)[-1].stem
    print("Model is " + lastCheckpoint)

    model = load_model("struct_model", lastCheckpoint)
    return model
  else:
    print("Model is builded")
    return build_model()

def train_model():
  checkAndCreateDirectory("/content/model/test.txt")

  for iteration in range(1):
    basepath = '/content/model/weight_model_' + str(iteration)
    best_checkpoint = ModelCheckpoint(basepath +'_{epoch:02d}_{loss:.2f}_{accuracy:.2f}_{val_loss:.2f}_{val_accuracy:.2f}.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
    # callback_list = [best_checkpoint]

    model = get_model()
    history = model.fit_generator(
        generator=train_data,
        validation_data=validation_data,
        epochs=200,
        # callbacks=callback_list
    )

    plot_result(model, history)

  return model, history

# !rm -rf /content/model
model, history = train_model()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model is builded
# Model: "functional_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 127, 127, 32)      896
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 63, 63, 64)        18496
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 254016)            0
# _________________________________________________________________
# dense_181 (Dense)            (None, 128)               32514176
# _________________________________________________________________
# dense_182 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_183 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_184 (Dense)            (None, 4)                 132
# =================================================================
# Total params: 32,544,036
# Trainable params: 32,544,036
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 188/188 [==============================] - 3s 15ms/step - loss: 2202.3284 - accuracy: 0.3378 - val_loss: 220.5095 - val_accuracy: 0.4194
# Epoch 2/200
# 188/188 [==============================] - 3s 14ms/step - loss: 58.8981 - accuracy: 0.7899 - val_loss: 219.9566 - val_accuracy: 0.2823
# Epoch 3/200
# 188/188 [==============================] - 3s 15ms/step - loss: 8.6602 - accuracy: 0.9229 - val_loss: 191.7361 - val_accuracy: 0.3548
# Epoch 4/200
# 188/188 [==============================] - 3s 14ms/step - loss: 5.5528 - accuracy: 0.9707 - val_loss: 224.0110 - val_accuracy: 0.3871
# Epoch 5/200
# 188/188 [==============================] - 3s 14ms/step - loss: 4.0832 - accuracy: 0.9787 - val_loss: 215.7018 - val_accuracy: 0.3306
# Epoch 6/200
# 188/188 [==============================] - 3s 15ms/step - loss: 1.0781 - accuracy: 0.9814 - val_loss: 425.5517 - val_accuracy: 0.2823
# Epoch 7/200
# 188/188 [==============================] - 3s 15ms/step - loss: 36.1605 - accuracy: 0.9149 - val_loss: 534.7761 - val_accuracy: 0.2823
# Epoch 8/200
# 188/188 [==============================] - 3s 14ms/step - loss: 325.1451 - accuracy: 0.7048 - val_loss: 1657.4954 - val_accuracy: 0.2581
# Epoch 9/200
# 188/188 [==============================] - 3s 14ms/step - loss: 839.2737 - accuracy: 0.6888 - val_loss: 1404.8199 - val_accuracy: 0.3145
# Epoch 10/200
# 188/188 [==============================] - 3s 14ms/step - loss: 353.1483 - accuracy: 0.7979 - val_loss: 1081.1542 - val_accuracy: 0.3145
# Epoch 11/200
# 188/188 [==============================] - 3s 14ms/step - loss: 68.7947 - accuracy: 0.9495 - val_loss: 1242.9702 - val_accuracy: 0.3548
# Epoch 12/200
# 188/188 [==============================] - 3s 14ms/step - loss: 28.6104 - accuracy: 0.9628 - val_loss: 876.5662 - val_accuracy: 0.3306
# Epoch 13/200
# 188/188 [==============================] - 3s 14ms/step - loss: 19.1601 - accuracy: 0.9707 - val_loss: 1124.0551 - val_accuracy: 0.3226
# Epoch 14/200
# 188/188 [==============================] - 3s 15ms/step - loss: 14.0848 - accuracy: 0.9787 - val_loss: 1204.8082 - val_accuracy: 0.3710
# Epoch 15/200
# 188/188 [==============================] - 3s 14ms/step - loss: 24.8937 - accuracy: 0.9814 - val_loss: 1152.6565 - val_accuracy: 0.3306
# Epoch 16/200
# 188/188 [==============================] - 3s 14ms/step - loss: 7.9039 - accuracy: 0.9920 - val_loss: 1070.0461 - val_accuracy: 0.3387
# Epoch 17/200
# 188/188 [==============================] - 3s 14ms/step - loss: 10.9861 - accuracy: 0.9867 - val_loss: 1161.7511 - val_accuracy: 0.3790
# Epoch 18/200
# 188/188 [==============================] - 3s 14ms/step - loss: 8.9680 - accuracy: 0.9947 - val_loss: 1306.6992 - val_accuracy: 0.3629
# Epoch 19/200
# 188/188 [==============================] - 3s 14ms/step - loss: 2832.0615 - accuracy: 0.7766 - val_loss: 11275.9473 - val_accuracy: 0.3387
# Epoch 20/200
# 188/188 [==============================] - 3s 14ms/step - loss: 1411.5220 - accuracy: 0.8085 - val_loss: 5995.8525 - val_accuracy: 0.3629
# Epoch 21/200
# 188/188 [==============================] - 3s 15ms/step - loss: 217.8948 - accuracy: 0.9468 - val_loss: 5607.6733 - val_accuracy: 0.3387
# Epoch 22/200
# 188/188 [==============================] - 3s 14ms/step - loss: 159.8452 - accuracy: 0.9548 - val_loss: 6086.9702 - val_accuracy: 0.2823
# Epoch 23/200
# 188/188 [==============================] - 3s 15ms/step - loss: 57.2460 - accuracy: 0.9734 - val_loss: 5382.4033 - val_accuracy: 0.3387
# Epoch 24/200
# 188/188 [==============================] - 3s 15ms/step - loss: 9.6974 - accuracy: 0.9947 - val_loss: 5168.7812 - val_accuracy: 0.3468
# Epoch 25/200
# 188/188 [==============================] - 3s 14ms/step - loss: 11.2648 - accuracy: 0.9947 - val_loss: 4960.9980 - val_accuracy: 0.3629
# Epoch 26/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 27/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 28/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 29/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 30/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 31/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 32/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 33/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 34/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6021 - val_accuracy: 0.3629
# Epoch 35/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 36/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 37/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 38/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 39/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 40/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 41/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 42/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 43/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 44/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 45/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 46/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 47/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6021 - val_accuracy: 0.3629
# Epoch 48/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 49/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 50/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 51/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 52/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 53/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 54/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 55/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 56/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 57/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 58/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 59/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 60/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 61/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 62/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 63/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 64/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 65/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 66/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 67/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 68/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 69/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 70/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 71/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 72/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 73/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 74/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 75/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 76/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 77/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 78/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 79/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 80/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 81/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 82/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 83/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 84/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 85/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 86/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 87/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 88/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 89/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 90/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 91/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 92/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 93/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 94/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 95/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 96/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 97/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 98/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 99/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 100/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 101/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 102/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 103/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 104/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 105/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 106/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5991 - val_accuracy: 0.3629
# Epoch 107/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 108/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 109/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 110/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 111/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 112/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 113/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 114/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 115/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 116/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 117/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 118/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5991 - val_accuracy: 0.3629
# Epoch 119/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 120/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 121/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 122/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 123/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 124/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 125/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 126/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 127/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 128/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 129/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 130/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 131/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 132/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 133/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 134/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 135/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 136/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 137/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 138/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 139/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 140/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 141/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 142/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 143/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 144/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 145/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 146/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 147/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 148/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6021 - val_accuracy: 0.3629
# Epoch 149/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 150/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6021 - val_accuracy: 0.3629
# Epoch 151/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 152/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 153/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 154/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 155/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 156/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 157/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6021 - val_accuracy: 0.3629
# Epoch 158/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 159/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 160/200
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 161/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 162/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 163/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 164/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 165/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 166/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 167/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 168/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5991 - val_accuracy: 0.3629
# Epoch 169/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 170/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 171/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 172/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 173/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 174/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 175/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 176/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 177/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 178/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6021 - val_accuracy: 0.3629
# Epoch 179/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 180/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5991 - val_accuracy: 0.3629
# Epoch 181/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 182/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 183/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 184/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 185/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 186/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 187/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 188/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5991 - val_accuracy: 0.3629
# Epoch 189/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5991 - val_accuracy: 0.3629
# Epoch 190/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5996 - val_accuracy: 0.3629
# Epoch 191/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6011 - val_accuracy: 0.3629
# Epoch 192/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 193/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 194/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 195/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 196/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6001 - val_accuracy: 0.3629
# Epoch 197/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 198/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.5991 - val_accuracy: 0.3629
# Epoch 199/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# Epoch 200/200
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4961.6006 - val_accuracy: 0.3629
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Evaluation

# %%
test_generator = ImageDataGenerator()
test_data = test_generator.flow_from_directory(
    directory="mfcc/test/",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    target_size=(256, 256)
)

loss, accuracy = model.evaluate_generator(generator=test_data)
print(
    ""
    "Prediction Loss: %2d\n"
    "Prediction Accuracy: %2d%%"
    ""
    % (loss, accuracy * 100))
# Out:
# Found 124 images belonging to 4 classes.
# Prediction Loss: 9006
# Prediction Accuracy: 28%

# %% [markdown]
# # Analysis

# %%
target_names = ['Angry', 'Happy', 'Neutral', "Sad"]

Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_data.classes, y_pred))

print('\n\nClassification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 4  7 10 10]
#  [ 2  9  5 15]
#  [ 2 10  5 14]
#  [ 1  5  8 17]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#        Angry       0.44      0.13      0.20        31
#        Happy       0.29      0.29      0.29        31
#      Neutral       0.18      0.16      0.17        31
#          Sad       0.30      0.55      0.39        31
#
#     accuracy                           0.28       124
#    macro avg       0.30      0.28      0.26       124
# weighted avg       0.30      0.28      0.26       124
