# %% [markdown]
# # Prepare Data

# %%
import tensorflow as tf
import cv2

from numba import cuda 

from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input, Softmax, Conv1D, MaxPooling1D, Activation
from keras.engine.saving import model_from_json
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils.vis_utils import plot_model
from keras.layers.normalization import BatchNormalization
from keras_preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import MinMaxScaler

from skimage.restoration import denoise_wavelet

from pathlib import Path

from google.colab import files
from google.colab import drive

import os
import sys

import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

import librosa
import librosa.display

# %%
drive.mount('/content/gdrive', force_remount=True)
iemocap = "gdrive/My Drive/Public/IEMOCAP_full_release"

print("GPU Name: ", tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Mounted at /content/gdrive
# GPU Name:  /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# # Convert into CSV

# %%
sessions = ["Session1", "Session2", "Session3", "Session4", "Session5"]

def convertSession(session_name):
  session_file = iemocap + "/Duration/Processed/" + session_name + ".txt"
  tokenized_lines = []

  with open(session_file) as f:
    lines = f.readlines()
    tokenizedLines = [x.split() for x in lines]

  session_csv = iemocap + "/Duration/Processed/" + session_name + ".csv"
  with open(session_csv, "w") as csv:
    audio_name = ''

    for line in tokenizedLines:
      if line[0] == "Recording":
        audio_name = line[1]
      else:
        csv.write(audio_name + ";" + line[0] + ";" + line[1] + "\n")

def convertRawToCsv():
  for session in sessions:
    convertSession(session)

# convertRawToCsv()

# %% [markdown]
# # Convert into data frame

# %%
def getSessionData(session_name):
  df = pd.read_csv(iemocap + "/Duration/Processed/" + session_name + ".csv", delimiter=";", header=None)
  df.columns = ["Audio Name", "Part", "Duration"]
  print(session_name + " count: " + str(len(df.index)))

  return df

def getDataFrame():
  result = pd.DataFrame()

  for session in sessions:
    df = getSessionData(session)
    result = result.append(df, ignore_index=True)

  return result

result = getDataFrame()
result["Duration"] = result["Duration"].apply(np.floor).astype(int)
result
# Out:
# Session1 count: 1819
# Session2 count: 1811
# Session3 count: 2136
# Session4 count: 2103
# Session5 count: 2170
#               Audio Name  Part  Duration
# 0         Ses01F_impro01  F000         1
# 1         Ses01F_impro01  F001         1
# 2         Ses01F_impro01  F002         3
# 3         Ses01F_impro01  F003         1
# 4         Ses01F_impro01  F004         3
# ...                  ...   ...       ...
# 10034  Ses05M_script03_2  M041         8
# 10035  Ses05M_script03_2  M042         1
# 10036  Ses05M_script03_2  M043         2
# 10037  Ses05M_script03_2  M044         4
# 10038  Ses05M_script03_2  M045         6
#
# [10039 rows x 3 columns]

# %% [markdown]
# # Plot

# %%
plot = seaborn.countplot(x='Duration', data=result)
plot.figure.set_size_inches(13,13)

for p in plot.patches:
  height = p.get_height()
  plot.text(p.get_x() + p.get_width()/2., height + 10, '{:1.0f}'.format(height), ha="center")

# %%
print("Original data: " + str(result.count()))

count_data = result.value_counts(subset=['Duration'], sort=False).values
count_normalize = result.value_counts(subset=['Duration'], sort=False, normalize=True).values
duration = sorted(result.Duration.unique())

count_df = pd.DataFrame({"Duration": duration, "Count": count_data, "Percentage": count_normalize})
count_df.Percentage = (count_df.Percentage * 100).round(3)
# Out:
# Original data: Audio Name     10039
# Part           10039
# Duration       10039
# Evaluation1        0
# Evaluation2        0
# Evaluation3        0
# Evaluation4        0
# Evaluation5        0
# Evaluation6        0
# Emotion        10039
# dtype: int64
#     Duration  Count  Percentage
# 0          0     50       0.498
# 1          1   1650      16.436
# 2          2   2341      23.319
# 3          3   1717      17.103
# 4          4   1148      11.435
# 5          5    828       8.248
# 6          6    682       6.794
# 7          7    449       4.473
# 8          8    322       3.207
# 9          9    249       2.480
# 10        10    175       1.743
# 11        11    116       1.155
# 12        12    101       1.006
# 13        13     52       0.518
# 14        14     51       0.508
# 15        15     38       0.379
# 16        16     21       0.209
# 17        17     12       0.120
# 18        18     11       0.110
# 19        19      5       0.050
# 20        20      4       0.040
# 21        21      2       0.020
# 22        22      2       0.020
# 23        23      4       0.040
# 24        24      2       0.020
# 25        25      1       0.010
# 26        26      2       0.020
# 27        29      2       0.020
# 28        31      1       0.010
# 29        34      1       0.010

# %% [markdown]
# # Labeling

# %%
def resetEvaluation():
  result["Emotion"] = None

def goLabeling():
  for session in sessions:
    emotion_path = iemocap + "/" + session + "/dialog/EmoEvaluation/"

    recordings = [file.name for file in os.scandir(emotion_path) if ".txt" in file.name]
    recordings.sort()
    
    for recording in recordings:
      with open(emotion_path + recording) as f:
        lines = f.readlines()
        tokenizedLines = [x.split() for x in lines if "Ses0" in x]

        for part in tokenizedLines:
          line_name = part[3]
          line_label = part[4]
          line_queries = line_name.split("_")
          
          line_part = line_queries[-1]
          line_queries.remove(line_part)

          line_name = "_".join(line_queries)

          search_query_name = ""
          search_query_part = line_queries[-1]
          search_result = result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"]
          search_count = search_result.shape[0]
          
          if search_count == 0:
            print("ERROR: No audio part found: ")
          elif search_count > 1:
            print("ERROR: Multiple audio found: ")
          else:
            result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"] = line_label

def getClassificationReport():
  max_duration = 10

  categorical_data = result.loc[
    (result["Duration"] < max_duration + 1) &
    (
      (result["Emotion"] == 'neu') |
      (result["Emotion"] == 'ang') |
      (result["Emotion"] == 'hap') |
      (result["Emotion"] == 'sad') 
    )
  ]
  
  categorical_plot = seaborn.countplot(x="Emotion", hue="Duration", data=categorical_data)
  categorical_plot.figure.set_size_inches(13,13)

  for p in categorical_plot.patches:
    height = p.get_height()
    categorical_plot.text(p.get_x() + p.get_width()/2., height + 3, '{:1.0f}'.format(height), ha="center") 

  return categorical_data

resetEvaluation()
goLabeling()
categorical_data = getClassificationReport()

# %% [markdown]
# # Selection and Splitting

# %%
def checkAndCreateDirectory(filename):
  if not os.path.exists(os.path.dirname(filename)):
    try:
        os.makedirs(os.path.dirname(filename))
    except OSError as exc: # Guard against race condition
        print(exc.errno)
        if exc.errno != errno.EEXIST:
            raise

def getMfccValue(audio_path, row, dataset_type):
  audio_file, sample_rate = librosa.load(audio_path)
  audio_file = denoise_wavelet(audio_file, method='VisuShrink', rescale_sigma=True)

  S = librosa.feature.melspectrogram(y=audio_file, sr=22000)
  # S[S < (np.average(S) * 1.0)] = np.average(S) * 0.1

  librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

  filename = "image/" + dataset_type + "/" + row["Emotion"] + "/" + row["Audio Name"] + "_" + row["Part"] + '.png'
  checkAndCreateDirectory(filename)

  plt.gca().set_axis_off()
  plt.savefig(filename, dpi=100, bbox_inches='tight',pad_inches=0)
  # plt.show()
  plt.clf()
  plt.close('all')

  return S

def getEncodedLabel(label):
  label_hot = [0, 0, 0, 0]
  
  if    (label == "neu"): label_hot = [1, 0, 0, 0]
  elif  (label == "ang"): label_hot = [0, 1, 0, 0]
  elif  (label == "hap"): label_hot = [0, 0, 1, 0]
  elif  (label == "sad"): label_hot = [0, 0, 0, 1]

  np.where(np.array(label_hot) == 1)[0][0]
  return np.array(label_hot)

def getAudioPath(row):
  audio_prefix = row["Audio Name"][:5]
  audio_session = "Error"

  if    (audio_prefix == 'Ses01'): audio_session = "Session1"
  elif  (audio_prefix == 'Ses02'): audio_session = "Session2"
  elif  (audio_prefix == 'Ses03'): audio_session = "Session3"
  elif  (audio_prefix == 'Ses04'): audio_session = "Session4"
  elif  (audio_prefix == 'Ses05'): audio_session = "Session5"

  audio_path = iemocap + '/' + audio_session + '/sentences/wav/' + row["Audio Name"] + '/' + row["Audio Name"] + '_' + row["Part"] + '.wav'
  return audio_path

def getVectorAudio(base_duration, durationed_data, dataset_type):
  X = [] # Data
  Y = [] # Label

  durationed_length = len(durationed_data)

  # Iterate every data
  for index, row in durationed_data.iterrows():
    print("Saving " + str(durationed_length) + " " + str(index), end=" | ")

    if durationed_length % 30 == 0: print("\n")
    durationed_length -= 1

    # Get Label
    label = row["Emotion"]
    label_hot = getEncodedLabel(label)

    # Get Mfcc
    audio_path = getAudioPath(row)
    mfcc = getMfccValue(audio_path, row, dataset_type)
    
    # X.append(np.mean(mfcc.T, axis=0))
    # Y.append(label_hot)
    
    mfcc_length = mfcc.shape[1]

    mfcc_slice = 50 * base_duration

    for mfcc_partial in range(int(mfcc_length/mfcc_slice)):
      start = mfcc_partial * mfcc_slice
      end = (mfcc_partial + 1) * mfcc_slice

      mfcc_partial_result = np.pad(mfcc, pad_width=((0,0), (0, (mfcc_slice - (mfcc_length % mfcc_slice)))), mode='constant')
      mfcc_partial_result = mfcc_partial_result[:,start:end]

      if (mfcc_partial_result.shape[1] != mfcc_slice) | (mfcc_partial_result.shape[0] != 128):
        print("ERROR Mfcc " + str(index) + str(row))
        print("ERROR Mfcc " + index + row)
        break
      
      X.append(mfcc_partial_result)
      Y.append(label_hot)

  return np.array(X), np.array(Y)

def testDuration():
  audio_file, sample_rate = librosa.load('/content/gdrive/My Drive/Public/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro04/Ses01F_impro04_M008.wav')
  duration = librosa.get_duration(y=audio_file, sr=sample_rate)
  print(duration)

  S = librosa.feature.mfcc(y=audio_file, sr=48000)
  print(S.shape)

def getEmotionSplitting(base_duration, max_duration):
  train_data    = pd.DataFrame()
  val_data      = pd.DataFrame()
  test_data     = pd.DataFrame()

  for iterate_index in range(base_duration, max_duration + 1):
    neutral_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'neu')
    ]

    angry_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'ang')
    ]

    sad_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'sad')
    ]

    happy_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'hap')
    ]
    
    print("Duration " + str(iterate_index))
    print("Neutral " + str(neutral_duration.shape[0]))
    print("Angry " + str(angry_duration.shape[0]))
    print("Sad " + str(sad_duration.shape[0]))
    print("Happy " + str(happy_duration.shape[0]))
    print()

    sample_lowest = min(neutral_duration.shape[0], angry_duration.shape[0], sad_duration.shape[0], happy_duration.shape[0])

    neutral_duration  = neutral_duration.sample(sample_lowest)
    angry_duration    = angry_duration.sample(sample_lowest)
    sad_duration      = sad_duration.sample(sample_lowest)
    happy_duration    = happy_duration.sample(sample_lowest)

    # Splitting # 0,6 : 0,8 : 1,0 (60%, 20%, 20%)
    data_training_percent   = int(0.6 * sample_lowest)
    data_validation_percent = int(0.8 * sample_lowest)

    train_data = train_data.append(neutral_duration [:data_training_percent])
    train_data = train_data.append(angry_duration   [:data_training_percent])
    train_data = train_data.append(sad_duration     [:data_training_percent])
    train_data = train_data.append(happy_duration   [:data_training_percent])

    val_data = val_data.append(neutral_duration   [data_training_percent:data_validation_percent])
    val_data = val_data.append(angry_duration     [data_training_percent:data_validation_percent])
    val_data = val_data.append(sad_duration       [data_training_percent:data_validation_percent])
    val_data = val_data.append(happy_duration     [data_training_percent:data_validation_percent])

    test_data = test_data.append(neutral_duration     [data_validation_percent:sample_lowest])
    test_data = test_data.append(angry_duration       [data_validation_percent:sample_lowest])
    test_data = test_data.append(sad_duration         [data_validation_percent:sample_lowest])
    test_data = test_data.append(happy_duration       [data_validation_percent:sample_lowest])

  return train_data.sample(frac=1), val_data.sample(frac=1), test_data.sample(frac=1)

base_duration = 3
max_duration = 3

train_data, val_data, test_data = getEmotionSplitting(base_duration, max_duration)
# !rm -rf image

# In vector and save image
x_train, y_train  = getVectorAudio(base_duration, train_data, "train")
x_val, y_val      = getVectorAudio(base_duration, val_data, "val")
x_test, y_test    = getVectorAudio(base_duration, test_data, "test")
# Out:
# Duration 3
# Neutral 285
# Angry 204
# Sad 181
# Happy 110
#
# Saving 264 3898 | Saving 263 691 | Saving 262 2563 | Saving 261 6624 | Saving 260 1369 | Saving 259 4363 | Saving 258 2276 | Saving 257 6654 | Saving 256 9869 | Saving 255 1948 | Saving 254 6278 | Saving 253 4237 | Saving 252 2854 | Saving 251 4712 | Saving 250 7426 | Saving 249 69 | Saving 248 2764 | Saving 247 8188 | Saving 246 8333 | Saving 245 2149 | Saving 244 1642 | Saving 243 4436 | Saving 242 2671 | Saving 241 5314 | Saving 240 2372 |
#
# Saving 239 3934 | Saving 238 3806 | Saving 237 45 | Saving 236 7046 | Saving 235 3689 | Saving 234 1806 | Saving 233 3823 | Saving 232 1141 | Saving 231 4793 | Saving 230 4377 | Saving 229 9674 | Saving 228 7622 | Saving 227 2981 | Saving 226 10033 | Saving 225 5028 | Saving 224 179 | Saving 223 8613 | Saving 222 5523 | Saving 221 5950 | Saving 220 8209 | Saving 219 9684 | Saving 218 4837 | Saving 217 8990 | Saving 216 1320 | Saving 215 719 | Saving 214 7176 | Saving 213 7174 | Saving 212 6701 | Saving 211 8480 | Saving 210 2598 |
#
# Saving 209 7156 | Saving 208 6815 | Saving 207 4171 | Saving 206 5583 | Saving 205 4991 | Saving 204 5435 | Saving 203 9500 | Saving 202 5267 | Saving 201 8645 | Saving 200 4387 | Saving 199 9896 | Saving 198 1410 | Saving 197 7806 | Saving 196 5049 | Saving 195 781 | Saving 194 9114 | Saving 193 4713 | Saving 192 3254 | Saving 191 729 | Saving 190 2661 | Saving 189 5762 | Saving 188 3901 | Saving 187 4432 | Saving 186 9129 | Saving 185 1221 | Saving 184 9633 | Saving 183 1315 | Saving 182 5596 | Saving 181 4099 | Saving 180 5683 |
#
# Saving 179 5369 | Saving 178 4684 | Saving 177 4357 | Saving 176 4618 | Saving 175 4682 | Saving 174 3834 | Saving 173 4463 | Saving 172 1759 | Saving 171 1559 | Saving 170 4780 | Saving 169 2558 | Saving 168 1924 | Saving 167 4100 | Saving 166 626 | Saving 165 2910 | Saving 164 4897 | Saving 163 1346 | Saving 162 1936 | Saving 161 4673 | Saving 160 2275 | Saving 159 9160 | Saving 158 3515 | Saving 157 7463 | Saving 156 5048 | Saving 155 3817 | Saving 154 9166 | Saving 153 1032 | Saving 152 5352 | Saving 151 9026 | Saving 150 7939 |
#
# Saving 149 6519 | Saving 148 2893 | Saving 147 442 | Saving 146 8337 | Saving 145 6544 | Saving 144 880 | Saving 143 6704 | Saving 142 4658 | Saving 141 3258 | Saving 140 9090 | Saving 139 4433 | Saving 138 2888 | Saving 137 8216 | Saving 136 3916 | Saving 135 1801 | Saving 134 9726 | Saving 133 1420 | Saving 132 5171 | Saving 131 9269 | Saving 130 6328 | Saving 129 886 | Saving 128 4936 | Saving 127 4625 | Saving 126 6378 | Saving 125 526 | Saving 124 8208 | Saving 123 3201 | Saving 122 72 | Saving 121 7950 | Saving 120 479 |
#
# Saving 119 4819 | Saving 118 9871 | Saving 117 5821 | Saving 116 5977 | Saving 115 118 | Saving 114 609 | Saving 113 7981 | Saving 112 93 | Saving 111 9322 | Saving 110 5055 | Saving 109 49 | Saving 108 8648 | Saving 107 38 | Saving 106 2559 | Saving 105 4123 | Saving 104 2234 | Saving 103 1429 | Saving 102 4271 | Saving 101 9681 | Saving 100 6958 | Saving 99 8512 | Saving 98 5373 | Saving 97 2162 | Saving 96 2047 | Saving 95 9954 | Saving 94 78 | Saving 93 6433 | Saving 92 8999 | Saving 91 8938 | Saving 90 4710 |
#
# Saving 89 8187 | Saving 88 8547 | Saving 87 3895 | Saving 86 3870 | Saving 85 3296 | Saving 84 5039 | Saving 83 995 | Saving 82 2049 | Saving 81 9305 | Saving 80 4356 | Saving 79 4706 | Saving 78 298 | Saving 77 4987 | Saving 76 4141 | Saving 75 1183 | Saving 74 2557 | Saving 73 1304 | Saving 72 4150 | Saving 71 7799 | Saving 70 6058 | Saving 69 4190 | Saving 68 1665 | Saving 67 9119 | Saving 66 5549 | Saving 65 7268 | Saving 64 948 | Saving 63 5026 | Saving 62 6094 | Saving 61 1303 | Saving 60 6450 |
#
# Saving 59 3465 | Saving 58 3582 | Saving 57 5220 | Saving 56 684 | Saving 55 1200 | Saving 54 4192 | Saving 53 3222 | Saving 52 8833 | Saving 51 7542 | Saving 50 935 | Saving 49 7453 | Saving 48 1321 | Saving 47 6048 | Saving 46 109 | Saving 45 207 | Saving 44 7639 | Saving 43 6432 | Saving 42 5722 | Saving 41 4746 | Saving 40 1937 | Saving 39 3009 | Saving 38 60 | Saving 37 4202 | Saving 36 4588 | Saving 35 1181 | Saving 34 4383 | Saving 33 2164 | Saving 32 9355 | Saving 31 2736 | Saving 30 6658 |
#
# Saving 29 1575 | Saving 28 7642 | Saving 27 5391 | Saving 26 6513 | Saving 25 7452 | Saving 24 8262 | Saving 23 5014 | Saving 22 2738 | Saving 21 8045 | Saving 20 5202 | Saving 19 7060 | Saving 18 4969 | Saving 17 1472 | Saving 16 8614 | Saving 15 4967 | Saving 14 499 | Saving 13 5389 | Saving 12 5250 | Saving 11 8639 | Saving 10 5988 | Saving 9 9158 | Saving 8 4384 | Saving 7 1925 | Saving 6 1744 | Saving 5 3275 | Saving 4 5723 | Saving 3 4551 | Saving 2 1255 | Saving 1 4393 | Saving 88 6799 | Saving 87 5673 | Saving 86 10026 | Saving 85 967 | Saving 84 9502 | Saving 83 4201 | Saving 82 8145 | Saving 81 4525 | Saving 80 4006 | Saving 79 4408 | Saving 78 8917 | Saving 77 4226 | Saving 76 3864 | Saving 75 5338 | Saving 74 4834 | Saving 73 2304 | Saving 72 1657 | Saving 71 220 | Saving 70 9952 | Saving 69 524 | Saving 68 936 | Saving 67 5312 | Saving 66 4542 | Saving 65 5315 | Saving 64 5787 | Saving 63 1187 | Saving 62 7400 | Saving 61 8346 | Saving 60 8932 |
#
# Saving 59 7289 | Saving 58 7442 | Saving 57 5040 | Saving 56 8637 | Saving 55 9987 | Saving 54 6045 | Saving 53 48 | Saving 52 6636 | Saving 51 3274 | Saving 50 165 | Saving 49 9113 | Saving 48 1922 | Saving 47 6657 | Saving 46 1667 | Saving 45 5038 | Saving 44 9716 | Saving 43 427 | Saving 42 7942 | Saving 41 7389 | Saving 40 6860 | Saving 39 5368 | Saving 38 1192 | Saving 37 156 | Saving 36 6646 | Saving 35 7556 | Saving 34 1707 | Saving 33 7044 | Saving 32 4216 | Saving 31 4591 | Saving 30 1682 |
#
# Saving 29 1669 | Saving 28 1276 | Saving 27 8125 | Saving 26 3807 | Saving 25 7800 | Saving 24 7210 | Saving 23 868 | Saving 22 6809 | Saving 21 8689 | Saving 20 969 | Saving 19 62 | Saving 18 1678 | Saving 17 3750 | Saving 16 7017 | Saving 15 7340 | Saving 14 3253 | Saving 13 1188 | Saving 12 843 | Saving 11 2836 | Saving 10 2213 | Saving 9 5376 | Saving 8 9497 | Saving 7 1419 | Saving 6 917 | Saving 5 6386 | Saving 4 7923 | Saving 3 5955 | Saving 2 9876 | Saving 1 384 | Saving 88 9215 | Saving 87 4390 | Saving 86 3862 | Saving 85 9133 | Saving 84 3086 | Saving 83 1124 | Saving 82 5082 | Saving 81 4555 | Saving 80 3877 | Saving 79 3852 | Saving 78 4189 | Saving 77 7855 | Saving 76 1720 | Saving 75 5528 | Saving 74 2961 | Saving 73 3418 | Saving 72 4741 | Saving 71 3116 | Saving 70 1663 | Saving 69 5010 | Saving 68 5269 | Saving 67 9440 | Saving 66 5341 | Saving 65 2853 | Saving 64 620 | Saving 63 885 | Saving 62 9147 | Saving 61 8109 | Saving 60 3147 |
#
# Saving 59 7466 | Saving 58 2830 | Saving 57 1424 | Saving 56 6242 | Saving 55 3529 | Saving 54 7776 | Saving 53 696 | Saving 52 8494 | Saving 51 167 | Saving 50 3858 | Saving 49 3139 | Saving 48 8838 | Saving 47 6434 | Saving 46 8914 | Saving 45 949 | Saving 44 7379 | Saving 43 5288 | Saving 42 3271 | Saving 41 5009 | Saving 40 3688 | Saving 39 4919 | Saving 38 881 | Saving 37 5006 | Saving 36 4023 | Saving 35 3912 | Saving 34 8221 | Saving 33 1428 | Saving 32 3115 | Saving 31 3608 | Saving 30 6805 |
#
# Saving 29 1196 | Saving 28 7820 | Saving 27 7767 | Saving 26 3015 | Saving 25 7140 | Saving 24 2499 | Saving 23 3906 | Saving 22 7688 | Saving 21 379 | Saving 20 653 | Saving 19 1307 | Saving 18 702 | Saving 17 1634 | Saving 16 7010 | Saving 15 9426 | Saving 14 7761 | Saving 13 213 | Saving 12 5169 | Saving 11 5149 | Saving 10 841 | Saving 9 1723 | Saving 8 1450 | Saving 7 1787 | Saving 6 1757 | Saving 5 5770 | Saving 4 7436 | Saving 3 578 | Saving 2 3714 | Saving 1 1283 |

# %%
audio_file, sample_rate = librosa.load('/content/gdrive/My Drive/Public/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro04/Ses01F_impro04_M002.wav')

S = librosa.feature.melspectrogram(y=audio_file, sr=48000)
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

# %%
S = librosa.feature.melspectrogram(y=audio_file, sr=48000)
S[S < (np.average(S) * 1.)] = 0.001

librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

# %%
def loadGenerator():
  # 352, 235
  train_image_generator = ImageDataGenerator()
  train_data = train_image_generator.flow_from_directory(
      directory="image/train/",
      class_mode="categorical",
      batch_size=4,
      shuffle=True,
      target_size=(128, 128)
  )
    
  validation_image_generator = ImageDataGenerator()
  validation_data = validation_image_generator.flow_from_directory(
      directory="image/val/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(128, 128)
  )

  test_image_generator = ImageDataGenerator()
  test_data = test_image_generator.flow_from_directory(
      directory="image/test/",
      batch_size=1,
      class_mode="categorical",
      shuffle=True,
      target_size=(128, 128)
  )

  return train_data, validation_data, test_data

# def scaleVector():
#   scaler = MinMaxScaler()

#   x_train_scaled = []
#   x_val_scaled = []

#   for x in x_train:
#     scaler.partial_fit(x)

#   for x in x_val:
#     scaler.partial_fit(x)

#   for x in x_train:
#     x_result = scaler.transform(x)
#     x_train_scaled.append(x_result)

#   for x in x_val:
#     x_result = scaler.transform(x)
#     x_val_scaled.append(x_result)

#   return np.array(x_train_scaled), np.array(x_val_scaled)

# In generator
train_generator, validation_generator, test_generator = loadGenerator()

# In vector
# x_train_scaled, x_val_scaled = scaleVector()

print(x_train.shape)
print(x_val.shape)
# Out:
# Found 264 images belonging to 4 classes.
# Found 88 images belonging to 4 classes.
# Found 88 images belonging to 4 classes.
# (133, 128, 150)
# (45, 128, 150)

# %%
def load_model(struct, weight):
  # json_file = open("/content/model/" + struct + ".json", "r")
  json_file = open("struct_model.json", "r")
  loaded_model_json = json_file.read()
  json_file.close()

  loaded_model = model_from_json(loaded_model_json)
  # loaded_model.load_weights("/content/model/" + weight + ".hdf5")
  loaded_model.load_weights("weight_model_62_0.49_0.80_1.15_0.72.hdf5")
  loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  return loaded_model

# lastCheckpoint = sorted(Path("/content/model").iterdir(), key=os.path.getmtime)[-1].stem
# print("Model is " + lastCheckpoint)

# loaded_model = load_model("struct_model", lastCheckpoint)

loaded_model = load_model("struct_model", "")

# %%
def plot_result(model, history):
  # list all data in history
  print(history.history.keys())

  # summarize history for accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss') 
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

def save_model(model, filename):
  checkAndCreateDirectory("/content/model/test.txt")
  model.summary()

  plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

  with open("/content/model/" + filename + ".json", "w") as json_file:
    model_json = model.to_json()
    json_file.write(model_json)

def buildModel():
  model_input = Input(shape=(128, 128, 3))
  # model_input = Input(shape=(128, 1))

  model = Conv2D(16, kernel_size=5, strides=1, padding='valid', trainable=True)(model_input)
  model = BatchNormalization()(model)
  model = Activation('relu')(model)
  model = Dropout(0.5)(model)

  model = Conv2D(16, kernel_size=5, strides=1, padding='valid', trainable=True)(model)
  model = BatchNormalization()(model)
  model = Activation('relu')(model)
  model = Dropout(0.5)(model)

  model = Conv2D(32, kernel_size=5, strides=1, padding='valid', trainable=True)(model)
  model = BatchNormalization()(model)
  model = Activation('relu')(model)
  model = Dropout(0.5)(model)

  model = Conv2D(32, kernel_size=5, strides=1, padding='valid', trainable=True)(model)
  model = BatchNormalization()(model)
  model = Activation('relu')(model)
  model = Dropout(0.5)(model)

  model = Flatten()(model)

  model = Dense(512)(model)

  model = Dense(4, activation='softmax')(model)
  
  # Model compile
  model = Model(inputs=[model_input], outputs=[model])
  model.compile(optimizer="adam", loss=tf.keras.losses.CategoricalCrossentropy(), metrics=["accuracy"])
  
  # Visualize & Save Model
  save_model(loaded_model, "struct_model")

  # Checkpoint
  basepath = '/content/model/weight_model'
  best_checkpoint = ModelCheckpoint(basepath +'_{epoch:02d}_{loss:.2f}_{accuracy:.2f}_{val_loss:.2f}_{val_accuracy:.2f}.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
  callback_list = [best_checkpoint]

  # history = model.fit(
  #   x_train, 
  #   y_train, 
  #   validation_data=(x_val, y_val),
  #   batch_size=4, 
  #   epochs=100,
  #   callbacks=callback_list
  # )

  history = loaded_model.fit_generator(
    generator=train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=callback_list
  )

  return model, history

model = None
history = None

# !sudo chmod 777 /mnt
# !rm -rf model
# !rm -rf /mnt/model
# !rm -rf ../.local/share/Trash/files

# device = cuda.get_current_device()
# device.reset()

model, history = buildModel()
plot_result(model, history)
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 124, 124, 16)      1216
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 124, 124, 16)      64
# _________________________________________________________________
# activation_43 (Activation)   (None, 124, 124, 16)      0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 124, 124, 16)      0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 59, 59, 16)        12560
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 59, 59, 16)        64
# _________________________________________________________________
# activation_44 (Activation)   (None, 59, 59, 16)        0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 59, 59, 16)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 53, 53, 32)        25120
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 53, 53, 32)        128
# _________________________________________________________________
# activation_45 (Activation)   (None, 53, 53, 32)        0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 53, 53, 32)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 22, 22, 32)        102432
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 22, 22, 32)        128
# _________________________________________________________________
# activation_46 (Activation)   (None, 22, 22, 32)        0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 16, 16, 64)        100416
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_47 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 4, 4, 64)          409664
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 4, 4, 64)          256
# _________________________________________________________________
# activation_48 (Activation)   (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_29 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_30 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_31 (Dense)             (None, 4)                 4100
# =================================================================
# Total params: 3,805,204
# Trainable params: 3,804,756
# Non-trainable params: 448
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
#  4/66 [>.............................] - ETA: 1s - loss: 0.3487 - accuracy: 0.8750
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 66/66 [==============================] - 2s 30ms/step - loss: 0.3879 - accuracy: 0.8939 - val_loss: 3.8909 - val_accuracy: 0.4432
#
# Epoch 00001: val_accuracy improved from -inf to 0.44318, saving model to /content/model/weight_model_01_0.39_0.89_3.89_0.44.hdf5
# Epoch 2/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3071 - accuracy: 0.9280 - val_loss: 2.9512 - val_accuracy: 0.3977
#
# Epoch 00002: val_accuracy did not improve from 0.44318
# Epoch 3/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3267 - accuracy: 0.9129 - val_loss: 3.3855 - val_accuracy: 0.3636
#
# Epoch 00003: val_accuracy did not improve from 0.44318
# Epoch 4/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2732 - accuracy: 0.9318 - val_loss: 3.7724 - val_accuracy: 0.4432
#
# Epoch 00004: val_accuracy did not improve from 0.44318
# Epoch 5/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2446 - accuracy: 0.9242 - val_loss: 3.6546 - val_accuracy: 0.3864
#
# Epoch 00005: val_accuracy did not improve from 0.44318
# Epoch 6/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.1266 - accuracy: 0.9583 - val_loss: 3.9261 - val_accuracy: 0.3750
#
# Epoch 00006: val_accuracy did not improve from 0.44318
# Epoch 7/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2058 - accuracy: 0.9508 - val_loss: 3.6971 - val_accuracy: 0.4205
#
# Epoch 00007: val_accuracy did not improve from 0.44318
# Epoch 8/100
# 66/66 [==============================] - 2s 31ms/step - loss: 0.2931 - accuracy: 0.9091 - val_loss: 4.4458 - val_accuracy: 0.3864
#
# Epoch 00008: val_accuracy did not improve from 0.44318
# Epoch 9/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2604 - accuracy: 0.9242 - val_loss: 3.9559 - val_accuracy: 0.4318
#
# Epoch 00009: val_accuracy did not improve from 0.44318
# Epoch 10/100
# 66/66 [==============================] - 2s 30ms/step - loss: 0.4743 - accuracy: 0.8977 - val_loss: 3.7847 - val_accuracy: 0.3182
#
# Epoch 00010: val_accuracy did not improve from 0.44318
# Epoch 11/100
# 66/66 [==============================] - 2s 30ms/step - loss: 0.1619 - accuracy: 0.9470 - val_loss: 3.4227 - val_accuracy: 0.4091
#
# Epoch 00011: val_accuracy did not improve from 0.44318
# Epoch 12/100
# 66/66 [==============================] - 2s 30ms/step - loss: 0.1428 - accuracy: 0.9659 - val_loss: 3.5710 - val_accuracy: 0.4091
#
# Epoch 00012: val_accuracy did not improve from 0.44318
# Epoch 13/100
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0840 - accuracy: 0.9659 - val_loss: 4.0005 - val_accuracy: 0.3977
#
# Epoch 00013: val_accuracy did not improve from 0.44318
# Epoch 14/100
# 66/66 [==============================] - 2s 30ms/step - loss: 0.1641 - accuracy: 0.9508 - val_loss: 3.5678 - val_accuracy: 0.4205
#
# Epoch 00014: val_accuracy did not improve from 0.44318
# Epoch 15/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.1806 - accuracy: 0.9394 - val_loss: 3.2053 - val_accuracy: 0.4091
#
# Epoch 00015: val_accuracy did not improve from 0.44318
# Epoch 16/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4032 - accuracy: 0.8939 - val_loss: 3.3488 - val_accuracy: 0.3977
#
# Epoch 00016: val_accuracy did not improve from 0.44318
# Epoch 17/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2205 - accuracy: 0.9318 - val_loss: 5.6115 - val_accuracy: 0.3977
#
# Epoch 00017: val_accuracy did not improve from 0.44318
# Epoch 18/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.5665 - accuracy: 0.9015 - val_loss: 9.8599 - val_accuracy: 0.3409
#
# Epoch 00018: val_accuracy did not improve from 0.44318
# Epoch 19/100
# 66/66 [==============================] - 2s 29ms/step - loss: 1.2429 - accuracy: 0.8371 - val_loss: 9.6019 - val_accuracy: 0.4318
#
# Epoch 00019: val_accuracy did not improve from 0.44318
# Epoch 20/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.7316 - accuracy: 0.8182 - val_loss: 6.5899 - val_accuracy: 0.3750
#
# Epoch 00020: val_accuracy did not improve from 0.44318
# Epoch 21/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4822 - accuracy: 0.8902 - val_loss: 5.0642 - val_accuracy: 0.3864
#
# Epoch 00021: val_accuracy did not improve from 0.44318
# Epoch 22/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.4108 - accuracy: 0.9129 - val_loss: 4.4802 - val_accuracy: 0.4091
#
# Epoch 00022: val_accuracy did not improve from 0.44318
# Epoch 23/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.5781 - accuracy: 0.8864 - val_loss: 4.9304 - val_accuracy: 0.3750
#
# Epoch 00023: val_accuracy did not improve from 0.44318
# Epoch 24/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3881 - accuracy: 0.8750 - val_loss: 4.3306 - val_accuracy: 0.3977
#
# Epoch 00024: val_accuracy did not improve from 0.44318
# Epoch 25/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4629 - accuracy: 0.8826 - val_loss: 2.9120 - val_accuracy: 0.4886
#
# Epoch 00025: val_accuracy improved from 0.44318 to 0.48864, saving model to /content/model/weight_model_25_0.46_0.88_2.91_0.49.hdf5
# Epoch 26/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3354 - accuracy: 0.9015 - val_loss: 2.9989 - val_accuracy: 0.4432
#
# Epoch 00026: val_accuracy did not improve from 0.48864
# Epoch 27/100
# 66/66 [==============================] - 2s 30ms/step - loss: 0.3098 - accuracy: 0.9129 - val_loss: 3.4884 - val_accuracy: 0.4318
#
# Epoch 00027: val_accuracy did not improve from 0.48864
# Epoch 28/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.1442 - accuracy: 0.9356 - val_loss: 3.5686 - val_accuracy: 0.3864
#
# Epoch 00028: val_accuracy did not improve from 0.48864
# Epoch 29/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.3279 - accuracy: 0.9318 - val_loss: 3.1987 - val_accuracy: 0.4773
#
# Epoch 00029: val_accuracy did not improve from 0.48864
# Epoch 30/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2780 - accuracy: 0.9205 - val_loss: 3.4182 - val_accuracy: 0.3864
#
# Epoch 00030: val_accuracy did not improve from 0.48864
# Epoch 31/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.2976 - accuracy: 0.9205 - val_loss: 2.9986 - val_accuracy: 0.4318
#
# Epoch 00031: val_accuracy did not improve from 0.48864
# Epoch 32/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.1545 - accuracy: 0.9432 - val_loss: 3.0056 - val_accuracy: 0.4432
#
# Epoch 00032: val_accuracy did not improve from 0.48864
# Epoch 33/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2592 - accuracy: 0.9167 - val_loss: 5.0745 - val_accuracy: 0.4091
#
# Epoch 00033: val_accuracy did not improve from 0.48864
# Epoch 34/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.2612 - accuracy: 0.9280 - val_loss: 4.3039 - val_accuracy: 0.4091
#
# Epoch 00034: val_accuracy did not improve from 0.48864
# Epoch 35/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4311 - accuracy: 0.9015 - val_loss: 3.6606 - val_accuracy: 0.4091
#
# Epoch 00035: val_accuracy did not improve from 0.48864
# Epoch 36/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2627 - accuracy: 0.9432 - val_loss: 3.4437 - val_accuracy: 0.4773
#
# Epoch 00036: val_accuracy did not improve from 0.48864
# Epoch 37/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.3557 - accuracy: 0.9015 - val_loss: 3.6591 - val_accuracy: 0.4886
#
# Epoch 00037: val_accuracy did not improve from 0.48864
# Epoch 38/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3297 - accuracy: 0.9470 - val_loss: 4.6174 - val_accuracy: 0.4773
#
# Epoch 00038: val_accuracy did not improve from 0.48864
# Epoch 39/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2696 - accuracy: 0.9432 - val_loss: 6.0246 - val_accuracy: 0.3636
#
# Epoch 00039: val_accuracy did not improve from 0.48864
# Epoch 40/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2207 - accuracy: 0.9470 - val_loss: 5.4163 - val_accuracy: 0.3409
#
# Epoch 00040: val_accuracy did not improve from 0.48864
# Epoch 41/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.2668 - accuracy: 0.9205 - val_loss: 5.7999 - val_accuracy: 0.4545
#
# Epoch 00041: val_accuracy did not improve from 0.48864
# Epoch 42/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2733 - accuracy: 0.9356 - val_loss: 3.9236 - val_accuracy: 0.4773
#
# Epoch 00042: val_accuracy did not improve from 0.48864
# Epoch 43/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4656 - accuracy: 0.8977 - val_loss: 4.5503 - val_accuracy: 0.4545
#
# Epoch 00043: val_accuracy did not improve from 0.48864
# Epoch 44/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4437 - accuracy: 0.9167 - val_loss: 4.5027 - val_accuracy: 0.4318
#
# Epoch 00044: val_accuracy did not improve from 0.48864
# Epoch 45/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.6115 - accuracy: 0.8826 - val_loss: 4.8618 - val_accuracy: 0.3864
#
# Epoch 00045: val_accuracy did not improve from 0.48864
# Epoch 46/100
# 66/66 [==============================] - 2s 29ms/step - loss: 1.8681 - accuracy: 0.7765 - val_loss: 9.1693 - val_accuracy: 0.3750
#
# Epoch 00046: val_accuracy did not improve from 0.48864
# Epoch 47/100
# 66/66 [==============================] - 2s 29ms/step - loss: 2.0468 - accuracy: 0.7197 - val_loss: 4.6085 - val_accuracy: 0.3977
#
# Epoch 00047: val_accuracy did not improve from 0.48864
# Epoch 48/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.7023 - accuracy: 0.8636 - val_loss: 4.6070 - val_accuracy: 0.4318
#
# Epoch 00048: val_accuracy did not improve from 0.48864
# Epoch 49/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.7655 - accuracy: 0.8447 - val_loss: 3.8151 - val_accuracy: 0.4091
#
# Epoch 00049: val_accuracy did not improve from 0.48864
# Epoch 50/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.5066 - accuracy: 0.8826 - val_loss: 3.2094 - val_accuracy: 0.4318
#
# Epoch 00050: val_accuracy did not improve from 0.48864
# Epoch 51/100
# 66/66 [==============================] - 2s 30ms/step - loss: 0.3581 - accuracy: 0.9091 - val_loss: 3.3173 - val_accuracy: 0.4886
#
# Epoch 00051: val_accuracy did not improve from 0.48864
# Epoch 52/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3726 - accuracy: 0.8977 - val_loss: 3.1330 - val_accuracy: 0.4318
#
# Epoch 00052: val_accuracy did not improve from 0.48864
# Epoch 53/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2660 - accuracy: 0.9394 - val_loss: 3.2602 - val_accuracy: 0.4091
#
# Epoch 00053: val_accuracy did not improve from 0.48864
# Epoch 54/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2885 - accuracy: 0.9356 - val_loss: 3.4338 - val_accuracy: 0.4318
#
# Epoch 00054: val_accuracy did not improve from 0.48864
# Epoch 55/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.1940 - accuracy: 0.9356 - val_loss: 3.7872 - val_accuracy: 0.4432
#
# Epoch 00055: val_accuracy did not improve from 0.48864
# Epoch 56/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.4400 - accuracy: 0.8902 - val_loss: 3.7582 - val_accuracy: 0.3864
#
# Epoch 00056: val_accuracy did not improve from 0.48864
# Epoch 57/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2663 - accuracy: 0.9470 - val_loss: 4.1045 - val_accuracy: 0.3977
#
# Epoch 00057: val_accuracy did not improve from 0.48864
# Epoch 58/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3272 - accuracy: 0.9280 - val_loss: 4.0063 - val_accuracy: 0.3523
#
# Epoch 00058: val_accuracy did not improve from 0.48864
# Epoch 59/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4239 - accuracy: 0.9242 - val_loss: 4.4577 - val_accuracy: 0.4091
#
# Epoch 00059: val_accuracy did not improve from 0.48864
# Epoch 60/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.2048 - accuracy: 0.9053 - val_loss: 4.5130 - val_accuracy: 0.3636
#
# Epoch 00060: val_accuracy did not improve from 0.48864
# Epoch 61/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3099 - accuracy: 0.9280 - val_loss: 4.3657 - val_accuracy: 0.3864
#
# Epoch 00061: val_accuracy did not improve from 0.48864
# Epoch 62/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.2581 - accuracy: 0.9356 - val_loss: 5.5817 - val_accuracy: 0.3523
#
# Epoch 00062: val_accuracy did not improve from 0.48864
# Epoch 63/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.2328 - accuracy: 0.9394 - val_loss: 4.9582 - val_accuracy: 0.3750
#
# Epoch 00063: val_accuracy did not improve from 0.48864
# Epoch 64/100
# 66/66 [==============================] - 2s 28ms/step - loss: 0.3308 - accuracy: 0.9318 - val_loss: 5.5688 - val_accuracy: 0.4205
#
# Epoch 00064: val_accuracy did not improve from 0.48864
# Epoch 65/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3615 - accuracy: 0.9167 - val_loss: 8.0846 - val_accuracy: 0.3864
#
# Epoch 00065: val_accuracy did not improve from 0.48864
# Epoch 66/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4864 - accuracy: 0.9167 - val_loss: 6.4458 - val_accuracy: 0.3182
#
# Epoch 00066: val_accuracy did not improve from 0.48864
# Epoch 67/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3252 - accuracy: 0.9205 - val_loss: 5.3912 - val_accuracy: 0.4091
#
# Epoch 00067: val_accuracy did not improve from 0.48864
# Epoch 68/100
# 66/66 [==============================] - 2s 31ms/step - loss: 0.2310 - accuracy: 0.9394 - val_loss: 4.7554 - val_accuracy: 0.3977
#
# Epoch 00068: val_accuracy did not improve from 0.48864
# Epoch 69/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.6492 - accuracy: 0.8977 - val_loss: 7.6555 - val_accuracy: 0.4545
#
# Epoch 00069: val_accuracy did not improve from 0.48864
# Epoch 70/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.7031 - accuracy: 0.9015 - val_loss: 8.0206 - val_accuracy: 0.4091
#
# Epoch 00070: val_accuracy did not improve from 0.48864
# Epoch 71/100
# 66/66 [==============================] - 2s 29ms/step - loss: 1.6636 - accuracy: 0.8598 - val_loss: 7.1136 - val_accuracy: 0.3409
#
# Epoch 00071: val_accuracy did not improve from 0.48864
# Epoch 72/100
# 66/66 [==============================] - 2s 29ms/step - loss: 1.8778 - accuracy: 0.8598 - val_loss: 13.8790 - val_accuracy: 0.4886
#
# Epoch 00072: val_accuracy did not improve from 0.48864
# Epoch 73/100
# 66/66 [==============================] - 2s 29ms/step - loss: 1.6791 - accuracy: 0.8371 - val_loss: 10.5489 - val_accuracy: 0.3295
#
# Epoch 00073: val_accuracy did not improve from 0.48864
# Epoch 74/100
# 66/66 [==============================] - 2s 29ms/step - loss: 1.3039 - accuracy: 0.8409 - val_loss: 6.8616 - val_accuracy: 0.3409
#
# Epoch 00074: val_accuracy did not improve from 0.48864
# Epoch 75/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.8475 - accuracy: 0.8864 - val_loss: 6.9179 - val_accuracy: 0.4091
#
# Epoch 00075: val_accuracy did not improve from 0.48864
# Epoch 76/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.4886 - accuracy: 0.9129 - val_loss: 6.4857 - val_accuracy: 0.3977
#
# Epoch 00076: val_accuracy did not improve from 0.48864
# Epoch 77/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.3817 - accuracy: 0.9167 - val_loss: 5.6239 - val_accuracy: 0.4773
#
# Epoch 00077: val_accuracy did not improve from 0.48864
# Epoch 78/100
# 66/66 [==============================] - 2s 29ms/step - loss: 0.5936 - accuracy: 0.9167 - val_loss: 4.6509 - val_accuracy: 0.3977
#
# Epoch 00078: val_accuracy did not improve from 0.48864
# Epoch 79/100
# 64/66 [============================>.] - ETA: 0s - loss: 0.5252 - accuracy: 0.8906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9ca105f8306c> in <module>()
#     102 # device.reset()
#     103
# --> 104 model, history = buildModel()
#     105 plot_result(model, history)
#
# <ipython-input-12-9ca105f8306c> in buildModel()
#      86     validation_data=validation_generator,
#      87     epochs=100,
# ---> 88     callbacks=callback_list
#      89   )
#      90
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1859         use_multiprocessing=use_multiprocessing,
#    1860         shuffle=shuffle,
# -> 1861         initial_epoch=initial_epoch)
#    1862
#    1863   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1139               workers=workers,
#    1140               use_multiprocessing=use_multiprocessing,
# -> 1141               return_dict=True)
#    1142           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1143           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1387             with trace.Trace('test', step_num=step, _r=1):
#    1388               callbacks.on_test_batch_begin(step)
# -> 1389               tmp_logs = self.test_function(iterator)
#    1390               if data_handler.should_sync:
#    1391                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
def load_model(struct, weight):
  # json_file = open("/content/model/" + struct + ".json", "r")
  json_file = open("struct_model.json", "r")
  loaded_model_json = json_file.read()
  json_file.close()

  loaded_model = model_from_json(loaded_model_json)
  # loaded_model.load_weights("/content/model/" + weight + ".hdf5")
  loaded_model.load_weights("weight_model_62_0.49_0.80_1.15_0.72.hdf5")
  loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  return loaded_model

# lastCheckpoint = sorted(Path("/content/model").iterdir(), key=os.path.getmtime)[-1].stem
# print("Model is " + lastCheckpoint)

# loaded_model = load_model("struct_model", lastCheckpoint)

loaded_model = load_model("struct_model", "")

# %% [markdown]
# # Testing

# %%
train_loss, train_accuracy = loaded_model.evaluate(x_train, y_train)
val_loss, val_accuracy = loaded_model.evaluate(x_val, y_val)
test_loss, test_accuracy = loaded_model.evaluate(x_test, y_test)

print(
    ""
    "\n"
    "Train Loss: " + str(train_loss) + "\n"
    "Train Accuracy: " + str(train_accuracy * 100) + "%\n"
    "\n"
    "Validation Loss: " + str(val_loss) + "\n"
    "Validation Accuracy: " + str(val_accuracy * 100) + "%\n"
    "\n"
    "Test Loss: " + str(test_loss) + "\n"
    "Test Accuracy: " + str(test_accuracy * 100) + "%"
    "")
# Out:
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9953
# 11/11 [==============================] - 0s 6ms/step - loss: 3.0408 - accuracy: 0.5693
# 11/11 [==============================] - 0s 6ms/step - loss: 3.1216 - accuracy: 0.5588
#
# Train Loss: 0.01928798481822014
# Train Accuracy: 99.4918704032898%
#
# Validation Loss: 3.040834665298462
# Validation Accuracy: 56.92771077156067%
#
# Test Loss: 3.1215615272521973
# Test Accuracy: 55.88235259056091%

# %%
loss, accuracy = loaded_model.evaluate_generator(generator=test_generator)
print(
    ""
    "Prediction Loss: %2d\n"
    "Prediction Accuracy: %2d%%"
    ""
    % (loss, accuracy * 100))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Prediction Loss:  4
# Prediction Accuracy: 27%

# %% [markdown]
# # Analysis

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

y_decoded = []
for pred in y_test:
  decoded = np.where(pred == 1)[0][0]
  y_decoded.append(decoded)

print('Confusion Matrix')
print(target_names)
print(confusion_matrix(y_decoded, y_pred))
print(x_test.shape)

print('\n\nClassification Report')
print(classification_report(y_decoded, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# ['neu', 'ang', 'hap', 'sad']
# [[ 3  2  7  3]
#  [ 2  6  6  3]
#  [ 7  3  5  3]
#  [ 3  0  4 10]]
# (67, 128, 50)
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#          neu       0.20      0.20      0.20        15
#          ang       0.55      0.35      0.43        17
#          hap       0.23      0.28      0.25        18
#          sad       0.53      0.59      0.56        17
#
#     accuracy                           0.36        67
#    macro avg       0.37      0.35      0.36        67
# weighted avg       0.38      0.36      0.36        67

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_data.classes, y_pred))

print('\n\nClassification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
