# %% [markdown]
# # Prepare Data

# %%
from google.colab import files
from google.colab import drive

from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input, Softmax
from keras.engine.saving import model_from_json
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils.vis_utils import plot_model
from keras_preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from pathlib import Path

import os
import sys

import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

import librosa
import librosa.display

import tensorflow as tf

# %%
drive.mount('/content/gdrive', force_remount=True)
iemocap = "gdrive/My Drive/Public/IEMOCAP_full_release"

print("GPU Name: ", tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Mounted at /content/gdrive
# GPU Name:  /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# # Convert into CSV

# %%
sessions = ["Session1", "Session2", "Session3", "Session4", "Session5"]

def convertSession(session_name):
  session_file = iemocap + "/Duration/Processed/" + session_name + ".txt"
  tokenized_lines = []

  with open(session_file) as f:
    lines = f.readlines()
    tokenizedLines = [x.split() for x in lines]

  session_csv = iemocap + "/Duration/Processed/" + session_name + ".csv"
  with open(session_csv, "w") as csv:
    audio_name = ''

    for line in tokenizedLines:
      if line[0] == "Recording":
        audio_name = line[1]
      else:
        csv.write(audio_name + ";" + line[0] + ";" + line[1] + "\n")

def convertRawToCsv():
  for session in sessions:
    convertSession(session)

# convertRawToCsv()

# %% [markdown]
# # Convert into data frame

# %%
def getSessionData(session_name):
  df = pd.read_csv(iemocap + "/Duration/Processed/" + session_name + ".csv", delimiter=";", header=None)
  df.columns = ["Audio Name", "Part", "Duration"]
  print(session_name + " count: " + str(len(df.index)))

  return df

def getDataFrame():
  result = pd.DataFrame()

  for session in sessions:
    df = getSessionData(session)
    result = result.append(df, ignore_index=True)

  return result

result = getDataFrame()
result["Duration"] = result["Duration"].apply(np.floor).astype(int)
result
# Out:
# Session1 count: 1819
# Session2 count: 1811
# Session3 count: 2136
# Session4 count: 2103
# Session5 count: 2170
#               Audio Name  Part  Duration
# 0         Ses01F_impro01  F000         1
# 1         Ses01F_impro01  F001         1
# 2         Ses01F_impro01  F002         3
# 3         Ses01F_impro01  F003         1
# 4         Ses01F_impro01  F004         3
# ...                  ...   ...       ...
# 10034  Ses05M_script03_2  M041         8
# 10035  Ses05M_script03_2  M042         1
# 10036  Ses05M_script03_2  M043         2
# 10037  Ses05M_script03_2  M044         4
# 10038  Ses05M_script03_2  M045         6
#
# [10039 rows x 3 columns]

# %% [markdown]
# # Plot

# %%
plot = seaborn.countplot(x='Duration', data=result)
plot.figure.set_size_inches(13,13)

for p in plot.patches:
  height = p.get_height()
  plot.text(p.get_x() + p.get_width()/2., height + 10, '{:1.0f}'.format(height), ha="center")

# %%
print("Original data: " + str(result.count()))

count_data = result.value_counts(subset=['Duration'], sort=False).values
count_normalize = result.value_counts(subset=['Duration'], sort=False, normalize=True).values
duration = sorted(result.Duration.unique())

count_df = pd.DataFrame({"Duration": duration, "Count": count_data, "Percentage": count_normalize})
count_df.Percentage = (count_df.Percentage * 100).round(3)
count_df
# Out:
# Original data: Audio Name     10039
# Part           10039
# Duration       10039
# Evaluation1        0
# Evaluation2        0
# Evaluation3        0
# Evaluation4        0
# Evaluation5        0
# Evaluation6        0
# Emotion        10039
# dtype: int64
#     Duration  Count  Percentage
# 0          0     50       0.498
# 1          1   1650      16.436
# 2          2   2341      23.319
# 3          3   1717      17.103
# 4          4   1148      11.435
# 5          5    828       8.248
# 6          6    682       6.794
# 7          7    449       4.473
# 8          8    322       3.207
# 9          9    249       2.480
# 10        10    175       1.743
# 11        11    116       1.155
# 12        12    101       1.006
# 13        13     52       0.518
# 14        14     51       0.508
# 15        15     38       0.379
# 16        16     21       0.209
# 17        17     12       0.120
# 18        18     11       0.110
# 19        19      5       0.050
# 20        20      4       0.040
# 21        21      2       0.020
# 22        22      2       0.020
# 23        23      4       0.040
# 24        24      2       0.020
# 25        25      1       0.010
# 26        26      2       0.020
# 27        29      2       0.020
# 28        31      1       0.010
# 29        34      1       0.010

# %% [markdown]
# # Labeling

# %%
def resetEvaluation():
  # TODO Relabel
  # emotion_column = ["Evaluation1", "Evaluation2", "Evaluation3", "Evaluation4", "Evaluation5", "Evaluation6"]

  # for column in emotion_column:
  #   result[column] = None

  result["Emotion"] = None

def goLabeling():
  for session in sessions:
    emotion_path = iemocap + "/" + session + "/dialog/EmoEvaluation/"

    recordings = [file.name for file in os.scandir(emotion_path) if ".txt" in file.name]
    recordings.sort()
    
    for recording in recordings:
      with open(emotion_path + recording) as f:
        lines = f.readlines()
        tokenizedLines = [x.split() for x in lines if "Ses0" in x]

        for part in tokenizedLines:
          line_name = part[3]
          line_label = part[4]
          line_queries = line_name.split("_")
          
          line_part = line_queries[-1]
          line_queries.remove(line_part)

          line_name = "_".join(line_queries)

          search_query_name = ""
          search_query_part = line_queries[-1]
          search_result = result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"]
          search_count = search_result.shape[0]
          
          if search_count == 0:
            print("ERROR: No audio part found: ")
          elif search_count > 1:
            print("ERROR: Multiple audio found: ")
          else:
            result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"] = line_label

def getClassificationReport():
  max_duration = 7

  categorical_data = result.loc[
    (result["Duration"] < max_duration + 1) &
    (
      (result["Emotion"] == 'neu') |
      (result["Emotion"] == 'ang') |
      (result["Emotion"] == 'hap') |
      (result["Emotion"] == 'sad') 
    )
  ]
  
  categorical_plot = seaborn.countplot(x="Emotion", hue="Duration", data=categorical_data)
  categorical_plot.figure.set_size_inches(13,13)

  for p in categorical_plot.patches:
    height = p.get_height()
    categorical_plot.text(p.get_x() + p.get_width()/2., height + 3, '{:1.0f}'.format(height), ha="center") 

  return categorical_data

resetEvaluation()
goLabeling()
categorical_data = getClassificationReport()

# %% [markdown]
# # Selection and Splitting

# %%
def checkAndCreateDirectory(filename):
  if not os.path.exists(os.path.dirname(filename)):
    try:
        os.makedirs(os.path.dirname(filename))
    except OSError as exc: # Guard against race condition
        print(exc.errno)
        if exc.errno != errno.EEXIST:
            raise

def getMfccValue(audio_path, row, dataset_type):
  audio_file, sample_rate = librosa.load(audio_path)
  S = librosa.feature.melspectrogram(y=audio_file, sr=sample_rate)
    
  librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

  filename = "image/" + dataset_type + "/" + row["Emotion"] + "/" + row["Audio Name"] + "_" + row["Part"] + '.png'
  checkAndCreateDirectory(filename)

  plt.gca().set_axis_off()
  plt.savefig(filename, dpi=100, bbox_inches='tight',pad_inches=0)
  # plt.show()
  plt.clf()
  plt.close('all')

  return S

def getEncodedLabel(label):
  label_hot = [0, 0, 0, 0]
  
  if    (label == "neu"): label_hot = [1, 0, 0, 0]
  elif  (label == "ang"): label_hot = [0, 1, 0, 0]
  elif  (label == "hap"): label_hot = [0, 0, 1, 0]
  elif  (label == "sad"): label_hot = [0, 0, 0, 1]

  np.where(np.array(label_hot) == 1)[0][0]
  return np.array(label_hot)

def getAudioPath(row):
  audio_prefix = row["Audio Name"][:5]
  audio_session = "Error"

  if    (audio_prefix == 'Ses01'): audio_session = "Session1"
  elif  (audio_prefix == 'Ses02'): audio_session = "Session2"
  elif  (audio_prefix == 'Ses03'): audio_session = "Session3"
  elif  (audio_prefix == 'Ses04'): audio_session = "Session4"
  elif  (audio_prefix == 'Ses05'): audio_session = "Session5"

  audio_path = iemocap + '/' + audio_session + '/sentences/wav/' + row["Audio Name"] + '/' + row["Audio Name"] + '_' + row["Part"] + '.wav'
  return audio_path

def getVectorAudio(base_duration, durationed_data, dataset_type):
  X = [] # Data
  Y = [] # Label

  durationed_length = len(durationed_data)

  # Iterate every data
  for index, row in durationed_data.iterrows():
    print("Saving " + str(durationed_length) + " " + str(index), end=" | ")

    if durationed_length % 30 == 0: print("\n")
    durationed_length -= 1

    # Get Label
    label = row["Emotion"]
    label_hot = getEncodedLabel(label)

    # Get Mfcc
    audio_path = getAudioPath(row)
    mfcc = getMfccValue(audio_path, row, dataset_type)
    mfcc_length = mfcc.shape[1]

    mfcc_slice = 50 * base_duration

    for mfcc_partial in range(int(mfcc_length/mfcc_slice) + 1):
      start = mfcc_partial * mfcc_slice
      end = (mfcc_partial + 1) * mfcc_slice

      mfcc_partial_result = np.pad(mfcc, pad_width=((0,0), (0, (mfcc_slice - (mfcc_length % mfcc_slice)))), mode='constant')
      mfcc_partial_result = mfcc_partial_result[:,start:end]

      if (mfcc_partial_result.shape[1] != mfcc_slice) | (mfcc_partial_result.shape[0] != 128):
        print("ERROR Mfcc " + str(index) + str(row))
        print("ERROR Mfcc " + index + row)
        break
      
      X.append(mfcc_partial_result)
      Y.append(label_hot)

  return np.array(X), np.array(Y)

def testDuration():
  audio_file, sample_rate = librosa.load('/content/gdrive/My Drive/Public/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro04/Ses01F_impro04_M008.wav')
  duration = librosa.get_duration(y=audio_file, sr=sample_rate)
  print(duration)

  S = librosa.feature.mfcc(y=audio_file, sr=48000)
  print(S.shape)

def getEmotionSplitting(base_duration, max_duration):
  train_data    = pd.DataFrame()
  val_data      = pd.DataFrame()
  test_data     = pd.DataFrame()

  for iterate_index in range(base_duration, max_duration + 1):
    neutral_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'neu')
    ]

    angry_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'ang')
    ]

    sad_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'sad')
    ]

    happy_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'hap')
    ]
    
    print("Duration " + str(iterate_index))
    print("Neutral " + str(neutral_duration.shape[0]))
    print("Angry " + str(angry_duration.shape[0]))
    print("Sad " + str(sad_duration.shape[0]))
    print("Happy " + str(happy_duration.shape[0]))
    print()

    sample_lowest = min(neutral_duration.shape[0], angry_duration.shape[0], sad_duration.shape[0], happy_duration.shape[0])

    neutral_duration  = neutral_duration.sample(sample_lowest)
    angry_duration    = angry_duration.sample(sample_lowest)
    sad_duration      = sad_duration.sample(sample_lowest)
    happy_duration    = happy_duration.sample(sample_lowest)

    # Splitting # 0,6 : 0,8 : 1,0 (60%, 20%, 20%)
    data_training_percent   = int(0.6 * sample_lowest)
    data_validation_percent = int(0.8 * sample_lowest)

    train_data = train_data.append(neutral_duration [:data_training_percent])
    train_data = train_data.append(angry_duration   [:data_training_percent])
    train_data = train_data.append(sad_duration     [:data_training_percent])
    train_data = train_data.append(happy_duration   [:data_training_percent])

    val_data = val_data.append(neutral_duration   [data_training_percent:data_validation_percent])
    val_data = val_data.append(angry_duration     [data_training_percent:data_validation_percent])
    val_data = val_data.append(sad_duration       [data_training_percent:data_validation_percent])
    val_data = val_data.append(happy_duration     [data_training_percent:data_validation_percent])

    test_data = test_data.append(neutral_duration     [data_validation_percent:sample_lowest])
    test_data = test_data.append(angry_duration       [data_validation_percent:sample_lowest])
    test_data = test_data.append(sad_duration         [data_validation_percent:sample_lowest])
    test_data = test_data.append(happy_duration       [data_validation_percent:sample_lowest])

  return train_data.sample(frac=1), val_data.sample(frac=1), test_data.sample(frac=1)

def loadGenerator():
  train_image_generator = ImageDataGenerator()
  train_data = train_image_generator.flow_from_directory(
      directory="image/train/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )
    
  validation_image_generator = ImageDataGenerator()
  validation_data = validation_image_generator.flow_from_directory(
      directory="image/val/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )

  return train_data, validation_data

base_duration = 1
max_duration = 5

train_data, val_data, test_data = getEmotionSplitting(base_duration, max_duration)
# !rm -rf image

# In vector and save image
x_train, y_train  = getVectorAudio(base_duration, train_data, "train")
x_val, y_val      = getVectorAudio(base_duration, val_data, "val")
x_test, y_test    = getVectorAudio(base_duration, test_data, "test")

# In generator
train_generator, validation_generator = loadGenerator()
# Out:
# Duration 1
# Neutral 374
# Angry 153
# Sad 110
# Happy 86
#
# Duration 2
# Neutral 419
# Angry 266
# Sad 221
# Happy 156
#
# Duration 3
# Neutral 285
# Angry 204
# Sad 181
# Happy 110
#
# Duration 4
# Neutral 198
# Angry 132
# Sad 127
# Happy 58
#
# Duration 5
# Neutral 124
# Angry 98
# Sad 97
# Happy 43
#
#
# Saving 89 1642 | Saving 88 5547 | Saving 87 8597 | Saving 86 8992 | Saving 85 8198 | Saving 84 598 | Saving 83 5069 | Saving 82 9266 | Saving 81 8033 | Saving 80 7282 | Saving 79 4683 | Saving 78 4154 | Saving 77 8874 | Saving 76 5739 | Saving 75 4868 | Saving 74 4452 | Saving 73 1764 | Saving 72 9827 | Saving 71 3438 | Saving 70 9696 | Saving 69 5164 | Saving 68 516 | Saving 67 2048 | Saving 66 2211 | Saving 65 8123 | Saving 64 8991 | Saving 63 9198 | Saving 62 1162 | Saving 61 1662 | Saving 60 3154 |
#
# Saving 59 3255 | Saving 58 3991 | Saving 57 2320 | Saving 56 5345 | Saving 55 1149 | Saving 54 6373 | Saving 53 4924 | Saving 52 7141 | Saving 51 3267 | Saving 50 5985 | Saving 49 4190 | Saving 48 4011 | Saving 47 4805 | Saving 46 5858 | Saving 45 4878 | Saving 44 8204 | Saving 43 8640 | Saving 42 474 | Saving 41 1255 | Saving 40 9682 | Saving 39 6099 | Saving 38 3912 | Saving 37 5597 | Saving 36 8838 | Saving 35 5071 | Saving 34 2602 | Saving 33 8453 | Saving 32 8662 | Saving 31 3915 | Saving 30 250 |
#
# Saving 29 6283 | Saving 28 3466 | Saving 27 5996 | Saving 26 8337 | Saving 25 3698 | Saving 24 5197 | Saving 23 8578 | Saving 22 404 | Saving 21 118 | Saving 20 5536 | Saving 19 8374 | Saving 18 6242 | Saving 17 2566 | Saving 16 9661 | Saving 15 6376 | Saving 14 1798 | Saving 13 5398 | Saving 12 8544 | Saving 11 9110 | Saving 10 6950 | Saving 9 1755 | Saving 8 4667 | Saving 7 527 | Saving 6 3947 | Saving 5 6386 | Saving 4 3882 | Saving 3 9599 | Saving 2 9303 | Saving 1 5008 | Found 1076 images belonging to 4 classes.
# Found 364 images belonging to 4 classes.

# %%
def plot_result(model, history):
  # list all data in history
  print(history.history.keys())

  # summarize history for accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

def save_model(model, filename):
  checkAndCreateDirectory("/content/model/test.txt")
  model.summary()

  plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

  with open("/content/model/" + filename + ".json", "w") as json_file:
    model_json = model.to_json()
    json_file.write(model_json)

def buildModel():
  model_input = Input(shape=(256, 256, 3))

  model = Conv2D(64, kernel_size=8, strides=2)(model_input)
  model = Conv2D(64, kernel_size=8, strides=2)(model)
  model = Conv2D(64, kernel_size=8, strides=2)(model)

  model = Conv2D(128, kernel_size=4, strides=1)(model)
  model = Conv2D(128, kernel_size=4, strides=1)(model)
  model = Conv2D(128, kernel_size=4, strides=1)(model)

  model = Flatten()(model)

  model = Dense(512)(model)

  model = Dense(4, activation='softmax')(model)
  
#   model = Sequential()
#   eff = tf.keras.applications.EfficientNetB0(
#     weights=None,
#     classes=4,
#     input_shape=(128,50,1)
#   )

#   model.add(eff)

  # Model compile
  model = Model(inputs=[model_input], outputs=[model])
  model.compile(optimizer="adam", loss=tf.keras.losses.CategoricalCrossentropy(), metrics=["accuracy"])
  
  # Visualize & Save Model
  save_model(model, "struct_model")

  # Checkpoint
  basepath = '/content/model/weight_model'
  best_checkpoint = ModelCheckpoint(basepath +'_{epoch:02d}_{loss:.2f}_{accuracy:.2f}_{val_loss:.2f}_{val_accuracy:.2f}.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
  callback_list = [best_checkpoint]

#   history = model.fit(
#     x_train, 
#     y_train, 
#     validation_data=(x_val, y_val),
#     batch_size=1, 
#     epochs=100,
#     callbacks=callback_list
#   )

  history = model.fit_generator(
    generator=train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=callback_list
  )

  return model, history

# !rm -rf model
model, history = buildModel()
plot_result(model, history)
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 125, 125, 64)      12352
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 59, 59, 64)        262208
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 26, 26, 64)        262208
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 23, 23, 128)       131200
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 20, 20, 128)       262272
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 17, 17, 128)       262272
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 36992)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               18940416
# _________________________________________________________________
# dense_19 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 20,134,980
# Trainable params: 20,134,980
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 1076/1076 [==============================] - 15s 13ms/step - loss: 241744.8127 - accuracy: 0.2792 - val_loss: 75.5162 - val_accuracy: 0.3764
#
# Epoch 00001: val_accuracy improved from -inf to 0.37637, saving model to /content/model/weight_model_01_58231.07_0.33_75.52_0.38.hdf5
# Epoch 2/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 67.6992 - accuracy: 0.4725 - val_loss: 74.6566 - val_accuracy: 0.3709
#
# Epoch 00002: val_accuracy did not improve from 0.37637
# Epoch 3/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 33.8159 - accuracy: 0.6051 - val_loss: 85.5472 - val_accuracy: 0.3187
#
# Epoch 00003: val_accuracy did not improve from 0.37637
# Epoch 4/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 23.9188 - accuracy: 0.6813 - val_loss: 64.6857 - val_accuracy: 0.4203
#
# Epoch 00004: val_accuracy improved from 0.37637 to 0.42033, saving model to /content/model/weight_model_04_27.68_0.66_64.69_0.42.hdf5
# Epoch 5/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 189730265.4606 - accuracy: 0.6484 - val_loss: 51751268.0000 - val_accuracy: 0.2363
#
# Epoch 00005: val_accuracy did not improve from 0.42033
# Epoch 6/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 14461843.0655 - accuracy: 0.2658 - val_loss: 854043.6250 - val_accuracy: 0.2582
#
# Epoch 00006: val_accuracy did not improve from 0.42033
# Epoch 7/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 622098.8042 - accuracy: 0.2876 - val_loss: 786902.0625 - val_accuracy: 0.2527
#
# Epoch 00007: val_accuracy did not improve from 0.42033
# Epoch 8/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 634696.5113 - accuracy: 0.2875 - val_loss: 680186.9375 - val_accuracy: 0.2885
#
# Epoch 00008: val_accuracy did not improve from 0.42033
# Epoch 9/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 577417.3962 - accuracy: 0.2998 - val_loss: 594531.9375 - val_accuracy: 0.2775
#
# Epoch 00009: val_accuracy did not improve from 0.42033
# Epoch 10/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 711538.6895 - accuracy: 0.3131 - val_loss: 274950.7812 - val_accuracy: 0.3324
#
# Epoch 00010: val_accuracy did not improve from 0.42033
# Epoch 11/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 470430.9396 - accuracy: 0.3326 - val_loss: 100804.9453 - val_accuracy: 0.3297
#
# Epoch 00011: val_accuracy did not improve from 0.42033
# Epoch 12/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 253660.8475 - accuracy: 0.2937 - val_loss: 99849.6250 - val_accuracy: 0.3626
#
# Epoch 00012: val_accuracy did not improve from 0.42033
# Epoch 13/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 93693.2054 - accuracy: 0.3322 - val_loss: 18606.8477 - val_accuracy: 0.4423
#
# Epoch 00013: val_accuracy improved from 0.42033 to 0.44231, saving model to /content/model/weight_model_13_71215.62_0.35_18606.85_0.44.hdf5
# Epoch 14/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1917048992.9772 - accuracy: 0.3087 - val_loss: 177366976.0000 - val_accuracy: 0.2582
#
# Epoch 00014: val_accuracy did not improve from 0.44231
# Epoch 15/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 40857342.0947 - accuracy: 0.2835 - val_loss: 10673945.0000 - val_accuracy: 0.2857
#
# Epoch 00015: val_accuracy did not improve from 0.44231
# Epoch 16/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 9438256.8542 - accuracy: 0.3008 - val_loss: 20656776.0000 - val_accuracy: 0.2720
#
# Epoch 00016: val_accuracy did not improve from 0.44231
# Epoch 17/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 10456241.6212 - accuracy: 0.2915 - val_loss: 4723168.5000 - val_accuracy: 0.2692
#
# Epoch 00017: val_accuracy did not improve from 0.44231
# Epoch 18/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 8217309.1182 - accuracy: 0.3647 - val_loss: 1580487.0000 - val_accuracy: 0.4121
#
# Epoch 00018: val_accuracy did not improve from 0.44231
# Epoch 19/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2672565.7590 - accuracy: 0.3230 - val_loss: 1082712.8750 - val_accuracy: 0.3242
#
# Epoch 00019: val_accuracy did not improve from 0.44231
# Epoch 20/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1539246.3611 - accuracy: 0.3659 - val_loss: 620563.3750 - val_accuracy: 0.3352
#
# Epoch 00020: val_accuracy did not improve from 0.44231
# Epoch 21/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1699112.4336 - accuracy: 0.3368 - val_loss: 643904.2500 - val_accuracy: 0.3132
#
# Epoch 00021: val_accuracy did not improve from 0.44231
# Epoch 22/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1355398.2861 - accuracy: 0.3293 - val_loss: 386436.5312 - val_accuracy: 0.3791
#
# Epoch 00022: val_accuracy did not improve from 0.44231
# Epoch 23/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1476541978.4518 - accuracy: 0.3155 - val_loss: 39261668.0000 - val_accuracy: 0.2582
#
# Epoch 00023: val_accuracy did not improve from 0.44231
# Epoch 24/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 23070965.1811 - accuracy: 0.2696 - val_loss: 4013018.7500 - val_accuracy: 0.2775
#
# Epoch 00024: val_accuracy did not improve from 0.44231
# Epoch 25/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 5191006.8981 - accuracy: 0.2945 - val_loss: 2582441.0000 - val_accuracy: 0.2885
#
# Epoch 00025: val_accuracy did not improve from 0.44231
# Epoch 26/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2109075.2631 - accuracy: 0.3481 - val_loss: 1218693.2500 - val_accuracy: 0.3077
#
# Epoch 00026: val_accuracy did not improve from 0.44231
# Epoch 27/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1850475.6869 - accuracy: 0.3158 - val_loss: 1355826.5000 - val_accuracy: 0.2857
#
# Epoch 00027: val_accuracy did not improve from 0.44231
# Epoch 28/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1527025.9351 - accuracy: 0.3736 - val_loss: 1886910.6250 - val_accuracy: 0.3324
#
# Epoch 00028: val_accuracy did not improve from 0.44231
# Epoch 29/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1109382.9296 - accuracy: 0.3458 - val_loss: 235776.8125 - val_accuracy: 0.3626
#
# Epoch 00029: val_accuracy did not improve from 0.44231
# Epoch 30/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 507997.5725 - accuracy: 0.3285 - val_loss: 1078634.6250 - val_accuracy: 0.2912
#
# Epoch 00030: val_accuracy did not improve from 0.44231
# Epoch 31/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 391432.7901 - accuracy: 0.3607 - val_loss: 260332.9375 - val_accuracy: 0.3407
#
# Epoch 00031: val_accuracy did not improve from 0.44231
# Epoch 32/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 227753.1694 - accuracy: 0.3581 - val_loss: 315831.9375 - val_accuracy: 0.3956
#
# Epoch 00032: val_accuracy did not improve from 0.44231
# Epoch 33/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 5800888220.9046 - accuracy: 0.3274 - val_loss: 8000915.0000 - val_accuracy: 0.3324
#
# Epoch 00033: val_accuracy did not improve from 0.44231
# Epoch 34/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 9231127.4067 - accuracy: 0.3248 - val_loss: 6351904.5000 - val_accuracy: 0.2967
#
# Epoch 00034: val_accuracy did not improve from 0.44231
# Epoch 35/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4110850.9726 - accuracy: 0.3004 - val_loss: 2173630.2500 - val_accuracy: 0.2995
#
# Epoch 00035: val_accuracy did not improve from 0.44231
# Epoch 36/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2331267.8106 - accuracy: 0.3264 - val_loss: 2861980.2500 - val_accuracy: 0.2253
#
# Epoch 00036: val_accuracy did not improve from 0.44231
# Epoch 37/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2475496.2908 - accuracy: 0.3424 - val_loss: 1921030.1250 - val_accuracy: 0.3159
#
# Epoch 00037: val_accuracy did not improve from 0.44231
# Epoch 38/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1885346.0283 - accuracy: 0.3245 - val_loss: 4388669.0000 - val_accuracy: 0.2445
#
# Epoch 00038: val_accuracy did not improve from 0.44231
# Epoch 39/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 998008.8824 - accuracy: 0.3312 - val_loss: 829871.8125 - val_accuracy: 0.3544
#
# Epoch 00039: val_accuracy did not improve from 0.44231
# Epoch 40/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 877957.3821 - accuracy: 0.3260 - val_loss: 139552.1094 - val_accuracy: 0.4093
#
# Epoch 00040: val_accuracy did not improve from 0.44231
# Epoch 41/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 287895.6179 - accuracy: 0.3765 - val_loss: 98286.8125 - val_accuracy: 0.4121
#
# Epoch 00041: val_accuracy did not improve from 0.44231
# Epoch 42/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 415737.4444 - accuracy: 0.3436 - val_loss: 57353.8086 - val_accuracy: 0.3242
#
# Epoch 00042: val_accuracy did not improve from 0.44231
# Epoch 43/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 59460.8578 - accuracy: 0.4210 - val_loss: 922839.6250 - val_accuracy: 0.3132
#
# Epoch 00043: val_accuracy did not improve from 0.44231
# Epoch 44/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 19968120721.3124 - accuracy: 0.2461 - val_loss: 7284212.5000 - val_accuracy: 0.3242
#
# Epoch 00044: val_accuracy did not improve from 0.44231
# Epoch 45/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 7447574.4285 - accuracy: 0.2789 - val_loss: 3951601.2500 - val_accuracy: 0.2802
#
# Epoch 00045: val_accuracy did not improve from 0.44231
# Epoch 46/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 5054392.8893 - accuracy: 0.3484 - val_loss: 10379306.0000 - val_accuracy: 0.2912
#
# Epoch 00046: val_accuracy did not improve from 0.44231
# Epoch 47/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4088683.7447 - accuracy: 0.3425 - val_loss: 2409541.0000 - val_accuracy: 0.3819
#
# Epoch 00047: val_accuracy did not improve from 0.44231
# Epoch 48/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4074802.6007 - accuracy: 0.3013 - val_loss: 4201274.5000 - val_accuracy: 0.3901
#
# Epoch 00048: val_accuracy did not improve from 0.44231
# Epoch 49/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 10336972.6263 - accuracy: 0.2918 - val_loss: 380165.2812 - val_accuracy: 0.3434
#
# Epoch 00049: val_accuracy did not improve from 0.44231
# Epoch 50/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 654991.4997 - accuracy: 0.3873 - val_loss: 2459455.7500 - val_accuracy: 0.2802
#
# Epoch 00050: val_accuracy did not improve from 0.44231
# Epoch 51/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 988639984.2539 - accuracy: 0.3730 - val_loss: 45267296256.0000 - val_accuracy: 0.2500
#
# Epoch 00051: val_accuracy did not improve from 0.44231
# Epoch 52/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 3990294784.7131 - accuracy: 0.2180 - val_loss: 13719314.0000 - val_accuracy: 0.2967
#
# Epoch 00052: val_accuracy did not improve from 0.44231
# Epoch 53/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 15234431.2340 - accuracy: 0.2697 - val_loss: 5806195.0000 - val_accuracy: 0.3434
#
# Epoch 00053: val_accuracy did not improve from 0.44231
# Epoch 54/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 9282191.7126 - accuracy: 0.3352 - val_loss: 7734331.0000 - val_accuracy: 0.2802
#
# Epoch 00054: val_accuracy did not improve from 0.44231
# Epoch 55/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4918878.4937 - accuracy: 0.3277 - val_loss: 2944906.2500 - val_accuracy: 0.2995
#
# Epoch 00055: val_accuracy did not improve from 0.44231
# Epoch 56/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4014490.2203 - accuracy: 0.3329 - val_loss: 6605090.0000 - val_accuracy: 0.2418
#
# Epoch 00056: val_accuracy did not improve from 0.44231
# Epoch 57/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4608188.7333 - accuracy: 0.3356 - val_loss: 9907922.0000 - val_accuracy: 0.2500
#
# Epoch 00057: val_accuracy did not improve from 0.44231
# Epoch 58/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 6087126.5989 - accuracy: 0.2882 - val_loss: 650054.1875 - val_accuracy: 0.3709
#
# Epoch 00058: val_accuracy did not improve from 0.44231
# Epoch 59/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 3109009.7131 - accuracy: 0.3184 - val_loss: 2507650.0000 - val_accuracy: 0.2582
#
# Epoch 00059: val_accuracy did not improve from 0.44231
# Epoch 60/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 783129.5947 - accuracy: 0.3026 - val_loss: 140360.7812 - val_accuracy: 0.2857
#
# Epoch 00060: val_accuracy did not improve from 0.44231
# Epoch 61/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 170368.2224 - accuracy: 0.3540 - val_loss: 182477.7344 - val_accuracy: 0.3324
#
# Epoch 00061: val_accuracy did not improve from 0.44231
# Epoch 62/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 218291.9643 - accuracy: 0.3237 - val_loss: 155397.6406 - val_accuracy: 0.2665
#
# Epoch 00062: val_accuracy did not improve from 0.44231
# Epoch 63/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 203015.9069 - accuracy: 0.3372 - val_loss: 2404266.2500 - val_accuracy: 0.2500
#
# Epoch 00063: val_accuracy did not improve from 0.44231
# Epoch 64/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 16434235915.6609 - accuracy: 0.2728 - val_loss: 6345808.0000 - val_accuracy: 0.3846
#
# Epoch 00064: val_accuracy did not improve from 0.44231
# Epoch 65/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 7663321.3064 - accuracy: 0.3090 - val_loss: 8406531.0000 - val_accuracy: 0.3516
#
# Epoch 00065: val_accuracy did not improve from 0.44231
# Epoch 66/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4367724.9299 - accuracy: 0.3280 - val_loss: 2439842.7500 - val_accuracy: 0.3434
#
# Epoch 00066: val_accuracy did not improve from 0.44231
# Epoch 67/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2965846.1756 - accuracy: 0.3577 - val_loss: 3189142.7500 - val_accuracy: 0.3434
#
# Epoch 00067: val_accuracy did not improve from 0.44231
# Epoch 68/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1876949.3653 - accuracy: 0.3239 - val_loss: 900069.1250 - val_accuracy: 0.3187
#
# Epoch 00068: val_accuracy did not improve from 0.44231
# Epoch 69/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1679391.4773 - accuracy: 0.3301 - val_loss: 1683443.0000 - val_accuracy: 0.2857
#
# Epoch 00069: val_accuracy did not improve from 0.44231
# Epoch 70/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1143880.9480 - accuracy: 0.3464 - val_loss: 1009277.3750 - val_accuracy: 0.2775
#
# Epoch 00070: val_accuracy did not improve from 0.44231
# Epoch 71/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 597705.8130 - accuracy: 0.3827 - val_loss: 445306.7812 - val_accuracy: 0.3022
#
# Epoch 00071: val_accuracy did not improve from 0.44231
# Epoch 72/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 397013124.8199 - accuracy: 0.4166 - val_loss: 7483658.0000 - val_accuracy: 0.3049
#
# Epoch 00072: val_accuracy did not improve from 0.44231
# Epoch 73/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 5204285.4986 - accuracy: 0.3465 - val_loss: 1144594.8750 - val_accuracy: 0.4368
#
# Epoch 00073: val_accuracy did not improve from 0.44231
# Epoch 74/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1713313.4035 - accuracy: 0.3767 - val_loss: 1331247.5000 - val_accuracy: 0.3626
#
# Epoch 00074: val_accuracy did not improve from 0.44231
# Epoch 75/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1081319.4429 - accuracy: 0.3948 - val_loss: 3260862.2500 - val_accuracy: 0.2500
#
# Epoch 00075: val_accuracy did not improve from 0.44231
# Epoch 76/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1650053.5030 - accuracy: 0.3670 - val_loss: 378474.9375 - val_accuracy: 0.3544
#
# Epoch 00076: val_accuracy did not improve from 0.44231
# Epoch 77/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 775464.3089 - accuracy: 0.3951 - val_loss: 250062.0625 - val_accuracy: 0.4038
#
# Epoch 00077: val_accuracy did not improve from 0.44231
# Epoch 78/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 548957.6780 - accuracy: 0.3723 - val_loss: 132786.4062 - val_accuracy: 0.4148
#
# Epoch 00078: val_accuracy did not improve from 0.44231
# Epoch 79/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 5053734110.6322 - accuracy: 0.3349 - val_loss: 34000728.0000 - val_accuracy: 0.2637
#
# Epoch 00079: val_accuracy did not improve from 0.44231
# Epoch 80/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 28107157.5822 - accuracy: 0.3080 - val_loss: 23639070.0000 - val_accuracy: 0.3049
#
# Epoch 00080: val_accuracy did not improve from 0.44231
# Epoch 81/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 10481952.3157 - accuracy: 0.3361 - val_loss: 6608875.5000 - val_accuracy: 0.3214
#
# Epoch 00081: val_accuracy did not improve from 0.44231
# Epoch 82/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4337195.3658 - accuracy: 0.3424 - val_loss: 15396697.0000 - val_accuracy: 0.2610
#
# Epoch 00082: val_accuracy did not improve from 0.44231
# Epoch 83/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 5828138.6448 - accuracy: 0.3361 - val_loss: 1565697.6250 - val_accuracy: 0.3901
#
# Epoch 00083: val_accuracy did not improve from 0.44231
# Epoch 84/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 5732047.9542 - accuracy: 0.3354 - val_loss: 1682708.3750 - val_accuracy: 0.3599
#
# Epoch 00084: val_accuracy did not improve from 0.44231
# Epoch 85/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 3235037.8641 - accuracy: 0.3100 - val_loss: 5160259.0000 - val_accuracy: 0.2582
#
# Epoch 00085: val_accuracy did not improve from 0.44231
# Epoch 86/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2119382.3470 - accuracy: 0.3054 - val_loss: 2424424.5000 - val_accuracy: 0.2473
#
# Epoch 00086: val_accuracy did not improve from 0.44231
# Epoch 87/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1000073.2384 - accuracy: 0.3740 - val_loss: 223265.7969 - val_accuracy: 0.4203
#
# Epoch 00087: val_accuracy did not improve from 0.44231
# Epoch 88/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 344378.4778 - accuracy: 0.3958 - val_loss: 230547.0781 - val_accuracy: 0.3654
#
# Epoch 00088: val_accuracy did not improve from 0.44231
# Epoch 89/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 3446068706.8094 - accuracy: 0.3366 - val_loss: 22724682.0000 - val_accuracy: 0.2665
#
# Epoch 00089: val_accuracy did not improve from 0.44231
# Epoch 90/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 14698547.5617 - accuracy: 0.2818 - val_loss: 5545308.0000 - val_accuracy: 0.3187
#
# Epoch 00090: val_accuracy did not improve from 0.44231
# Epoch 91/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 3839575.1893 - accuracy: 0.2977 - val_loss: 2382211.0000 - val_accuracy: 0.3269
#
# Epoch 00091: val_accuracy did not improve from 0.44231
# Epoch 92/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2125282.9143 - accuracy: 0.3460 - val_loss: 2526390.7500 - val_accuracy: 0.4093
#
# Epoch 00092: val_accuracy did not improve from 0.44231
# Epoch 93/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2149022.0509 - accuracy: 0.3370 - val_loss: 655255.3750 - val_accuracy: 0.4148
#
# Epoch 00093: val_accuracy did not improve from 0.44231
# Epoch 94/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2183626.8527 - accuracy: 0.3501 - val_loss: 1525317.5000 - val_accuracy: 0.3269
#
# Epoch 00094: val_accuracy did not improve from 0.44231
# Epoch 95/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 1688270.9416 - accuracy: 0.3475 - val_loss: 939099.6250 - val_accuracy: 0.3187
#
# Epoch 00095: val_accuracy did not improve from 0.44231
# Epoch 96/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 2395119.7289 - accuracy: 0.3442 - val_loss: 356441.6250 - val_accuracy: 0.3791
#
# Epoch 00096: val_accuracy did not improve from 0.44231
# Epoch 97/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 567293.0915 - accuracy: 0.3845 - val_loss: 286351.7812 - val_accuracy: 0.3407
#
# Epoch 00097: val_accuracy did not improve from 0.44231
# Epoch 98/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 6282738059.5802 - accuracy: 0.3017 - val_loss: 13296364.0000 - val_accuracy: 0.2967
#
# Epoch 00098: val_accuracy did not improve from 0.44231
# Epoch 99/100
# 1076/1076 [==============================] - 15s 13ms/step - loss: 8542003.3431 - accuracy: 0.3263 - val_loss: 5795839.5000 - val_accuracy: 0.3407
#
# Epoch 00099: val_accuracy did not improve from 0.44231
# Epoch 100/100
# 1076/1076 [==============================] - 14s 13ms/step - loss: 4122079.3828 - accuracy: 0.3769 - val_loss: 2304660.0000 - val_accuracy: 0.3544
#
# Epoch 00100: val_accuracy did not improve from 0.44231
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
def load_model(struct, weight):
  json_file = open("model/" + struct + ".json", "r")
  loaded_model_json = json_file.read()
  json_file.close()

  loaded_model = model_from_json(loaded_model_json)
  loaded_model.load_weights("model/" + weight + ".hdf5")
  loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  return loaded_model

lastCheckpoint = sorted(Path("/content/model").iterdir(), key=os.path.getmtime)[-1].stem
print("Model is " + lastCheckpoint)

loaded_model = load_model("struct_model", lastCheckpoint)
# Out:
# Model is weight_model_713_18886.62_0.61_495903.19_0.68

# %% [markdown]
# # Testing

# %%
# train_loss, train_accuracy = loaded_model.evaluate(x_train, y_train)
# val_loss, val_accuracy = loaded_model.evaluate(x_val, y_val)
# test_loss, test_accuracy = loaded_model.evaluate(x_test, y_test)

# print(
#     ""
#     "\n"
#     "Train Loss: " + str(train_loss) + "\n"
#     "Train Accuracy: " + str(train_accuracy * 100) + "%\n"
#     "\n"
#     "Validation Loss: " + str(val_loss) + "\n"
#     "Validation Accuracy: " + str(val_accuracy * 100) + "%\n"
#     "\n"
#     "Test Loss: " + str(test_loss) + "\n"
#     "Test Accuracy: " + str(test_accuracy * 100) + "%"
#     "")
# Out:
# 13/13 [==============================] - 0s 19ms/step - loss: 4.8931 - accuracy: 0.3025
# 5/5 [==============================] - 0s 14ms/step - loss: 9.1233 - accuracy: 0.2879
# 5/5 [==============================] - 0s 13ms/step - loss: 3.7129 - accuracy: 0.2929
#
# Train Loss: 4.893118381500244
# Train Accuracy: 30.250000953674316%
#
# Validation Loss: 9.123268127441406
# Validation Accuracy: 28.787878155708313%
#
# Test Loss: 3.712925434112549
# Test Accuracy: 29.285714030265808%

# %%
test_generator = ImageDataGenerator()
test_data = test_generator.flow_from_directory(
    directory="image/test/",
    batch_size=1,
    class_mode="categorical",
    shuffle=True,
    target_size=(256, 256)
)

loss, accuracy = model.evaluate_generator(generator=test_data)
print(
    ""
    "Prediction Loss: %2d\n"
    "Prediction Accuracy: %2d%%"
    ""
    % (loss, accuracy * 100))

# %% [markdown]
# # Analysis

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

y_decoded = []
for pred in y_test:
  decoded = np.where(pred == 1)[0][0]
  y_decoded.append(decoded)

print('Confusion Matrix')
print(target_names)
print(confusion_matrix(y_decoded, y_pred))
print(x_test.shape)

print('\n\nClassification Report')
print(classification_report(y_decoded, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# ['neu', 'ang', 'hap', 'sad']
# [[ 3  2  7  3]
#  [ 2  6  6  3]
#  [ 7  3  5  3]
#  [ 3  0  4 10]]
# (67, 128, 50)
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#          neu       0.20      0.20      0.20        15
#          ang       0.55      0.35      0.43        17
#          hap       0.23      0.28      0.25        18
#          sad       0.53      0.59      0.56        17
#
#     accuracy                           0.36        67
#    macro avg       0.37      0.35      0.36        67
# weighted avg       0.38      0.36      0.36        67

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_data.classes, y_pred))

print('\n\nClassification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
