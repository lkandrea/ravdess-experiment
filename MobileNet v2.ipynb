# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import matplotlib.pylab as plt
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

# %%
import pandas as pd

# Increase precision of presented data for better side-by-side comparison
pd.set_option("display.precision", 8)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data_root='/content/drive/My Drive/Public/mammografy'

# %%
IMAGE_SHAPE = (224, 224)
TRAINING_DATA_DIR = str(data_root)

datagen_kwargs = dict(
    rescale=1./255, 
    validation_split=.25
)

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**datagen_kwargs)
train_generator = train_datagen.flow_from_directory(
    TRAINING_DATA_DIR, 
    subset="training", 
    shuffle=True,
    batch_size=1,
    target_size=IMAGE_SHAPE
)

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    TRAINING_DATA_DIR, 
    subset="validation", 
    shuffle=True,
    batch_size=1,
    target_size=IMAGE_SHAPE
)

model = tf.keras.Sequential([
  hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4", 
                 output_shape=[1280],
                 trainable=False),
  tf.keras.layers.Dense(train_generator.num_classes, activation='relu')
])

model.build([None, 224, 224, 3])
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(),loss='categorical_crossentropy',metrics=['acc'])

steps_per_epoch = np.ceil(train_generator.samples/train_generator.batch_size)
val_steps_per_epoch = np.ceil(valid_generator.samples/valid_generator.batch_size)

hist = model.fit(
    train_generator, 
    epochs=20,
    verbose=1,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=val_steps_per_epoch
).history
# Out:
# Found 156 images belonging to 2 classes.
# Found 52 images belonging to 2 classes.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_3 (KerasLayer)   multiple                  2257984
# _________________________________________________________________
# dense_3 (Dense)              multiple                  2562
# =================================================================
# Total params: 2,260,546
# Trainable params: 2,562
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Epoch 1/20
# 156/156 [==============================] - 2s 14ms/step - loss: 7.9873 - acc: 0.4936 - val_loss: 8.0591 - val_acc: 0.5000
# Epoch 2/20
# 156/156 [==============================] - 2s 11ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.3690 - val_acc: 0.4808
# Epoch 3/20
# 156/156 [==============================] - 2s 13ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 4/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.3690 - val_acc: 0.4808
# Epoch 5/20
# 156/156 [==============================] - 2s 13ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 6/20
# 156/156 [==============================] - 2s 13ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 7/20
# 156/156 [==============================] - 2s 11ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 8/20
# 156/156 [==============================] - 2s 13ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0591 - val_acc: 0.5000
# Epoch 9/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 10/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 11/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.6790 - val_acc: 0.4615
# Epoch 12/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.3690 - val_acc: 0.4808
# Epoch 13/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.1292 - val_acc: 0.5577
# Epoch 14/20
# 156/156 [==============================] - 2s 13ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 9.6089 - val_acc: 0.4038
# Epoch 15/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.4391 - val_acc: 0.5385
# Epoch 16/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 17/20
# 156/156 [==============================] - 2s 13ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0591 - val_acc: 0.5000
# Epoch 18/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.7491 - val_acc: 0.5192
# Epoch 19/20
# 156/156 [==============================] - 2s 13ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0591 - val_acc: 0.5000
# Epoch 20/20
# 156/156 [==============================] - 2s 12ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 6.8192 - val_acc: 0.5769

# %%
final_loss, final_accuracy = model.evaluate(valid_generator, steps = val_steps_per_epoch)
print("Final loss: {:.2f}".format(final_loss))
print("Final accuracy: {:.2f}%".format(final_accuracy * 100))
# Out:
# 52/52 [==============================] - 0s 9ms/step - loss: 1.2766 - acc: 0.4231
# Final loss: 1.28
# Final accuracy: 42.31%
