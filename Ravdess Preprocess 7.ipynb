# %% [markdown]
# # Prepare Data

# %%
from google.colab import files
from google.colab import drive

from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input, Softmax
from keras.engine.saving import model_from_json
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils.vis_utils import plot_model
from keras_preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from pathlib import Path

import os
import sys

import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

import librosa
import librosa.display

import tensorflow as tf

# %%
drive.mount('/content/gdrive', force_remount=True)
iemocap = "gdrive/My Drive/Public/IEMOCAP_full_release"

print("GPU Name: ", tf.test.gpu_device_name())
print("Num GPUs Available: ", tf.config.experimental.list_physical_devices('GPU'))
# Out:
# Mounted at /content/gdrive
# GPU Name:  /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# # Convert into CSV

# %%
sessions = ["Session1", "Session2", "Session3", "Session4", "Session5"]

def convertSession(session_name):
  session_file = iemocap + "/Duration/Processed/" + session_name + ".txt"
  tokenized_lines = []

  with open(session_file) as f:
    lines = f.readlines()
    tokenizedLines = [x.split() for x in lines]

  session_csv = iemocap + "/Duration/Processed/" + session_name + ".csv"
  with open(session_csv, "w") as csv:
    audio_name = ''

    for line in tokenizedLines:
      if line[0] == "Recording":
        audio_name = line[1]
      else:
        csv.write(audio_name + ";" + line[0] + ";" + line[1] + "\n")

def convertRawToCsv():
  for session in sessions:
    convertSession(session)

# convertRawToCsv()

# %% [markdown]
# # Convert into data frame

# %%
def getSessionData(session_name):
  df = pd.read_csv(iemocap + "/Duration/Processed/" + session_name + ".csv", delimiter=";", header=None)
  df.columns = ["Audio Name", "Part", "Duration"]
  print(session_name + " count: " + str(len(df.index)))

  return df

def getDataFrame():
  result = pd.DataFrame()

  for session in sessions:
    df = getSessionData(session)
    result = result.append(df, ignore_index=True)

  return result

result = getDataFrame()
result["Duration"] = result["Duration"].apply(np.floor).astype(int)
result
# Out:
# Session1 count: 1819
# Session2 count: 1811
# Session3 count: 2136
# Session4 count: 2103
# Session5 count: 2170
#               Audio Name  Part  Duration
# 0         Ses01F_impro01  F000         1
# 1         Ses01F_impro01  F001         1
# 2         Ses01F_impro01  F002         3
# 3         Ses01F_impro01  F003         1
# 4         Ses01F_impro01  F004         3
# ...                  ...   ...       ...
# 10034  Ses05M_script03_2  M041         8
# 10035  Ses05M_script03_2  M042         1
# 10036  Ses05M_script03_2  M043         2
# 10037  Ses05M_script03_2  M044         4
# 10038  Ses05M_script03_2  M045         6
#
# [10039 rows x 3 columns]

# %% [markdown]
# # Plot

# %%
plot = seaborn.countplot(x='Duration', data=result)
plot.figure.set_size_inches(13,13)

for p in plot.patches:
  height = p.get_height()
  plot.text(p.get_x() + p.get_width()/2., height + 10, '{:1.0f}'.format(height), ha="center")

# %%
print("Original data: " + str(result.count()))

count_data = result.value_counts(subset=['Duration'], sort=False).values
count_normalize = result.value_counts(subset=['Duration'], sort=False, normalize=True).values
duration = sorted(result.Duration.unique())

count_df = pd.DataFrame({"Duration": duration, "Count": count_data, "Percentage": count_normalize})
count_df.Percentage = (count_df.Percentage * 100).round(3)
count_df
# Out:
# Original data: Audio Name     10039
# Part           10039
# Duration       10039
# Evaluation1        0
# Evaluation2        0
# Evaluation3        0
# Evaluation4        0
# Evaluation5        0
# Evaluation6        0
# Emotion        10039
# dtype: int64
#     Duration  Count  Percentage
# 0          0     50       0.498
# 1          1   1650      16.436
# 2          2   2341      23.319
# 3          3   1717      17.103
# 4          4   1148      11.435
# 5          5    828       8.248
# 6          6    682       6.794
# 7          7    449       4.473
# 8          8    322       3.207
# 9          9    249       2.480
# 10        10    175       1.743
# 11        11    116       1.155
# 12        12    101       1.006
# 13        13     52       0.518
# 14        14     51       0.508
# 15        15     38       0.379
# 16        16     21       0.209
# 17        17     12       0.120
# 18        18     11       0.110
# 19        19      5       0.050
# 20        20      4       0.040
# 21        21      2       0.020
# 22        22      2       0.020
# 23        23      4       0.040
# 24        24      2       0.020
# 25        25      1       0.010
# 26        26      2       0.020
# 27        29      2       0.020
# 28        31      1       0.010
# 29        34      1       0.010

# %% [markdown]
# # Labeling

# %%
def resetEvaluation():
  # TODO Relabel
  # emotion_column = ["Evaluation1", "Evaluation2", "Evaluation3", "Evaluation4", "Evaluation5", "Evaluation6"]

  # for column in emotion_column:
  #   result[column] = None

  result["Emotion"] = None

def goLabeling():
  for session in sessions:
    emotion_path = iemocap + "/" + session + "/dialog/EmoEvaluation/"

    recordings = [file.name for file in os.scandir(emotion_path) if ".txt" in file.name]
    recordings.sort()
    
    for recording in recordings:
      with open(emotion_path + recording) as f:
        lines = f.readlines()
        tokenizedLines = [x.split() for x in lines if "Ses0" in x]

        for part in tokenizedLines:
          line_name = part[3]
          line_label = part[4]
          line_queries = line_name.split("_")
          
          line_part = line_queries[-1]
          line_queries.remove(line_part)

          line_name = "_".join(line_queries)

          search_query_name = ""
          search_query_part = line_queries[-1]
          search_result = result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"]
          search_count = search_result.shape[0]
          
          if search_count == 0:
            print("ERROR: No audio part found: ")
          elif search_count > 1:
            print("ERROR: Multiple audio found: ")
          else:
            result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"] = line_label

def getClassificationReport():
  max_duration = 7

  categorical_data = result.loc[
    (result["Duration"] < max_duration + 1) &
    (
      (result["Emotion"] == 'neu') |
      (result["Emotion"] == 'ang') |
      (result["Emotion"] == 'hap') |
      (result["Emotion"] == 'sad') 
    )
  ]
  
  categorical_plot = seaborn.countplot(x="Emotion", hue="Duration", data=categorical_data)
  categorical_plot.figure.set_size_inches(13,13)

  for p in categorical_plot.patches:
    height = p.get_height()
    categorical_plot.text(p.get_x() + p.get_width()/2., height + 3, '{:1.0f}'.format(height), ha="center") 

  return categorical_data

resetEvaluation()
goLabeling()
categorical_data = getClassificationReport()

# %% [markdown]
# # Selection and Splitting

# %%
def checkAndCreateDirectory(filename):
  if not os.path.exists(os.path.dirname(filename)):
    try:
        os.makedirs(os.path.dirname(filename))
    except OSError as exc: # Guard against race condition
        print(exc.errno)
        if exc.errno != errno.EEXIST:
            raise

def getMfccValue(audio_path, row, dataset_type):
  audio_file, sample_rate = librosa.load(audio_path)
  S = librosa.feature.melspectrogram(y=audio_file, sr=sample_rate)
    
  librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

  filename = "image/" + dataset_type + "/" + row["Emotion"] + "/" + row["Audio Name"] + "_" + row["Part"] + '.png'
  checkAndCreateDirectory(filename)

  plt.gca().set_axis_off()
  plt.savefig(filename, dpi=100, bbox_inches='tight',pad_inches=0)
  # plt.show()
  plt.clf()
  plt.close('all')

  return S

def getEncodedLabel(label):
  label_hot = [0, 0, 0, 0]
  
  if    (label == "neu"): label_hot = [1, 0, 0, 0]
  elif  (label == "ang"): label_hot = [0, 1, 0, 0]
  elif  (label == "hap"): label_hot = [0, 0, 1, 0]
  elif  (label == "sad"): label_hot = [0, 0, 0, 1]

  np.where(np.array(label_hot) == 1)[0][0]
  return np.array(label_hot)

def getAudioPath(row):
  audio_prefix = row["Audio Name"][:5]
  audio_session = "Error"

  if    (audio_prefix == 'Ses01'): audio_session = "Session1"
  elif  (audio_prefix == 'Ses02'): audio_session = "Session2"
  elif  (audio_prefix == 'Ses03'): audio_session = "Session3"
  elif  (audio_prefix == 'Ses04'): audio_session = "Session4"
  elif  (audio_prefix == 'Ses05'): audio_session = "Session5"

  audio_path = iemocap + '/' + audio_session + '/sentences/wav/' + row["Audio Name"] + '/' + row["Audio Name"] + '_' + row["Part"] + '.wav'
  return audio_path

def getVectorAudio(base_duration, durationed_data, dataset_type):
  X = [] # Data
  Y = [] # Label

  durationed_length = len(durationed_data)

  # Iterate every data
  for index, row in durationed_data.iterrows():
    print("Saving " + str(durationed_length) + " " + str(index), end=" | ")

    if durationed_length % 30 == 0: print("\n")
    durationed_length -= 1

    # Get Label
    label = row["Emotion"]
    label_hot = getEncodedLabel(label)

    # Get Mfcc
    audio_path = getAudioPath(row)
    mfcc = getMfccValue(audio_path, row, dataset_type)
    mfcc_length = mfcc.shape[1]

    mfcc_slice = 50 * base_duration

    for mfcc_partial in range(int(mfcc_length/mfcc_slice) + 1):
      start = mfcc_partial * mfcc_slice
      end = (mfcc_partial + 1) * mfcc_slice

      mfcc_partial_result = np.pad(mfcc, pad_width=((0,0), (0, (mfcc_slice - (mfcc_length % mfcc_slice)))), mode='constant')
      mfcc_partial_result = mfcc_partial_result[:,start:end]

      if (mfcc_partial_result.shape[1] != mfcc_slice) | (mfcc_partial_result.shape[0] != 128):
        print("ERROR Mfcc " + str(index) + str(row))
        print("ERROR Mfcc " + index + row)
        break
      
      X.append(mfcc_partial_result)
      Y.append(label_hot)

  return np.array(X), np.array(Y)

def testDuration():
  audio_file, sample_rate = librosa.load('/content/gdrive/My Drive/Public/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro04/Ses01F_impro04_M008.wav')
  duration = librosa.get_duration(y=audio_file, sr=sample_rate)
  print(duration)

  S = librosa.feature.mfcc(y=audio_file, sr=48000)
  print(S.shape)

def getEmotionSplitting(base_duration, max_duration):
  train_data    = pd.DataFrame()
  val_data      = pd.DataFrame()
  test_data     = pd.DataFrame()

  for iterate_index in range(base_duration, max_duration + 1):
    neutral_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'neu')
    ]

    angry_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'ang')
    ]

    sad_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'sad')
    ]

    happy_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'hap')
    ]
    
    print("Duration " + str(iterate_index))
    print("Neutral " + str(neutral_duration.shape[0]))
    print("Angry " + str(angry_duration.shape[0]))
    print("Sad " + str(sad_duration.shape[0]))
    print("Happy " + str(happy_duration.shape[0]))
    print()

    sample_lowest = min(neutral_duration.shape[0], angry_duration.shape[0], sad_duration.shape[0], happy_duration.shape[0])

    neutral_duration  = neutral_duration.sample(sample_lowest)
    angry_duration    = angry_duration.sample(sample_lowest)
    sad_duration      = sad_duration.sample(sample_lowest)
    happy_duration    = happy_duration.sample(sample_lowest)

    # Splitting # 0,6 : 0,8 : 1,0 (60%, 20%, 20%)
    data_training_percent   = int(0.6 * sample_lowest)
    data_validation_percent = int(0.8 * sample_lowest)

    train_data = train_data.append(neutral_duration [:data_training_percent])
    train_data = train_data.append(angry_duration   [:data_training_percent])
    train_data = train_data.append(sad_duration     [:data_training_percent])
    train_data = train_data.append(happy_duration   [:data_training_percent])

    val_data = val_data.append(neutral_duration   [data_training_percent:data_validation_percent])
    val_data = val_data.append(angry_duration     [data_training_percent:data_validation_percent])
    val_data = val_data.append(sad_duration       [data_training_percent:data_validation_percent])
    val_data = val_data.append(happy_duration     [data_training_percent:data_validation_percent])

    test_data = test_data.append(neutral_duration     [data_validation_percent:sample_lowest])
    test_data = test_data.append(angry_duration       [data_validation_percent:sample_lowest])
    test_data = test_data.append(sad_duration         [data_validation_percent:sample_lowest])
    test_data = test_data.append(happy_duration       [data_validation_percent:sample_lowest])

  return train_data.sample(frac=1), val_data.sample(frac=1), test_data.sample(frac=1)

def loadGenerator():
  train_image_generator = ImageDataGenerator()
  train_data = train_image_generator.flow_from_directory(
      directory="image/train/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )
    
  validation_image_generator = ImageDataGenerator()
  validation_data = validation_image_generator.flow_from_directory(
      directory="image/val/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )

  return train_data, validation_data

base_duration = 2
max_duration = 5

train_data, val_data, test_data = getEmotionSplitting(base_duration, max_duration)
# !rm -rf image

# In vector and save image
x_train, y_train  = getVectorAudio(base_duration, train_data, "train")
x_val, y_val      = getVectorAudio(base_duration, val_data, "val")
x_test, y_test    = getVectorAudio(base_duration, test_data, "test")

# In generator
train_generator, validation_generator = loadGenerator()
# Out:
# Duration 2
# Neutral 419
# Angry 266
# Sad 221
# Happy 156
#
# Duration 3
# Neutral 285
# Angry 204
# Sad 181
# Happy 110
#
# Duration 4
# Neutral 198
# Angry 132
# Sad 127
# Happy 58
#
# Duration 5
# Neutral 124
# Angry 98
# Sad 97
# Happy 43
#
# Saving 872 3513 | Saving 871 1109 | Saving 870 5816 |
#
# Saving 869 486 | Saving 868 8947 | Saving 867 3515 | Saving 866 5124 | Saving 865 8029 | Saving 864 3228 | Saving 863 5027 | Saving 862 5540 | Saving 861 3154 | Saving 860 2334 | Saving 859 4187 | Saving 858 2574 | Saving 857 4189 | Saving 856 4236 | Saving 855 7458 | Saving 854 9296 | Saving 853 6654 | Saving 852 7423 | Saving 851 4538 | Saving 850 4829 | Saving 849 8188 | Saving 848 4270 | Saving 847 476 | Saving 846 6517 | Saving 845 4793 | Saving 844 9535 | Saving 843 3423 | Saving 842 7513 | Saving 841 855 | Saving 840 7758 |
#
# Saving 839 6316 | Saving 838 9454 | Saving 837 1924 | Saving 836 3928 | Saving 835 936 | Saving 834 151 | Saving 833 8058 | Saving 832 9304 | Saving 831 8218 | Saving 830 4777 | Saving 829 8517 | Saving 828 964 | Saving 827 3718 | Saving 826 4737 | Saving 825 2708 | Saving 824 3915 | Saving 823 2231 | Saving 822 34 | Saving 821 9196 | Saving 820 7321 | Saving 819 7179 | Saving 818 3729 | Saving 817 6377 | Saving 816 3608 | Saving 815 2499 | Saving 814 2488 | Saving 813 3418 | Saving 812 9901 | Saving 811 6835 | Saving 810 5523 |
#
# Saving 809 6054 | Saving 808 1487 | Saving 807 7877 | Saving 806 3136 | Saving 805 1162 | Saving 804 5058 | Saving 803 9960 | Saving 802 8341 | Saving 801 3813 | Saving 800 830 | Saving 799 1365 | Saving 798 9265 | Saving 797 1814 | Saving 796 3089 | Saving 795 483 | Saving 794 6872 | Saving 793 1327 | Saving 792 1634 | Saving 791 4569 | Saving 790 7795 | Saving 789 3311 | Saving 788 1694 | Saving 787 3998 | Saving 786 4925 | Saving 785 6106 | Saving 784 3866 | Saving 783 237 | Saving 782 2970 | Saving 781 7981 | Saving 780 4516 |
#
# Saving 779 2651 | Saving 778 6253 | Saving 777 5013 | Saving 776 3892 | Saving 775 4112 | Saving 774 6355 | Saving 773 9446 | Saving 772 9830 | Saving 771 1767 | Saving 770 5044 | Saving 769 62 | Saving 768 6252 | Saving 767 9716 | Saving 766 4591 | Saving 765 902 | Saving 764 793 | Saving 763 5154 | Saving 762 7228 | Saving 761 3688 | Saving 760 2376 | Saving 759 3910 | Saving 758 4173 | Saving 757 8527 | Saving 756 5785 | Saving 755 5353 | Saving 754 654 | Saving 753 5391 | Saving 752 522 | Saving 751 7471 | Saving 750 7998 |
#
# Saving 749 1155 | Saving 748 8050 | Saving 747 9070 | Saving 746 1672 | Saving 745 3999 | Saving 744 9333 | Saving 743 3496 | Saving 742 5170 | Saving 741 1748 | Saving 740 3148 | Saving 739 543 | Saving 738 9824 | Saving 737 2424 | Saving 736 4121 | Saving 735 6799 | Saving 734 1242 | Saving 733 777 | Saving 732 7803 | Saving 731 470 | Saving 730 5369 | Saving 729 2706 | Saving 728 1482 | Saving 727 9618 | Saving 726 1589 | Saving 725 8788 | Saving 724 1423 | Saving 723 7201 | Saving 722 7083 | Saving 721 3066 | Saving 720 5818 |
#
# Saving 719 8054 | Saving 718 4669 | Saving 717 9722 | Saving 716 78 | Saving 715 8217 | Saving 714 1197 | Saving 713 8528 | Saving 712 4919 | Saving 711 5168 | Saving 710 8242 | Saving 709 5787 | Saving 708 519 | Saving 707 7776 | Saving 706 7055 | Saving 705 7450 | Saving 704 1505 | Saving 703 8038 | Saving 702 7045 | Saving 701 9471 | Saving 700 7833 | Saving 699 8930 | Saving 698 7140 | Saving 697 4709 | Saving 696 1192 | Saving 695 1575 | Saving 694 2965 | Saving 693 4140 | Saving 692 6376 | Saving 691 5702 | Saving 690 4013 |
#
# Saving 689 1421 | Saving 688 7476 | Saving 687 4802 | Saving 686 6657 | Saving 685 966 | Saving 684 8456 | Saving 683 2171 | Saving 682 1004 | Saving 681 5800 | Saving 680 3835 | Saving 679 3841 | Saving 678 4099 | Saving 677 6453 | Saving 676 9952 | Saving 675 5367 | Saving 674 521 | Saving 673 4111 | Saving 672 4434 | Saving 671 4647 | Saving 670 3144 | Saving 669 1298 | Saving 668 165 | Saving 667 49 | Saving 666 8945 | Saving 665 1799 | Saving 664 1731 | Saving 663 7094 | Saving 662 3681 | Saving 661 2053 | Saving 660 5837 |
#
# Saving 659 295 | Saving 658 76 | Saving 657 5036 | Saving 656 6627 | Saving 655 5758 | Saving 654 5398 | Saving 653 4947 | Saving 652 5748 | Saving 651 4795 | Saving 650 2949 | Saving 649 3945 | Saving 648 836 | Saving 647 7393 | Saving 646 2738 | Saving 645 7057 | Saving 644 7941 | Saving 643 3748 | Saving 642 2969 | Saving 641 7690 | Saving 640 5022 | Saving 639 9160 | Saving 638 2348 | Saving 637 862 | Saving 636 8874 | Saving 635 5163 | Saving 634 801 | Saving 633 1113 | Saving 632 8609 | Saving 631 4920 | Saving 630 808 |
#
# Saving 629 1862 | Saving 628 5759 | Saving 627 3551 | Saving 626 403 | Saving 625 5009 | Saving 624 7466 | Saving 623 3894 | Saving 622 7323 | Saving 621 4967 | Saving 620 8518 | Saving 619 8799 | Saving 618 9361 | Saving 617 8323 | Saving 616 4237 | Saving 615 2983 | Saving 614 3898 | Saving 613 4618 | Saving 612 4819 | Saving 611 9976 | Saving 610 2296 | Saving 609 4534 | Saving 608 475 | Saving 607 9324 | Saving 606 9559 | Saving 605 8307 | Saving 604 2335 | Saving 603 3903 | Saving 602 1952 | Saving 601 250 | Saving 600 4374 |
#
# Saving 599 3139 | Saving 598 9113 | Saving 597 7640 | Saving 596 1083 | Saving 595 5004 | Saving 594 950 | Saving 593 9620 | Saving 592 1925 | Saving 591 7123 | Saving 590 3836 | Saving 589 3674 | Saving 588 3744 | Saving 587 8979 | Saving 586 73 | Saving 585 3673 | Saving 584 957 | Saving 583 620 | Saving 582 3885 | Saving 581 8273 | Saving 580 5920 | Saving 579 1763 | Saving 578 8962 | Saving 577 6094 | Saving 576 4924 | Saving 575 9983 | Saving 574 5076 | Saving 573 5549 | Saving 572 2614 | Saving 571 3012 | Saving 570 5541 |
#
# Saving 569 6841 | Saving 568 7213 | Saving 567 9167 | Saving 566 5019 | Saving 565 958 | Saving 564 1050 | Saving 563 7442 | Saving 562 3680 | Saving 561 6498 | Saving 560 1667 | Saving 559 1707 | Saving 558 5865 | Saving 557 2559 | Saving 556 1974 | Saving 555 6386 | Saving 554 1399 | Saving 553 7050 | Saving 552 7093 | Saving 551 3579 | Saving 550 1558 | Saving 549 5042 | Saving 548 499 | Saving 547 702 | Saving 546 154 | Saving 545 1806 | Saving 544 6091 | Saving 543 7373 | Saving 542 48 | Saving 541 4887 | Saving 540 5312 |
#
# Saving 539 8925 | Saving 538 4219 | Saving 537 4586 | Saving 536 2956 | Saving 535 2041 | Saving 534 5039 | Saving 533 5371 | Saving 532 4969 | Saving 531 2576 | Saving 530 5073 | Saving 529 4234 | Saving 528 1047 | Saving 527 92 | Saving 526 619 | Saving 525 9161 | Saving 524 8648 | Saving 523 7293 | Saving 522 2636 | Saving 521 9382 | Saving 520 4998 | Saving 519 1621 | Saving 518 5212 | Saving 517 6104 | Saving 516 9554 | Saving 515 3614 | Saving 514 4775 | Saving 513 9916 | Saving 512 9894 | Saving 511 8364 | Saving 510 6191 |
#
# Saving 509 3541 | Saving 508 4909 | Saving 507 3019 | Saving 506 9602 | Saving 505 4339 | Saving 504 1283 | Saving 503 5971 | Saving 502 1662 | Saving 501 6267 | Saving 500 5028 | Saving 499 347 | Saving 498 6321 | Saving 497 7419 | Saving 496 4240 | Saving 495 7926 | Saving 494 5810 | Saving 493 1255 | Saving 492 8637 | Saving 491 4061 | Saving 490 3234 | Saving 489 4661 | Saving 488 8990 | Saving 487 3902 | Saving 486 10022 | Saving 485 2966 | Saving 484 3086 | Saving 483 442 | Saving 482 8193 | Saving 481 5577 | Saving 480 854 |
#
# Saving 479 2575 | Saving 478 4215 | Saving 477 9592 | Saving 476 1669 | Saving 475 6449 | Saving 474 7545 | Saving 473 8562 | Saving 472 1032 | Saving 471 3015 | Saving 470 8563 | Saving 469 3751 | Saving 468 10024 | Saving 467 9630 | Saving 466 69 | Saving 465 8480 | Saving 464 7762 | Saving 463 9869 | Saving 462 4367 | Saving 461 814 | Saving 460 6380 | Saving 459 6808 | Saving 458 9253 | Saving 457 3719 | Saving 456 3575 | Saving 455 9743 | Saving 454 5202 | Saving 453 118 | Saving 452 384 | Saving 451 8303 | Saving 450 5125 |
#
# Saving 449 5406 | Saving 448 7372 | Saving 447 170 | Saving 446 7010 | Saving 445 4779 | Saving 444 5370 | Saving 443 1319 | Saving 442 1448 | Saving 441 84 | Saving 440 1911 | Saving 439 5 | Saving 438 8977 | Saving 437 7394 | Saving 436 8833 | Saving 435 1703 | Saving 434 8655 | Saving 433 31 | Saving 432 2569 | Saving 431 5274 | Saving 430 7395 | Saving 429 427 | Saving 428 813 | Saving 427 4671 | Saving 426 2760 | Saving 425 9092 | Saving 424 2596 | Saving 423 4245 | Saving 422 3155 | Saving 421 9331 | Saving 420 4235 |
#
# Saving 419 9963 | Saving 418 3598 | Saving 417 5988 | Saving 416 5024 | Saving 415 3811 | Saving 414 4190 | Saving 413 7790 | Saving 412 96 | Saving 411 8969 | Saving 410 8537 | Saving 409 5529 | Saving 408 357 | Saving 407 216 | Saving 406 3258 | Saving 405 5752 | Saving 404 3982 | Saving 403 3201 | Saving 402 2595 | Saving 401 7794 | Saving 400 7193 | Saving 399 5727 | Saving 398 5268 | Saving 397 951 | Saving 396 5551 | Saving 395 8355 | Saving 394 2319 | Saving 393 9133 | Saving 392 1642 | Saving 391 485 | Saving 390 4610 |
#
# Saving 389 3499 | Saving 388 6048 | Saving 387 5050 | Saving 386 4229 | Saving 385 4710 | Saving 384 1378 | Saving 383 4383 | Saving 382 9281 | Saving 381 6481 | Saving 380 6478 | Saving 379 4834 | Saving 378 1979 | Saving 377 4937 | Saving 376 3156 | Saving 375 7402 | Saving 374 6278 | Saving 373 9684 | Saving 372 7952 | Saving 371 4435 | Saving 370 110 | Saving 369 2572 | Saving 368 4389 | Saving 367 8719 | Saving 366 3009 | Saving 365 1453 | Saving 364 1151 | Saving 363 774 | Saving 362 1948 | Saving 361 1770 | Saving 360 7047 |
#
# Saving 359 4228 | Saving 358 4713 | Saving 357 9696 | Saving 356 1813 | Saving 355 6365 | Saving 354 9450 | Saving 353 2220 | Saving 352 3248 | Saving 351 4225 | Saving 350 3677 | Saving 349 3926 | Saving 348 5270 | Saving 347 8151 | Saving 346 1729 | Saving 345 4986 | Saving 344 234 | Saving 343 8333 | Saving 342 5722 | Saving 341 8915 | Saving 340 3827 | Saving 339 1194 | Saving 338 4706 | Saving 337 2690 | Saving 336 4684 | Saving 335 5376 | Saving 334 203 | Saving 333 287 | Saving 332 8121 | Saving 331 9169 | Saving 330 7044 |
#
# Saving 329 3876 | Saving 328 5726 | Saving 327 1419 | Saving 326 7789 | Saving 325 5007 | Saving 324 5762 | Saving 323 8329 | Saving 322 10037 | Saving 321 9349 | Saving 320 2961 | Saving 319 2477 | Saving 318 3574 | Saving 317 3592 | Saving 316 2764 | Saving 315 4418 | Saving 314 4936 | Saving 313 3295 | Saving 312 9119 | Saving 311 3534 | Saving 310 7398 | Saving 309 1682 | Saving 308 150 | Saving 307 52 | Saving 306 5361 | Saving 305 8046 | Saving 304 2960 | Saving 303 221 | Saving 302 8222 | Saving 301 3184 | Saving 300 3606 |
#
# Saving 299 8568 | Saving 298 8641 | Saving 297 3468 | Saving 296 70 | Saving 295 1360 | Saving 294 6860 | Saving 293 3879 | Saving 292 3891 | Saving 291 2331 | Saving 290 4384 | Saving 289 4543 | Saving 288 10029 | Saving 287 1472 | Saving 286 4904 | Saving 285 89 | Saving 284 608 | Saving 283 7041 | Saving 282 4095 | Saving 281 3625 | Saving 280 7518 | Saving 279 5418 | Saving 278 4778 | Saving 277 6528 | Saving 276 4186 | Saving 275 7175 | Saving 274 376 | Saving 273 1091 | Saving 272 9702 | Saving 271 9599 | Saving 270 4628 |
#
# Saving 269 6385 | Saving 268 9090 | Saving 267 5354 | Saving 266 7124 | Saving 265 1657 | Saving 264 8382 | Saving 263 963 | Saving 262 4644 | Saving 261 3438 | Saving 260 7282 | Saving 259 5701 | Saving 258 5547 | Saving 257 2768 | Saving 256 4268 | Saving 255 9098 | Saving 254 4244 | Saving 253 5753 | Saving 252 1363 | Saving 251 177 | Saving 250 10030 | Saving 249 5273 | Saving 248 4377 | Saving 247 1154 | Saving 246 8186 | Saving 245 679 | Saving 244 4585 | Saving 243 591 | Saving 242 6518 | Saving 241 8483 | Saving 240 1712 |
#
# Saving 239 9114 | Saving 238 5733 | Saving 237 1416 | Saving 236 5689 | Saving 235 4512 | Saving 234 4201 | Saving 233 655 | Saving 232 8957 | Saving 231 7017 | Saving 230 6457 | Saving 229 5596 | Saving 228 3536 | Saving 227 852 | Saving 226 8838 | Saving 225 4171 | Saving 224 8221 | Saving 223 9149 | Saving 222 2557 | Saving 221 1560 | Saving 220 6555 | Saving 219 4452 | Saving 218 3582 | Saving 217 5217 | Saving 216 6410 | Saving 215 4463 | Saving 214 3712 | Saving 213 780 | Saving 212 4878 | Saving 211 4932 | Saving 210 4688 |
#
# Saving 209 10028 | Saving 208 2958 | Saving 207 6856 | Saving 206 1601 | Saving 205 2170 | Saving 204 9745 | Saving 203 7368 | Saving 202 2830 | Saving 201 4005 | Saving 200 9115 | Saving 199 843 | Saving 198 5023 | Saving 197 4659 | Saving 196 4356 | Saving 195 3478 | Saving 194 219 | Saving 193 5010 | Saving 192 4698 | Saving 191 2948 | Saving 190 8300 | Saving 189 7801 | Saving 188 1941 | Saving 187 2374 | Saving 186 7268 | Saving 185 8952 | Saving 184 1809 | Saving 183 7923 | Saving 182 2560 | Saving 181 8545 | Saving 180 9312 |
#
# Saving 179 9197 | Saving 178 6358 | Saving 177 7177 | Saving 176 4192 | Saving 175 1496 | Saving 174 2373 | Saving 173 6513 | Saving 172 1015 | Saving 171 5262 | Saving 170 8917 | Saving 169 4701 | Saving 168 3024 | Saving 167 9866 | Saving 166 5222 | Saving 165 9305 | Saving 164 1449 | Saving 163 5239 | Saving 162 1935 | Saving 161 3916 | Saving 160 412 | Saving 159 1688 | Saving 158 4753 | Saving 157 9659 | Saving 156 2573 | Saving 155 6008 | Saving 154 2232 | Saving 153 3088 | Saving 152 4930 | Saving 151 7269 | Saving 150 9202 |
#
# Saving 149 6258 | Saving 148 5453 | Saving 147 1123 | Saving 146 5051 | Saving 145 9685 | Saving 144 7560 | Saving 143 7920 | Saving 142 545 | Saving 141 2343 | Saving 140 7324 | Saving 139 1080 | Saving 138 970 | Saving 137 8101 | Saving 136 4996 | Saving 135 7556 | Saving 134 9303 | Saving 133 4845 | Saving 132 515 | Saving 131 7454 | Saving 130 5078 | Saving 129 618 | Saving 128 728 | Saving 127 4796 | Saving 126 853 | Saving 125 4390 | Saving 124 2710 | Saving 123 8216 | Saving 122 4267 | Saving 121 3034 | Saving 120 3210 |
#
# Saving 119 5323 | Saving 118 9299 | Saving 117 3214 | Saving 116 4503 | Saving 115 5718 | Saving 114 4224 | Saving 113 3808 | Saving 112 5797 | Saving 111 3869 | Saving 110 1768 | Saving 109 3833 | Saving 108 9272 | Saving 107 5832 | Saving 106 3799 | Saving 105 9111 | Saving 104 9123 | Saving 103 4642 | Saving 102 8566 | Saving 101 4243 | Saving 100 2060 | Saving 99 935 | Saving 98 9355 | Saving 97 2772 | Saving 96 3108 | Saving 95 1723 | Saving 94 841 | Saving 93 4464 | Saving 92 2650 | Saving 91 3936 | Saving 90 8817 |
#
# Saving 89 4660 | Saving 88 2351 | Saving 87 8373 | Saving 86 7939 | Saving 85 4683 | Saving 84 3862 | Saving 83 2558 | Saving 82 3504 | Saving 81 6020 | Saving 80 1811 | Saving 79 8614 | Saving 78 4687 | Saving 77 5057 | Saving 76 3065 | Saving 75 2320 | Saving 74 5389 | Saving 73 6347 | Saving 72 1452 | Saving 71 167 | Saving 70 7761 | Saving 69 3463 | Saving 68 1183 | Saving 67 2556 | Saving 66 4994 | Saving 65 9093 | Saving 64 8137 | Saving 63 3693 | Saving 62 626 | Saving 61 4071 | Saving 60 1819 |
#
# Saving 59 9205 | Saving 58 8204 | Saving 57 5153 | Saving 56 8458 | Saving 55 719 | Saving 54 973 | Saving 53 5046 | Saving 52 2570 | Saving 51 5288 | Saving 50 1684 | Saving 49 3490 | Saving 48 9985 | Saving 47 6830 | Saving 46 4582 | Saving 45 3912 | Saving 44 4693 | Saving 43 7919 | Saving 42 6326 | Saving 41 6828 | Saving 40 8146 | Saving 39 2836 | Saving 38 3770 | Saving 37 6340 | Saving 36 5368 | Saving 35 8353 | Saving 34 6822 | Saving 33 9147 | Saving 32 6263 | Saving 31 7648 | Saving 30 6010 |
#
# Saving 29 9655 | Saving 28 8289 | Saving 27 38 | Saving 26 7855 | Saving 25 3749 | Saving 24 8270 | Saving 23 4217 | Saving 22 7651 | Saving 21 8209 | Saving 20 4221 | Saving 19 1424 | Saving 18 5070 | Saving 17 5813 | Saving 16 6322 | Saving 15 8639 | Saving 14 7340 | Saving 13 5049 | Saving 12 7196 | Saving 11 3823 | Saving 10 4507 | Saving 9 2540 | Saving 8 5047 | Saving 7 5242 | Saving 6 1700 | Saving 5 8045 | Saving 4 3900 | Saving 3 3899 | Saving 2 4207 | Saving 1 6815 | Saving 296 2276 | Saving 295 1652 | Saving 294 2179 | Saving 293 5221 | Saving 292 3583 | Saving 291 1328 | Saving 290 4150 | Saving 289 1295 | Saving 288 1615 | Saving 287 7988 | Saving 286 8339 | Saving 285 32 | Saving 284 68 | Saving 283 1930 | Saving 282 8604 | Saving 281 7992 | Saving 280 5812 | Saving 279 3750 | Saving 278 5374 | Saving 277 60 | Saving 276 6432 | Saving 275 4271 | Saving 274 9276 | Saving 273 3271 | Saving 272 7834 | Saving 271 5553 | Saving 270 9000 |
#
# Saving 269 858 | Saving 268 5528 | Saving 267 1149 | Saving 266 2544 | Saving 265 1980 | Saving 264 7379 | Saving 263 5774 | Saving 262 7813 | Saving 261 7792 | Saving 260 776 | Saving 259 3512 | Saving 258 5669 | Saving 257 2758 | Saving 256 646 | Saving 255 6636 | Saving 254 3500 | Saving 253 5683 | Saving 252 4256 | Saving 251 2840 | Saving 250 3529 | Saving 249 3924 | Saving 248 4935 | Saving 247 7639 | Saving 246 8946 | Saving 245 3243 | Saving 244 6817 | Saving 243 2162 | Saving 242 9729 | Saving 241 3870 | Saving 240 1027 |
#
# Saving 239 7453 | Saving 238 1936 | Saving 237 4024 | Saving 236 8663 | Saving 235 3481 | Saving 234 3267 | Saving 233 804 | Saving 232 8932 | Saving 231 3905 | Saving 230 9195 | Saving 229 1153 | Saving 228 5114 | Saving 227 4987 | Saving 226 3923 | Saving 225 268 | Saving 224 3908 | Saving 223 5166 | Saving 222 1168 | Saving 221 6623 | Saving 220 1730 | Saving 219 4746 | Saving 218 7759 | Saving 217 1873 | Saving 216 5587 | Saving 215 8526 | Saving 214 5435 | Saving 213 5729 | Saving 212 205 | Saving 211 7333 | Saving 210 8207 |
#
# Saving 209 9057 | Saving 208 691 | Saving 207 5509 | Saving 206 4007 | Saving 205 9009 | Saving 204 4682 | Saving 203 8841 | Saving 202 3297 | Saving 201 1321 | Saving 200 109 | Saving 199 4188 | Saving 198 8254 | Saving 197 2548 | Saving 196 2539 | Saving 195 5366 | Saving 194 1509 | Saving 193 4202 | Saving 192 4338 | Saving 191 2186 | Saving 190 1276 | Saving 189 7325 | Saving 188 7396 | Saving 187 7139 | Saving 186 2372 | Saving 185 4459 | Saving 184 1417 | Saving 183 5002 | Saving 182 1711 | Saving 181 4780 | Saving 180 7176 |
#
# Saving 179 8862 | Saving 178 4154 | Saving 177 120 | Saving 176 3821 | Saving 175 8789 | Saving 174 4995 | Saving 173 8587 | Saving 172 3907 | Saving 171 8176 | Saving 170 1178 | Saving 169 3470 | Saving 168 1665 | Saving 167 517 | Saving 166 471 | Saving 165 8148 | Saving 164 6510 | Saving 163 1651 | Saving 162 8642 | Saving 161 1944 | Saving 160 3473 | Saving 159 7571 | Saving 158 8944 | Saving 157 7822 | Saving 156 7338 | Saving 155 10027 | Saving 154 1359 | Saving 153 212 | Saving 152 5055 | Saving 151 7950 | Saving 150 8923 |
#
# Saving 149 5552 | Saving 148 4387 | Saving 147 3682 | Saving 146 779 | Saving 145 3425 | Saving 144 7097 | Saving 143 8826 | Saving 142 3901 | Saving 141 6401 | Saving 140 2154 | Saving 139 8033 | Saving 138 3697 | Saving 137 4054 | Saving 136 5505 | Saving 135 8056 | Saving 134 3200 | Saving 133 4249 | Saving 132 9538 | Saving 131 7634 | Saving 130 5543 | Saving 129 4837 | Saving 128 6006 | Saving 127 9371 | Saving 126 6824 | Saving 125 4745 | Saving 124 8367 | Saving 123 253 | Saving 122 1152 | Saving 121 6477 | Saving 120 7106 |
#
# Saving 119 9274 | Saving 118 2516 | Saving 117 781 | Saving 116 6361 | Saving 115 5601 | Saving 114 8035 | Saving 113 3968 | Saving 112 5041 | Saving 111 1766 | Saving 110 3589 | Saving 109 6862 | Saving 108 5025 | Saving 107 5400 | Saving 106 1201 | Saving 105 1686 | Saving 104 9185 | Saving 103 882 | Saving 102 4631 | Saving 101 4732 | Saving 100 3162 | Saving 99 8281 | Saving 98 6031 | Saving 97 3011 | Saving 96 1422 | Saving 95 50 | Saving 94 8266 | Saving 93 280 | Saving 92 2852 | Saving 91 5216 | Saving 90 827 |
#
# Saving 89 6805 | Saving 88 1387 | Saving 87 3727 | Saving 86 6820 | Saving 85 5316 | Saving 84 5778 | Saving 83 8047 | Saving 82 8778 | Saving 81 1284 | Saving 80 2634 | Saving 79 1185 | Saving 78 2260 | Saving 77 81 | Saving 76 9248 | Saving 75 6601 | Saving 74 2566 | Saving 73 3889 | Saving 72 1645 | Saving 71 9723 | Saving 70 684 | Saving 69 2038 | Saving 68 9551 | Saving 67 6814 | Saving 66 5130 | Saving 65 479 | Saving 64 7046 | Saving 63 1773 | Saving 62 1313 | Saving 61 4536 | Saving 60 4432 |
#
# Saving 59 4433 | Saving 58 3199 | Saving 57 3860 | Saving 56 6661 | Saving 55 5384 | Saving 54 8691 | Saving 53 7514 | Saving 52 4747 | Saving 51 3867 | Saving 50 8619 | Saving 49 1918 | Saving 48 1250 | Saving 47 5296 | Saving 46 1339 | Saving 45 7847 | Saving 44 6774 | Saving 43 8090 | Saving 42 5827 | Saving 41 2042 | Saving 40 6242 | Saving 39 8921 | Saving 38 6200 | Saving 37 148 | Saving 36 1176 | Saving 35 213 | Saving 34 758 | Saving 33 3840 | Saving 32 8316 | Saving 31 3934 | Saving 30 6371 |
#
# Saving 29 8938 | Saving 28 1720 | Saving 27 1758 | Saving 26 4685 | Saving 25 681 | Saving 24 4808 | Saving 23 1687 | Saving 22 7358 | Saving 21 5373 | Saving 20 3023 | Saving 19 4436 | Saving 18 7544 | Saving 17 2279 | Saving 16 1362 | Saving 15 3859 | Saving 14 6013 | Saving 13 5016 | Saving 12 572 | Saving 11 1428 | Saving 10 5053 | Saving 9 8244 | Saving 8 404 | Saving 7 4191 | Saving 6 3497 | Saving 5 1663 | Saving 4 3190 | Saving 3 273 | Saving 2 8567 | Saving 1 8468 | Saving 300 1085 |
#
# Saving 299 1868 | Saving 298 4314 | Saving 297 520 | Saving 296 7356 | Saving 295 1105 | Saving 294 7688 | Saving 293 9645 | Saving 292 6958 | Saving 291 1678 | Saving 290 3930 | Saving 289 3585 | Saving 288 8109 | Saving 287 2925 | Saving 286 9158 | Saving 285 4833 | Saving 284 9166 | Saving 283 707 | Saving 282 5385 | Saving 281 5706 | Saving 280 2523 | Saving 279 5067 | Saving 278 1922 | Saving 277 9479 | Saving 276 3581 | Saving 275 8125 | Saving 274 9638 | Saving 273 7060 | Saving 272 4545 | Saving 271 2211 | Saving 270 4557 |
#
# Saving 269 1478 | Saving 268 6480 | Saving 267 1430 | Saving 266 7858 | Saving 265 4997 | Saving 264 8791 | Saving 263 7397 | Saving 262 3255 | Saving 261 8128 | Saving 260 2199 | Saving 259 3503 | Saving 258 1125 | Saving 257 10036 | Saving 256 9839 | Saving 255 3805 | Saving 254 1871 | Saving 253 72 | Saving 252 7826 | Saving 251 5386 | Saving 250 5419 | Saving 249 869 | Saving 248 5048 | Saving 247 9966 | Saving 246 5059 | Saving 245 9543 | Saving 244 9987 | Saving 243 5005 | Saving 242 8127 | Saving 241 3064 | Saving 240 3166 |
#
# Saving 239 961 | Saving 238 4183 | Saving 237 5054 | Saving 236 3300 | Saving 235 2778 | Saving 234 8512 | Saving 233 3253 | Saving 232 9497 | Saving 231 563 | Saving 230 1042 | Saving 229 8473 | Saving 228 3685 | Saving 227 7788 | Saving 226 749 | Saving 225 1582 | Saving 224 5394 | Saving 223 5198 | Saving 222 1286 | Saving 221 4141 | Saving 220 2378 | Saving 219 3810 | Saving 218 912 | Saving 217 7767 | Saving 216 8243 | Saving 215 4781 | Saving 214 9198 | Saving 213 1760 | Saving 212 6011 | Saving 211 494 | Saving 210 4282 |
#
# Saving 209 9950 | Saving 208 2222 | Saving 207 3275 | Saving 206 2307 | Saving 205 3888 | Saving 204 4146 | Saving 203 8330 | Saving 202 4098 | Saving 201 5712 | Saving 200 5014 | Saving 199 7468 | Saving 198 2192 | Saving 197 7104 | Saving 196 8647 | Saving 195 5826 | Saving 194 4365 | Saving 193 8942 | Saving 192 93 | Saving 191 9877 | Saving 190 3578 | Saving 189 991 | Saving 188 4144 | Saving 187 8368 | Saving 186 10001 | Saving 185 7216 | Saving 184 4357 | Saving 183 101 | Saving 182 1019 | Saving 181 2498 | Saving 180 9880 |
#
# Saving 179 3880 | Saving 178 160 | Saving 177 454 | Saving 176 9448 | Saving 175 729 | Saving 174 8515 | Saving 173 1191 | Saving 172 9065 | Saving 171 1041 | Saving 170 718 | Saving 169 2275 | Saving 168 924 | Saving 167 1685 | Saving 166 6525 | Saving 165 3274 | Saving 164 481 | Saving 163 1403 | Saving 162 5006 | Saving 161 4742 | Saving 160 1618 | Saving 159 1289 | Saving 158 2699 | Saving 157 6637 | Saving 156 2667 | Saving 155 5436 | Saving 154 6826 | Saving 153 1808 | Saving 152 5043 | Saving 151 4707 | Saving 150 8055 |
#
# Saving 149 4362 | Saving 148 1429 | Saving 147 8706 | Saving 146 3820 | Saving 145 8423 | Saving 144 4551 | Saving 143 9483 | Saving 142 6397 | Saving 141 6057 | Saving 140 5309 | Saving 139 3259 | Saving 138 5417 | Saving 137 9124 | Saving 136 6938 | Saving 135 2049 | Saving 134 6419 | Saving 133 5149 | Saving 132 1180 | Saving 131 4203 | Saving 130 5327 | Saving 129 3550 | Saving 128 8666 | Saving 127 159 | Saving 126 10020 | Saving 125 7270 | Saving 124 2213 | Saving 123 5730 | Saving 122 941 | Saving 121 3091 | Saving 120 1282 |
#
# Saving 119 9872 | Saving 118 121 | Saving 117 80 | Saving 116 7806 | Saving 115 3482 | Saving 114 2593 | Saving 113 3609 | Saving 112 4255 | Saving 111 1179 | Saving 110 2129 | Saving 109 4792 | Saving 108 5554 | Saving 107 1090 | Saving 106 849 | Saving 105 6546 | Saving 104 1937 | Saving 103 1206 | Saving 102 10008 | Saving 101 1456 | Saving 100 748 | Saving 99 1345 | Saving 98 9673 | Saving 97 6428 | Saving 96 4555 | Saving 95 5986 | Saving 94 4782 | Saving 93 2506 | Saving 92 7967 | Saving 91 599 | Saving 90 4888 |
#
# Saving 89 6305 | Saving 88 895 | Saving 87 6409 | Saving 86 4968 | Saving 85 9079 | Saving 84 9252 | Saving 83 4694 | Saving 82 3689 | Saving 81 1812 | Saving 80 7477 | Saving 79 3142 | Saving 78 1656 | Saving 77 5300 | Saving 76 5040 | Saving 75 939 | Saving 74 6867 | Saving 73 4741 | Saving 72 3587 | Saving 71 9876 | Saving 70 7805 | Saving 69 609 | Saving 68 1635 | Saving 67 9339 | Saving 66 3804 | Saving 65 6492 | Saving 64 4176 | Saving 63 6373 | Saving 62 1205 | Saving 61 2891 | Saving 60 7456 |
#
# Saving 59 1207 | Saving 58 1346 | Saving 57 4951 | Saving 56 2036 | Saving 55 4738 | Saving 54 5226 | Saving 53 5724 | Saving 52 1182 | Saving 51 102 | Saving 50 8354 | Saving 49 5597 | Saving 48 8189 | Saving 47 3247 | Saving 46 9177 | Saving 45 923 | Saving 44 2048 | Saving 43 4588 | Saving 42 1196 | Saving 41 3875 | Saving 40 4554 | Saving 39 3947 | Saving 38 5583 | Saving 37 7942 | Saving 36 1261 | Saving 35 2146 | Saving 34 1801 | Saving 33 7565 | Saving 32 7971 | Saving 31 108 | Saving 30 4100 |
#
# Saving 29 6349 | Saving 28 3049 | Saving 27 9583 | Saving 26 6658 | Saving 25 9695 | Saving 24 7337 | Saving 23 7930 | Saving 22 8994 | Saving 21 1771 | Saving 20 1810 | Saving 19 464 | Saving 18 5521 | Saving 17 4430 | Saving 16 9165 | Saving 15 45 | Saving 14 3153 | Saving 13 4023 | Saving 12 3157 | Saving 11 9468 | Saving 10 244 | Saving 9 653 | Saving 8 3909 | Saving 7 9110 | Saving 6 3117 | Saving 5 4667 | Saving 4 4177 | Saving 3 6519 | Saving 2 6890 | Saving 1 8665 | Found 872 images belonging to 4 classes.
# Found 296 images belonging to 4 classes.

# %%
def plot_result(model, history):
  # list all data in history
  print(history.history.keys())

  # summarize history for accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

def save_model(model, filename):
  checkAndCreateDirectory("/content/model/test.txt")
  model.summary()

  plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

  with open("/content/model/" + filename + ".json", "w") as json_file:
    model_json = model.to_json()
    json_file.write(model_json)

def buildModel():
  model_input = Input(shape=(256, 256, 3))

  # model = Conv2D(64, kernel_size=3, strides=2)(model)

  model = Conv2D(64, kernel_size=16, strides=1)(model_input)
  model = MaxPooling2D(2)(model)

  model = Conv2D(128, kernel_size=16, strides=1)(model)
  model = MaxPooling2D(2)(model)

  model = Conv2D(256, kernel_size=16, strides=1)(model)
  model = MaxPooling2D(2)(model)

  model = Flatten()(model)

  model = Dense(256)(model)

  model = Dense(4, activation='softmax')(model)
  
#   model = Sequential()
#   eff = tf.keras.applications.EfficientNetB0(
#     weights=None,
#     classes=4,
#     input_shape=(128,50,1)
#   )

#   model.add(eff)

  # Model compile
  model = Model(inputs=[model_input], outputs=[model])
  model.compile(optimizer="adam", loss=tf.keras.losses.CategoricalCrossentropy(), metrics=["accuracy"])
  
  # Visualize & Save Model
  save_model(model, "struct_model")

  # Checkpoint
  basepath = '/content/model/weight_model'
  best_checkpoint = ModelCheckpoint(basepath +'_{epoch:02d}_{loss:.2f}_{accuracy:.2f}_{val_loss:.2f}_{val_accuracy:.2f}.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
  callback_list = [best_checkpoint]

#   history = model.fit(
#     x_train, 
#     y_train, 
#     validation_data=(x_val, y_val),
#     batch_size=1, 
#     epochs=100,
#     callbacks=callback_list
#   )

  history = model.fit_generator(
    generator=train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=callback_list
  )

  return model, history

# !rm -rf model
model, history = buildModel()
plot_result(model, history)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 241, 241, 64)      49216
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 120, 120, 64)      0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 105, 105, 128)     2097280
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 52, 52, 128)       0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 37, 37, 256)       8388864
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 18, 18, 256)       0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               21233920
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 31,770,308
# Trainable params: 31,770,308
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 872/872 [==============================] - 95s 108ms/step - loss: 9361559.2768 - accuracy: 0.2920 - val_loss: 2146.4927 - val_accuracy: 0.3378
#
# Epoch 00001: val_accuracy improved from -inf to 0.33784, saving model to /content/model/weight_model_01_2847245.25_0.31_2146.49_0.34.hdf5
# Epoch 2/100
# 872/872 [==============================] - 94s 108ms/step - loss: 1276.7870 - accuracy: 0.3807 - val_loss: 598.6663 - val_accuracy: 0.3885
#
# Epoch 00002: val_accuracy improved from 0.33784 to 0.38851, saving model to /content/model/weight_model_02_1006.52_0.39_598.67_0.39.hdf5
# Epoch 3/100
# 872/872 [==============================] - 95s 109ms/step - loss: 661.3460 - accuracy: 0.4062 - val_loss: 541.2224 - val_accuracy: 0.3412
#
# Epoch 00003: val_accuracy did not improve from 0.38851
# Epoch 4/100
# 872/872 [==============================] - 95s 109ms/step - loss: 578.7182 - accuracy: 0.3996 - val_loss: 342.7655 - val_accuracy: 0.4020
#
# Epoch 00004: val_accuracy improved from 0.38851 to 0.40203, saving model to /content/model/weight_model_04_649.32_0.40_342.77_0.40.hdf5
# Epoch 5/100
# 872/872 [==============================] - 94s 108ms/step - loss: 625.1560 - accuracy: 0.4089 - val_loss: 240.7189 - val_accuracy: 0.4527
#
# Epoch 00005: val_accuracy improved from 0.40203 to 0.45270, saving model to /content/model/weight_model_05_497.82_0.42_240.72_0.45.hdf5
# Epoch 6/100
# 872/872 [==============================] - 95s 109ms/step - loss: 396.1057 - accuracy: 0.4390 - val_loss: 277.6900 - val_accuracy: 0.5000
#
# Epoch 00006: val_accuracy improved from 0.45270 to 0.50000, saving model to /content/model/weight_model_06_358.90_0.43_277.69_0.50.hdf5
# Epoch 7/100
# 872/872 [==============================] - 95s 109ms/step - loss: 201.5583 - accuracy: 0.5409 - val_loss: 107.9650 - val_accuracy: 0.4696
#
# Epoch 00007: val_accuracy did not improve from 0.50000
# Epoch 8/100
# 872/872 [==============================] - 95s 108ms/step - loss: 50.6767 - accuracy: 0.6789 - val_loss: 91.7133 - val_accuracy: 0.3818
#
# Epoch 00008: val_accuracy did not improve from 0.50000
# Epoch 9/100
# 872/872 [==============================] - 94s 108ms/step - loss: 31.1895 - accuracy: 0.7078 - val_loss: 110.3299 - val_accuracy: 0.4324
#
# Epoch 00009: val_accuracy did not improve from 0.50000
# Epoch 10/100
# 872/872 [==============================] - 94s 108ms/step - loss: 77327325.9911 - accuracy: 0.4943 - val_loss: 138090.7031 - val_accuracy: 0.3480
#
# Epoch 00010: val_accuracy did not improve from 0.50000
# Epoch 11/100
# 872/872 [==============================] - 94s 108ms/step - loss: 157367.0218 - accuracy: 0.3567 - val_loss: 91541.1875 - val_accuracy: 0.3750
#
# Epoch 00011: val_accuracy did not improve from 0.50000
# Epoch 12/100
# 872/872 [==============================] - 95s 109ms/step - loss: 204384.5867 - accuracy: 0.3769 - val_loss: 35437.8359 - val_accuracy: 0.4020
#
# Epoch 00012: val_accuracy did not improve from 0.50000
# Epoch 13/100
# 872/872 [==============================] - 95s 109ms/step - loss: 110011.2808 - accuracy: 0.3588 - val_loss: 111039.0469 - val_accuracy: 0.3209
#
# Epoch 00013: val_accuracy did not improve from 0.50000
# Epoch 14/100
# 872/872 [==============================] - 95s 109ms/step - loss: 68776.7055 - accuracy: 0.4016 - val_loss: 17796.9863 - val_accuracy: 0.4122
#
# Epoch 00014: val_accuracy did not improve from 0.50000
# Epoch 15/100
# 872/872 [==============================] - 96s 110ms/step - loss: 43567.4432 - accuracy: 0.3767 - val_loss: 60948.5273 - val_accuracy: 0.2838
#
# Epoch 00015: val_accuracy did not improve from 0.50000
# Epoch 16/100
# 872/872 [==============================] - 95s 109ms/step - loss: 69320.0349 - accuracy: 0.3173 - val_loss: 14946.7383 - val_accuracy: 0.3818
#
# Epoch 00016: val_accuracy did not improve from 0.50000
# Epoch 17/100
# 872/872 [==============================] - 95s 109ms/step - loss: 13016.4909 - accuracy: 0.3861 - val_loss: 9239.7275 - val_accuracy: 0.3176
#
# Epoch 00017: val_accuracy did not improve from 0.50000
# Epoch 18/100
# 872/872 [==============================] - 95s 109ms/step - loss: 82805275.9865 - accuracy: 0.3958 - val_loss: 367785.2812 - val_accuracy: 0.2534
#
# Epoch 00018: val_accuracy did not improve from 0.50000
# Epoch 19/100
# 872/872 [==============================] - 95s 108ms/step - loss: 428274.2415 - accuracy: 0.3261 - val_loss: 347793.1875 - val_accuracy: 0.2770
#
# Epoch 00019: val_accuracy did not improve from 0.50000
# Epoch 20/100
# 872/872 [==============================] - 95s 109ms/step - loss: 193918.4094 - accuracy: 0.2991 - val_loss: 232572.8438 - val_accuracy: 0.3547
#
# Epoch 00020: val_accuracy did not improve from 0.50000
# Epoch 21/100
# 872/872 [==============================] - 94s 108ms/step - loss: 184546.2812 - accuracy: 0.3492 - val_loss: 99538.0547 - val_accuracy: 0.3480
#
# Epoch 00021: val_accuracy did not improve from 0.50000
# Epoch 22/100
# 872/872 [==============================] - 94s 108ms/step - loss: 111763.8413 - accuracy: 0.3337 - val_loss: 168447.2656 - val_accuracy: 0.3007
#
# Epoch 00022: val_accuracy did not improve from 0.50000
# Epoch 23/100
# 872/872 [==============================] - 95s 109ms/step - loss: 103230.2124 - accuracy: 0.3664 - val_loss: 15247.3174 - val_accuracy: 0.3885
#
# Epoch 00023: val_accuracy did not improve from 0.50000
# Epoch 24/100
# 872/872 [==============================] - 95s 109ms/step - loss: 29336.7660 - accuracy: 0.3603 - val_loss: 23694.4551 - val_accuracy: 0.2838
#
# Epoch 00024: val_accuracy did not improve from 0.50000
# Epoch 25/100
# 872/872 [==============================] - 95s 109ms/step - loss: 25969.5206 - accuracy: 0.4010 - val_loss: 19123.2656 - val_accuracy: 0.3446
#
# Epoch 00025: val_accuracy did not improve from 0.50000
# Epoch 26/100
# 872/872 [==============================] - 95s 109ms/step - loss: 9242.6783 - accuracy: 0.3782 - val_loss: 4726.6509 - val_accuracy: 0.3750
#
# Epoch 00026: val_accuracy did not improve from 0.50000
# Epoch 27/100
# 872/872 [==============================] - 95s 109ms/step - loss: 3295.5279 - accuracy: 0.4629 - val_loss: 1593.2054 - val_accuracy: 0.4696
#
# Epoch 00027: val_accuracy did not improve from 0.50000
# Epoch 28/100
# 872/872 [==============================] - 95s 109ms/step - loss: 95123678.6567 - accuracy: 0.3472 - val_loss: 718374.1875 - val_accuracy: 0.3209
#
# Epoch 00028: val_accuracy did not improve from 0.50000
# Epoch 29/100
# 872/872 [==============================] - 95s 108ms/step - loss: 357473.2370 - accuracy: 0.2975 - val_loss: 134369.4062 - val_accuracy: 0.3615
#
# Epoch 00029: val_accuracy did not improve from 0.50000
# Epoch 30/100
# 872/872 [==============================] - 95s 109ms/step - loss: 175795.2272 - accuracy: 0.2973 - val_loss: 216568.3438 - val_accuracy: 0.2872
#
# Epoch 00030: val_accuracy did not improve from 0.50000
# Epoch 31/100
# 872/872 [==============================] - 95s 109ms/step - loss: 131718.3147 - accuracy: 0.3307 - val_loss: 38876.7773 - val_accuracy: 0.4054
#
# Epoch 00031: val_accuracy did not improve from 0.50000
# Epoch 32/100
# 872/872 [==============================] - 95s 109ms/step - loss: 101767.6573 - accuracy: 0.3418 - val_loss: 80666.4219 - val_accuracy: 0.3311
#
# Epoch 00032: val_accuracy did not improve from 0.50000
# Epoch 33/100
# 872/872 [==============================] - 95s 109ms/step - loss: 96868.7731 - accuracy: 0.3476 - val_loss: 26322.4121 - val_accuracy: 0.4054
#
# Epoch 00033: val_accuracy did not improve from 0.50000
# Epoch 34/100
# 872/872 [==============================] - 95s 109ms/step - loss: 88563.3371 - accuracy: 0.3526 - val_loss: 36319.6797 - val_accuracy: 0.3784
#
# Epoch 00034: val_accuracy did not improve from 0.50000
# Epoch 35/100
# 872/872 [==============================] - 95s 109ms/step - loss: 34979.5886 - accuracy: 0.4036 - val_loss: 10575.9189 - val_accuracy: 0.4493
#
# Epoch 00035: val_accuracy did not improve from 0.50000
# Epoch 36/100
# 872/872 [==============================] - 95s 109ms/step - loss: 57515.1673 - accuracy: 0.3496 - val_loss: 8737.4160 - val_accuracy: 0.4392
#
# Epoch 00036: val_accuracy did not improve from 0.50000
# Epoch 37/100
# 872/872 [==============================] - 95s 110ms/step - loss: 6980.5730 - accuracy: 0.4426 - val_loss: 9018700.0000 - val_accuracy: 0.2500
#
# Epoch 00037: val_accuracy did not improve from 0.50000
# Epoch 38/100
# 872/872 [==============================] - 95s 109ms/step - loss: 242105293.5315 - accuracy: 0.2325 - val_loss: 130056.5234 - val_accuracy: 0.2770
#
# Epoch 00038: val_accuracy did not improve from 0.50000
# Epoch 39/100
# 872/872 [==============================] - 95s 109ms/step - loss: 104110.0237 - accuracy: 0.3178 - val_loss: 39569.6211 - val_accuracy: 0.3885
#
# Epoch 00039: val_accuracy did not improve from 0.50000
# Epoch 40/100
# 872/872 [==============================] - 96s 110ms/step - loss: 64437.0479 - accuracy: 0.3565 - val_loss: 79588.4219 - val_accuracy: 0.3311
#
# Epoch 00040: val_accuracy did not improve from 0.50000
# Epoch 41/100
# 872/872 [==============================] - 96s 110ms/step - loss: 79633.8504 - accuracy: 0.3529 - val_loss: 116668.9062 - val_accuracy: 0.2534
#
# Epoch 00041: val_accuracy did not improve from 0.50000
# Epoch 42/100
# 872/872 [==============================] - 95s 109ms/step - loss: 51189.4089 - accuracy: 0.3375 - val_loss: 35229.2148 - val_accuracy: 0.4257
#
# Epoch 00042: val_accuracy did not improve from 0.50000
# Epoch 43/100
# 872/872 [==============================] - 95s 109ms/step - loss: 41547.6953 - accuracy: 0.3406 - val_loss: 23808.5449 - val_accuracy: 0.3750
#
# Epoch 00043: val_accuracy did not improve from 0.50000
# Epoch 44/100
# 872/872 [==============================] - 95s 109ms/step - loss: 13021.4790 - accuracy: 0.4077 - val_loss: 5433.6899 - val_accuracy: 0.4628
#
# Epoch 00044: val_accuracy did not improve from 0.50000
# Epoch 45/100
# 872/872 [==============================] - 96s 110ms/step - loss: 4852.1040 - accuracy: 0.4073 - val_loss: 10940.1250 - val_accuracy: 0.2939
#
# Epoch 00045: val_accuracy did not improve from 0.50000
# Epoch 46/100
# 872/872 [==============================] - 95s 110ms/step - loss: 529819786.2481 - accuracy: 0.3703 - val_loss: 3142042.7500 - val_accuracy: 0.3277
#
# Epoch 00046: val_accuracy did not improve from 0.50000
# Epoch 47/100
# 872/872 [==============================] - 95s 109ms/step - loss: 4705489.5682 - accuracy: 0.2803 - val_loss: 468322.9062 - val_accuracy: 0.3953
#
# Epoch 00047: val_accuracy did not improve from 0.50000
# Epoch 48/100
# 872/872 [==============================] - 96s 110ms/step - loss: 1113289.7904 - accuracy: 0.2964 - val_loss: 2916121.5000 - val_accuracy: 0.2669
#
# Epoch 00048: val_accuracy did not improve from 0.50000
# Epoch 49/100
# 872/872 [==============================] - 95s 109ms/step - loss: 1553537.1874 - accuracy: 0.3321 - val_loss: 885745.8125 - val_accuracy: 0.3108
#
# Epoch 00049: val_accuracy did not improve from 0.50000
# Epoch 50/100
# 852/872 [============================>.] - ETA: 1s - loss: 887856.8299 - accuracy: 0.2974
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-cc6256e18c69> in <module>()
#      91
#      92 get_ipython().system('rm -rf model')
# ---> 93 model, history = buildModel()
#      94 plot_result(model, history)
#
# <ipython-input-16-cc6256e18c69> in buildModel()
#      85     validation_data=validation_generator,
#      86     epochs=100,
# ---> 87     callbacks=callback_list
#      88   )
#      89
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1859         use_multiprocessing=use_multiprocessing,
#    1860         shuffle=shuffle,
# -> 1861         initial_epoch=initial_epoch)
#    1862
#    1863   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1103               logs = tmp_logs  # No error, now safe to assign to logs.
#    1104               end_step = step + data_handler.step_increment
# -> 1105               callbacks.on_train_batch_end(end_step, logs)
#    1106               if self.stop_training:
#    1107                 break
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     452     """
#     453     if self._should_call_train_batch_hooks:
# --> 454       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     455
#     456   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     294       self._call_batch_begin_hook(mode, batch, logs)
#     295     elif hook == 'end':
# --> 296       self._call_batch_end_hook(mode, batch, logs)
#     297     else:
#     298       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354       hook = getattr(callback, hook_name)
#     355       if getattr(callback, '_supports_tf_logs', False):
# --> 356         hook(batch, logs)
#     357       else:
#     358         if numpy_logs is None:  # Only convert once.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1018
#    1019   def on_train_batch_end(self, batch, logs=None):
# -> 1020     self._batch_update_progbar(batch, logs)
#    1021
#    1022   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1082     if self.verbose == 1:
#    1083       # Only block async when verbose = 1.
# -> 1084       logs = tf_utils.to_numpy_or_python_type(logs)
#    1085       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1086
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#     513
# --> 514   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     515
#     516
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     508   def _to_single_numpy_or_python_type(t):
#     509     if isinstance(t, ops.Tensor):
# --> 510       x = t.numpy()
#     511       return x.item() if np.ndim(x) == 0 else x
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1069     """
#    1070     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1071     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1072     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1073
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1035   def _numpy(self):
#    1036     try:
# -> 1037       return self._numpy_internal()
#    1038     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1039       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
def load_model(struct, weight):
  json_file = open("model/" + struct + ".json", "r")
  loaded_model_json = json_file.read()
  json_file.close()

  loaded_model = model_from_json(loaded_model_json)
  loaded_model.load_weights("model/" + weight + ".hdf5")
  loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  return loaded_model

lastCheckpoint = sorted(Path("/content/model").iterdir(), key=os.path.getmtime)[-1].stem
print("Model is " + lastCheckpoint)

loaded_model = load_model("struct_model", lastCheckpoint)
# Out:
# Model is weight_model_713_18886.62_0.61_495903.19_0.68

# %% [markdown]
# # Testing

# %%
# train_loss, train_accuracy = loaded_model.evaluate(x_train, y_train)
# val_loss, val_accuracy = loaded_model.evaluate(x_val, y_val)
# test_loss, test_accuracy = loaded_model.evaluate(x_test, y_test)

# print(
#     ""
#     "\n"
#     "Train Loss: " + str(train_loss) + "\n"
#     "Train Accuracy: " + str(train_accuracy * 100) + "%\n"
#     "\n"
#     "Validation Loss: " + str(val_loss) + "\n"
#     "Validation Accuracy: " + str(val_accuracy * 100) + "%\n"
#     "\n"
#     "Test Loss: " + str(test_loss) + "\n"
#     "Test Accuracy: " + str(test_accuracy * 100) + "%"
#     "")
# Out:
# 13/13 [==============================] - 0s 19ms/step - loss: 4.8931 - accuracy: 0.3025
# 5/5 [==============================] - 0s 14ms/step - loss: 9.1233 - accuracy: 0.2879
# 5/5 [==============================] - 0s 13ms/step - loss: 3.7129 - accuracy: 0.2929
#
# Train Loss: 4.893118381500244
# Train Accuracy: 30.250000953674316%
#
# Validation Loss: 9.123268127441406
# Validation Accuracy: 28.787878155708313%
#
# Test Loss: 3.712925434112549
# Test Accuracy: 29.285714030265808%

# %%
test_generator = ImageDataGenerator()
test_data = test_generator.flow_from_directory(
    directory="image/test/",
    batch_size=1,
    class_mode="categorical",
    shuffle=True,
    target_size=(256, 256)
)

loss, accuracy = model.evaluate_generator(generator=test_data)
print(
    ""
    "Prediction Loss: %2d\n"
    "Prediction Accuracy: %2d%%"
    ""
    % (loss, accuracy * 100))

# %% [markdown]
# # Analysis

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

y_decoded = []
for pred in y_test:
  decoded = np.where(pred == 1)[0][0]
  y_decoded.append(decoded)

print('Confusion Matrix')
print(target_names)
print(confusion_matrix(y_decoded, y_pred))
print(x_test.shape)

print('\n\nClassification Report')
print(classification_report(y_decoded, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# ['neu', 'ang', 'hap', 'sad']
# [[ 3  2  7  3]
#  [ 2  6  6  3]
#  [ 7  3  5  3]
#  [ 3  0  4 10]]
# (67, 128, 50)
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#          neu       0.20      0.20      0.20        15
#          ang       0.55      0.35      0.43        17
#          hap       0.23      0.28      0.25        18
#          sad       0.53      0.59      0.56        17
#
#     accuracy                           0.36        67
#    macro avg       0.37      0.35      0.36        67
# weighted avg       0.38      0.36      0.36        67

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_data.classes, y_pred))

print('\n\nClassification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
