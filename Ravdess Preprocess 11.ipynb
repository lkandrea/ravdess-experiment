# %% [markdown]
# # Prepare Data

# %%
import tensorflow as tf
import cv2

from numba import cuda 

from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input, Softmax, Conv1D, MaxPooling1D, Activation
from keras.engine.saving import model_from_json
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils.vis_utils import plot_model
from keras.layers.normalization import BatchNormalization
from keras_preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import MinMaxScaler

from skimage.restoration import denoise_wavelet

from pathlib import Path

from google.colab import files
from google.colab import drive

import os
import sys

import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

import librosa
import librosa.display

# %%
drive.mount('/content/gdrive', force_remount=True)
iemocap = "gdrive/My Drive/Public/IEMOCAP_full_release"

print("GPU Name: ", tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Mounted at /content/gdrive
# GPU Name:  /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# # Convert into CSV

# %%
sessions = ["Session1", "Session2", "Session3", "Session4", "Session5"]

def convertSession(session_name):
  session_file = iemocap + "/Duration/Processed/" + session_name + ".txt"
  tokenized_lines = []

  with open(session_file) as f:
    lines = f.readlines()
    tokenizedLines = [x.split() for x in lines]

  session_csv = iemocap + "/Duration/Processed/" + session_name + ".csv"
  with open(session_csv, "w") as csv:
    audio_name = ''

    for line in tokenizedLines:
      if line[0] == "Recording":
        audio_name = line[1]
      else:
        csv.write(audio_name + ";" + line[0] + ";" + line[1] + "\n")

def convertRawToCsv():
  for session in sessions:
    convertSession(session)

# convertRawToCsv()

# %% [markdown]
# # Convert into data frame

# %%
def getSessionData(session_name):
  df = pd.read_csv(iemocap + "/Duration/Processed/" + session_name + ".csv", delimiter=";", header=None)
  df.columns = ["Audio Name", "Part", "Duration"]
  print(session_name + " count: " + str(len(df.index)))

  return df

def getDataFrame():
  result = pd.DataFrame()

  for session in sessions:
    df = getSessionData(session)
    result = result.append(df, ignore_index=True)

  return result

result = getDataFrame()
result["Duration"] = result["Duration"].apply(np.floor).astype(int)
result
# Out:
# Session1 count: 1819
# Session2 count: 1811
# Session3 count: 2136
# Session4 count: 2103
# Session5 count: 2170
#               Audio Name  Part  Duration
# 0         Ses01F_impro01  F000         1
# 1         Ses01F_impro01  F001         1
# 2         Ses01F_impro01  F002         3
# 3         Ses01F_impro01  F003         1
# 4         Ses01F_impro01  F004         3
# ...                  ...   ...       ...
# 10034  Ses05M_script03_2  M041         8
# 10035  Ses05M_script03_2  M042         1
# 10036  Ses05M_script03_2  M043         2
# 10037  Ses05M_script03_2  M044         4
# 10038  Ses05M_script03_2  M045         6
#
# [10039 rows x 3 columns]

# %% [markdown]
# # Plot

# %%
plot = seaborn.countplot(x='Duration', data=result)
plot.figure.set_size_inches(13,13)

for p in plot.patches:
  height = p.get_height()
  plot.text(p.get_x() + p.get_width()/2., height + 10, '{:1.0f}'.format(height), ha="center")

# %%
print("Original data: " + str(result.count()))

count_data = result.value_counts(subset=['Duration'], sort=False).values
count_normalize = result.value_counts(subset=['Duration'], sort=False, normalize=True).values
duration = sorted(result.Duration.unique())

count_df = pd.DataFrame({"Duration": duration, "Count": count_data, "Percentage": count_normalize})
count_df.Percentage = (count_df.Percentage * 100).round(3)
# Out:
# Original data: Audio Name     10039
# Part           10039
# Duration       10039
# Evaluation1        0
# Evaluation2        0
# Evaluation3        0
# Evaluation4        0
# Evaluation5        0
# Evaluation6        0
# Emotion        10039
# dtype: int64
#     Duration  Count  Percentage
# 0          0     50       0.498
# 1          1   1650      16.436
# 2          2   2341      23.319
# 3          3   1717      17.103
# 4          4   1148      11.435
# 5          5    828       8.248
# 6          6    682       6.794
# 7          7    449       4.473
# 8          8    322       3.207
# 9          9    249       2.480
# 10        10    175       1.743
# 11        11    116       1.155
# 12        12    101       1.006
# 13        13     52       0.518
# 14        14     51       0.508
# 15        15     38       0.379
# 16        16     21       0.209
# 17        17     12       0.120
# 18        18     11       0.110
# 19        19      5       0.050
# 20        20      4       0.040
# 21        21      2       0.020
# 22        22      2       0.020
# 23        23      4       0.040
# 24        24      2       0.020
# 25        25      1       0.010
# 26        26      2       0.020
# 27        29      2       0.020
# 28        31      1       0.010
# 29        34      1       0.010

# %% [markdown]
# # Labeling

# %%
def resetEvaluation():
  result["Emotion"] = None

def goLabeling():
  for session in sessions:
    emotion_path = iemocap + "/" + session + "/dialog/EmoEvaluation/"

    recordings = [file.name for file in os.scandir(emotion_path) if ".txt" in file.name]
    recordings.sort()
    
    for recording in recordings:
      with open(emotion_path + recording) as f:
        lines = f.readlines()
        tokenizedLines = [x.split() for x in lines if "Ses0" in x]

        for part in tokenizedLines:
          line_name = part[3]
          line_label = part[4]
          line_queries = line_name.split("_")
          
          line_part = line_queries[-1]
          line_queries.remove(line_part)

          line_name = "_".join(line_queries)

          search_query_name = ""
          search_query_part = line_queries[-1]
          search_result = result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"]
          search_count = search_result.shape[0]
          
          if search_count == 0:
            print("ERROR: No audio part found: ")
          elif search_count > 1:
            print("ERROR: Multiple audio found: ")
          else:
            result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"] = line_label

def getClassificationReport():
  max_duration = 7

  categorical_data = result.loc[
    (result["Duration"] < max_duration + 1) &
    (
      (result["Emotion"] == 'neu') |
      (result["Emotion"] == 'ang') |
      (result["Emotion"] == 'hap') |
      (result["Emotion"] == 'sad') 
    )
  ]
  
  categorical_plot = seaborn.countplot(x="Emotion", hue="Duration", data=categorical_data)
  categorical_plot.figure.set_size_inches(13,13)

  for p in categorical_plot.patches:
    height = p.get_height()
    categorical_plot.text(p.get_x() + p.get_width()/2., height + 3, '{:1.0f}'.format(height), ha="center") 

  return categorical_data

resetEvaluation()
goLabeling()
categorical_data = getClassificationReport()

# %% [markdown]
# # Selection and Splitting

# %%
def checkAndCreateDirectory(filename):
  if not os.path.exists(os.path.dirname(filename)):
    try:
        os.makedirs(os.path.dirname(filename))
    except OSError as exc: # Guard against race condition
        print(exc.errno)
        if exc.errno != errno.EEXIST:
            raise

def getMfccValue(audio_path, row, dataset_type):
  audio_file, sample_rate = librosa.load(audio_path)
  # audio_file = denoise_wavelet(audio_file, method='VisuShrink', rescale_sigma=True)

  S = librosa.feature.mfcc(y=audio_file, sr=16000)
  # S[S < (np.average(S) * 1.8)] = np.average(S) * 0.1

  # librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

  # filename = "image/" + dataset_type + "/" + row["Emotion"] + "/" + row["Audio Name"] + "_" + row["Part"] + '.png'
  # checkAndCreateDirectory(filename)

  # plt.gca().set_axis_off()
  # plt.savefig(filename, dpi=100, bbox_inches='tight',pad_inches=0)
  # # plt.show()
  # plt.clf()
  # plt.close('all')

  return S

def getEncodedLabel(label):
  label_hot = [0, 0, 0, 0]
  
  if    (label == "neu"): label_hot = [1, 0, 0, 0]
  elif  (label == "ang"): label_hot = [0, 1, 0, 0]
  elif  (label == "hap"): label_hot = [0, 0, 1, 0]
  elif  (label == "sad"): label_hot = [0, 0, 0, 1]

  np.where(np.array(label_hot) == 1)[0][0]
  return np.array(label_hot)

def getAudioPath(row):
  audio_prefix = row["Audio Name"][:5]
  audio_session = "Error"

  if    (audio_prefix == 'Ses01'): audio_session = "Session1"
  elif  (audio_prefix == 'Ses02'): audio_session = "Session2"
  elif  (audio_prefix == 'Ses03'): audio_session = "Session3"
  elif  (audio_prefix == 'Ses04'): audio_session = "Session4"
  elif  (audio_prefix == 'Ses05'): audio_session = "Session5"

  audio_path = iemocap + '/' + audio_session + '/sentences/wav/' + row["Audio Name"] + '/' + row["Audio Name"] + '_' + row["Part"] + '.wav'
  return audio_path

def getVectorAudio(base_duration, durationed_data, dataset_type):
  X = [] # Data
  Y = [] # Label

  durationed_length = len(durationed_data)

  # Iterate every data
  for index, row in durationed_data.iterrows():
    print("Saving " + str(durationed_length) + " " + str(index), end=" | ")

    if durationed_length % 30 == 0: print("\n")
    durationed_length -= 1

    # Get Label
    label = row["Emotion"]
    label_hot = getEncodedLabel(label)

    # Get Mfcc
    audio_path = getAudioPath(row)
    mfcc = getMfccValue(audio_path, row, dataset_type)
    
    X.append(np.mean(mfcc.T, axis=0))
    Y.append(label_hot)
    
    # mfcc_length = mfcc.shape[1]

    # mfcc_slice = 50 * base_duration

    # for mfcc_partial in range(int(mfcc_length/mfcc_slice)):
    #   start = mfcc_partial * mfcc_slice
    #   end = (mfcc_partial + 1) * mfcc_slice

    #   mfcc_partial_result = np.pad(mfcc, pad_width=((0,0), (0, (mfcc_slice - (mfcc_length % mfcc_slice)))), mode='constant')
    #   mfcc_partial_result = mfcc_partial_result[:,start:end]

    #   if (mfcc_partial_result.shape[1] != mfcc_slice) | (mfcc_partial_result.shape[0] != 128):
    #     print("ERROR Mfcc " + str(index) + str(row))
    #     print("ERROR Mfcc " + index + row)
    #     break
      
    #   X.append(mfcc_partial_result)
    #   Y.append(label_hot)

  return np.array(X), np.array(Y)

def testDuration():
  audio_file, sample_rate = librosa.load('/content/gdrive/My Drive/Public/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro04/Ses01F_impro04_M008.wav')
  duration = librosa.get_duration(y=audio_file, sr=sample_rate)
  print(duration)

  S = librosa.feature.mfcc(y=audio_file, sr=48000)
  print(S.shape)

def getEmotionSplitting(base_duration, max_duration):
  train_data    = pd.DataFrame()
  val_data      = pd.DataFrame()
  test_data     = pd.DataFrame()

  for iterate_index in range(base_duration, max_duration + 1):
    neutral_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'neu')
    ]

    angry_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'ang')
    ]

    sad_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'sad')
    ]

    happy_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'hap')
    ]
    
    print("Duration " + str(iterate_index))
    print("Neutral " + str(neutral_duration.shape[0]))
    print("Angry " + str(angry_duration.shape[0]))
    print("Sad " + str(sad_duration.shape[0]))
    print("Happy " + str(happy_duration.shape[0]))
    print()

    sample_lowest = min(neutral_duration.shape[0], angry_duration.shape[0], sad_duration.shape[0], happy_duration.shape[0])

    neutral_duration  = neutral_duration.sample(sample_lowest)
    angry_duration    = angry_duration.sample(sample_lowest)
    sad_duration      = sad_duration.sample(sample_lowest)
    happy_duration    = happy_duration.sample(sample_lowest)

    # Splitting # 0,6 : 0,8 : 1,0 (60%, 20%, 20%)
    data_training_percent   = int(0.6 * sample_lowest)
    data_validation_percent = int(0.8 * sample_lowest)

    train_data = train_data.append(neutral_duration [:data_training_percent])
    train_data = train_data.append(angry_duration   [:data_training_percent])
    train_data = train_data.append(sad_duration     [:data_training_percent])
    train_data = train_data.append(happy_duration   [:data_training_percent])

    val_data = val_data.append(neutral_duration   [data_training_percent:data_validation_percent])
    val_data = val_data.append(angry_duration     [data_training_percent:data_validation_percent])
    val_data = val_data.append(sad_duration       [data_training_percent:data_validation_percent])
    val_data = val_data.append(happy_duration     [data_training_percent:data_validation_percent])

    test_data = test_data.append(neutral_duration     [data_validation_percent:sample_lowest])
    test_data = test_data.append(angry_duration       [data_validation_percent:sample_lowest])
    test_data = test_data.append(sad_duration         [data_validation_percent:sample_lowest])
    test_data = test_data.append(happy_duration       [data_validation_percent:sample_lowest])

  return train_data.sample(frac=1), val_data.sample(frac=1), test_data.sample(frac=1)

base_duration = 2
max_duration = 2

train_data, val_data, test_data = getEmotionSplitting(base_duration, max_duration)
# !rm -rf image

# In vector and save image
x_train, y_train  = getVectorAudio(base_duration, train_data, "train")
x_val, y_val      = getVectorAudio(base_duration, val_data, "val")
x_test, y_test    = getVectorAudio(base_duration, test_data, "test")
# Out:
# Duration 2
# Neutral 419
# Angry 266
# Sad 221
# Happy 156
#
# Saving 372 5024 | Saving 371 8382 | Saving 370 1647 | Saving 369 6480 | Saving 368 633 | Saving 367 8526 | Saving 366 9268 | Saving 365 7952 | Saving 364 8659 | Saving 363 10032 | Saving 362 166 | Saving 361 7560 | Saving 360 654 |
#
# Saving 359 1700 | Saving 358 5008 | Saving 357 1656 | Saving 356 1194 | Saving 355 5740 | Saving 354 4644 | Saving 353 9111 | Saving 352 6365 | Saving 351 8958 | Saving 350 7139 | Saving 349 6280 | Saving 348 7395 | Saving 347 5941 | Saving 346 3915 | Saving 345 1730 | Saving 344 7759 | Saving 343 6427 | Saving 342 6792 | Saving 341 1362 | Saving 340 3490 | Saving 339 5949 | Saving 338 4245 | Saving 337 3907 | Saving 336 1688 | Saving 335 7055 | Saving 334 3800 | Saving 333 10030 | Saving 332 2993 | Saving 331 2966 | Saving 330 6852 |
#
# Saving 329 4701 | Saving 328 101 | Saving 327 7998 | Saving 326 545 | Saving 325 1204 | Saving 324 8029 | Saving 323 6627 | Saving 322 8663 | Saving 321 2560 | Saving 320 1167 | Saving 319 5530 | Saving 318 4229 | Saving 317 1711 | Saving 316 481 | Saving 315 5553 | Saving 314 2501 | Saving 313 1148 | Saving 312 4507 | Saving 311 1652 | Saving 310 3168 | Saving 309 1448 | Saving 308 4244 | Saving 307 9685 | Saving 306 8580 | Saving 305 8483 | Saving 304 1672 | Saving 303 6492 | Saving 302 1456 | Saving 301 9966 | Saving 300 7798 |
#
# Saving 299 2653 | Saving 298 1766 | Saving 297 7287 | Saving 296 2667 | Saving 295 3876 | Saving 294 6347 | Saving 293 8361 | Saving 292 3808 | Saving 291 4283 | Saving 290 7321 | Saving 289 2331 | Saving 288 7456 | Saving 287 3945 | Saving 286 5023 | Saving 285 483 | Saving 284 1430 | Saving 283 2311 | Saving 282 7455 | Saving 281 5939 | Saving 280 3930 | Saving 279 102 | Saving 278 10002 | Saving 277 9702 | Saving 276 9877 | Saving 275 1810 | Saving 274 3088 | Saving 273 1803 | Saving 272 3820 | Saving 271 4583 | Saving 270 9439 |
#
# Saving 269 2376 | Saving 268 3504 | Saving 267 608 | Saving 266 3214 | Saving 265 1591 | Saving 264 2602 | Saving 263 7988 | Saving 262 7325 | Saving 261 3598 | Saving 260 6407 | Saving 259 5982 | Saving 258 8587 | Saving 257 2569 | Saving 256 6035 | Saving 255 244 | Saving 254 3534 | Saving 253 3154 | Saving 252 9541 | Saving 251 6752 | Saving 250 10027 | Saving 249 2512 | Saving 248 3496 | Saving 247 2408 | Saving 246 8317 | Saving 245 2570 | Saving 244 9901 | Saving 243 4176 | Saving 242 4187 | Saving 241 9115 | Saving 240 5013 |
#
# Saving 239 2599 | Saving 238 1739 | Saving 237 5073 | Saving 236 1952 | Saving 235 3928 | Saving 234 707 | Saving 233 2222 | Saving 232 8457 | Saving 231 2566 | Saving 230 5033 | Saving 229 1686 | Saving 228 1813 | Saving 227 6263 | Saving 226 1031 | Saving 225 1452 | Saving 224 1962 | Saving 223 2498 | Saving 222 1047 | Saving 221 9699 | Saving 220 7050 | Saving 219 4935 | Saving 218 4236 | Saving 217 957 | Saving 216 8170 | Saving 215 3536 | Saving 214 9167 | Saving 213 5601 | Saving 212 176 | Saving 211 3712 | Saving 210 1086 |
#
# Saving 209 1748 | Saving 208 792 | Saving 207 1282 | Saving 206 3089 | Saving 205 8033 | Saving 204 9466 | Saving 203 8826 | Saving 202 4683 | Saving 201 807 | Saving 200 834 | Saving 199 9161 | Saving 198 1201 | Saving 197 3184 | Saving 196 1582 | Saving 195 7205 | Saving 194 7919 | Saving 193 695 | Saving 192 5059 | Saving 191 9880 | Saving 190 6491 | Saving 189 9725 | Saving 188 8121 | Saving 187 3615 | Saving 186 2756 | Saving 185 6871 | Saving 184 2556 | Saving 183 749 | Saving 182 4688 | Saving 181 1988 | Saving 180 3157 |
#
# Saving 179 2186 | Saving 178 8945 | Saving 177 3587 | Saving 176 6867 | Saving 175 2770 | Saving 174 8127 | Saving 173 9110 | Saving 172 1328 | Saving 171 793 | Saving 170 1242 | Saving 169 4933 | Saving 168 1207 | Saving 167 68 | Saving 166 1431 | Saving 165 4173 | Saving 164 3423 | Saving 163 5017 | Saving 162 9455 | Saving 161 4255 | Saving 160 2238 | Saving 159 8456 | Saving 158 646 | Saving 157 4267 | Saving 156 8168 | Saving 155 3888 | Saving 154 3680 | Saving 153 2696 | Saving 152 7926 | Saving 151 6477 | Saving 150 5205 |
#
# Saving 149 4314 | Saving 148 2687 | Saving 147 9300 | Saving 146 148 | Saving 145 7565 | Saving 144 1421 | Saving 143 7785 | Saving 142 3259 | Saving 141 660 | Saving 140 1482 | Saving 139 6326 | Saving 138 8978 | Saving 137 8943 | Saving 136 8360 | Saving 135 4779 | Saving 134 9153 | Saving 133 9742 | Saving 132 1545 | Saving 131 3243 | Saving 130 1455 | Saving 129 3204 | Saving 128 7822 | Saving 127 2231 | Saving 126 475 | Saving 125 8718 | Saving 124 31 | Saving 123 9723 | Saving 122 5436 | Saving 121 9976 | Saving 120 3011 |
#
# Saving 119 8528 | Saving 118 9963 | Saving 117 5400 | Saving 116 2260 | Saving 115 2068 | Saving 114 7762 | Saving 113 5419 | Saving 112 2334 | Saving 111 8563 | Saving 110 8296 | Saving 109 5296 | Saving 108 4753 | Saving 107 5577 | Saving 106 1762 | Saving 105 9325 | Saving 104 9371 | Saving 103 1871 | Saving 102 872 | Saving 101 3049 | Saving 100 4628 | Saving 99 8090 | Saving 98 4207 | Saving 97 5757 | Saving 96 3589 | Saving 95 4111 | Saving 94 9353 | Saving 93 5800 | Saving 92 1261 | Saving 91 1496 | Saving 90 9473 |
#
# Saving 89 8961 | Saving 88 5370 | Saving 87 3894 | Saving 86 7196 | Saving 85 8507 | Saving 84 2320 | Saving 83 110 | Saving 82 4941 | Saving 81 5587 | Saving 80 7454 | Saving 79 6938 | Saving 78 2540 | Saving 77 1027 | Saving 76 9349 | Saving 75 3019 | Saving 74 5020 | Saving 73 970 | Saving 72 7634 | Saving 71 517 | Saving 70 4928 | Saving 69 10001 | Saving 68 73 | Saving 67 1868 | Saving 66 8791 | Saving 65 1363 | Saving 64 5132 | Saving 63 9454 | Saving 62 7123 | Saving 61 1197 | Saving 60 1436 |
#
# Saving 59 2758 | Saving 58 3064 | Saving 57 5753 | Saving 56 4186 | Saving 55 8328 | Saving 54 4904 | Saving 53 9988 | Saving 52 9333 | Saving 51 2219 | Saving 50 7372 | Saving 49 7651 | Saving 48 6250 | Saving 47 1329 | Saving 46 3804 | Saving 45 3923 | Saving 44 9638 | Saving 43 5057 | Saving 42 1416 | Saving 41 4953 | Saving 40 3866 | Saving 39 10028 | Saving 38 3244 | Saving 37 5163 | Saving 36 6371 | Saving 35 2699 | Saving 34 4560 | Saving 33 9810 | Saving 32 1422 | Saving 31 8035 | Saving 30 5374 |
#
# Saving 29 564 | Saving 28 9695 | Saving 27 8804 | Saving 26 6481 | Saving 25 7477 | Saving 24 2319 | Saving 23 862 | Saving 22 7782 | Saving 21 2628 | Saving 20 5542 | Saving 19 7564 | Saving 18 7859 | Saving 17 3463 | Saving 16 7514 | Saving 15 9361 | Saving 14 8047 | Saving 13 4737 | Saving 12 515 | Saving 11 1645 | Saving 10 6091 | Saving 9 3481 | Saving 8 2912 | Saving 7 9128 | Saving 6 8545 | Saving 5 8619 | Saving 4 84 | Saving 3 2157 | Saving 2 7228 | Saving 1 1487 | Saving 124 3450 | Saving 123 4914 | Saving 122 7826 | Saving 121 9658 | Saving 120 7545 |
#
# Saving 119 4270 | Saving 118 4121 | Saving 117 7922 | Saving 116 5810 | Saving 115 4782 | Saving 114 6104 | Saving 113 4339 | Saving 112 1662 | Saving 111 6354 | Saving 110 397 | Saving 109 9960 | Saving 108 4745 | Saving 107 3212 | Saving 106 4228 | Saving 105 5027 | Saving 104 1205 | Saving 103 9745 | Saving 102 8148 | Saving 101 1862 | Saving 100 493 | Saving 99 4795 | Saving 98 9696 | Saving 97 8055 | Saving 96 2129 | Saving 95 6849 | Saving 94 70 | Saving 93 2593 | Saving 92 5506 | Saving 91 9642 | Saving 90 2900 |
#
# Saving 89 2636 | Saving 88 9450 | Saving 87 5418 | Saving 86 5067 | Saving 85 6322 | Saving 84 4243 | Saving 83 6559 | Saving 82 4534 | Saving 81 657 | Saving 80 4947 | Saving 79 7825 | Saving 78 2002 | Saving 77 7445 | Saving 76 8692 | Saving 75 3748 | Saving 74 951 | Saving 73 9515 | Saving 72 5078 | Saving 71 4657 | Saving 70 2351 | Saving 69 2741 | Saving 68 3158 | Saving 67 2970 | Saving 66 4219 | Saving 65 5833 | Saving 64 7376 | Saving 63 219 | Saving 62 4253 | Saving 61 991 | Saving 60 1097 |
#
# Saving 59 1084 | Saving 58 3902 | Saving 57 3247 | Saving 56 968 | Saving 55 656 | Saving 54 9331 | Saving 53 4669 | Saving 52 8691 | Saving 51 804 | Saving 50 7833 | Saving 49 8518 | Saving 48 9296 | Saving 47 6554 | Saving 46 5155 | Saving 45 5505 | Saving 44 7216 | Saving 43 1694 | Saving 42 5406 | Saving 41 2969 | Saving 40 8038 | Saving 39 2343 | Saving 38 9079 | Saving 37 4282 | Saving 36 2262 | Saving 35 7594 | Saving 34 4742 | Saving 33 9839 | Saving 32 3478 | Saving 31 1365 | Saving 30 4993 |
#
# Saving 29 7096 | Saving 28 3951 | Saving 27 4316 | Saving 26 9543 | Saving 25 1154 | Saving 24 9870 | Saving 23 5367 | Saving 22 5371 | Saving 21 958 | Saving 20 3181 | Saving 19 8719 | Saving 18 1295 | Saving 17 8330 | Saving 16 941 | Saving 15 108 | Saving 14 8609 | Saving 13 46 | Saving 12 3499 | Saving 11 9124 | Saving 10 5709 | Saving 9 1570 | Saving 8 1687 | Saving 7 9620 | Saving 6 4235 | Saving 5 9645 | Saving 4 7518 | Saving 3 6397 | Saving 2 6865 | Saving 1 7045 | Saving 128 5739 | Saving 127 209 | Saving 126 1284 | Saving 125 7468 | Saving 124 6449 | Saving 123 8655 | Saving 122 4578 | Saving 121 4747 | Saving 120 6419 |
#
# Saving 119 543 | Saving 118 718 | Saving 117 1808 | Saving 116 6092 | Saving 115 6833 | Saving 114 4249 | Saving 113 2697 | Saving 112 758 | Saving 111 6085 | Saving 110 9169 | Saving 109 4687 | Saving 108 3723 | Saving 107 3875 | Saving 106 5826 | Saving 105 852 | Saving 104 4775 | Saving 103 3729 | Saving 102 3682 | Saving 101 6800 | Saving 100 9451 | Saving 99 1176 | Saving 98 2200 | Saving 97 8907 | Saving 96 5050 | Saving 95 1918 | Saving 94 7633 | Saving 93 2989 | Saving 92 1152 | Saving 91 4647 | Saving 90 5361 |
#
# Saving 89 1080 | Saving 88 2572 | Saving 87 2958 | Saving 86 963 | Saving 85 2335 | Saving 84 5812 | Saving 83 9675 | Saving 82 5353 | Saving 81 7992 | Saving 80 8101 | Saving 79 520 | Saving 78 4181 | Saving 77 5366 | Saving 76 6340 | Saving 75 3592 | Saving 74 10025 | Saving 73 2650 | Saving 72 4338 | Saving 71 377 | Saving 70 3904 | Saving 69 7823 | Saving 68 8562 | Saving 67 2348 | Saving 66 522 | Saving 65 7446 | Saving 64 1360 | Saving 63 1443 | Saving 62 5270 | Saving 61 5701 | Saving 60 1770 |
#
# Saving 59 181 | Saving 58 3744 | Saving 57 4163 | Saving 56 8058 | Saving 55 76 | Saving 54 5239 | Saving 53 3625 | Saving 52 6453 | Saving 51 4643 | Saving 50 426 | Saving 49 3567 | Saving 48 7323 | Saving 47 2289 | Saving 46 2575 | Saving 45 80 | Saving 44 9446 | Saving 43 3470 | Saving 42 485 | Saving 41 4365 | Saving 40 4101 | Saving 39 6019 | Saving 38 1731 | Saving 37 1712 | Saving 36 2282 | Saving 35 3982 | Saving 34 586 | Saving 33 8046 | Saving 32 9618 | Saving 31 4888 | Saving 30 492 |
#
# Saving 29 2634 | Saving 28 801 | Saving 27 3809 | Saving 26 8204 | Saving 25 8665 | Saving 24 3936 | Saving 23 4735 | Saving 22 7929 | Saving 21 4044 | Saving 20 119 | Saving 19 10020 | Saving 18 858 | Saving 17 9655 | Saving 16 3512 | Saving 15 7193 | Saving 14 2577 | Saving 13 380 | Saving 12 2046 | Saving 11 1651 | Saving 10 1092 | Saving 9 9057 | Saving 8 8930 | Saving 7 4050 | Saving 6 3900 | Saving 5 8128 | Saving 4 6498 | Saving 3 3622 | Saving 2 273 | Saving 1 480 |

# %%
audio_file, sample_rate = librosa.load('/content/gdrive/My Drive/Public/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro04/Ses01F_impro04_M002.wav')

S = librosa.feature.melspectrogram(y=audio_file, sr=48000)
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

# %%
S = librosa.feature.melspectrogram(y=audio_file, sr=48000)
S[S < (np.average(S) * 1.)] = 0.001

librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

# %%
def loadGenerator():
  # 352, 235
  train_image_generator = ImageDataGenerator()
  train_data = train_image_generator.flow_from_directory(
      directory="image/train/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(352, 235)
  )
    
  validation_image_generator = ImageDataGenerator()
  validation_data = validation_image_generator.flow_from_directory(
      directory="image/val/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(352, 235)
  )

  test_image_generator = ImageDataGenerator()
  test_data = test_image_generator.flow_from_directory(
      directory="image/test/",
      batch_size=1,
      class_mode="categorical",
      shuffle=True,
      target_size=(352, 235)
  )

  return train_data, validation_data, test_data

# def scaleVector():
#   scaler = MinMaxScaler()

#   x_train_scaled = []
#   x_val_scaled = []

#   for x in x_train:
#     scaler.partial_fit(x)

#   for x in x_val:
#     scaler.partial_fit(x)

#   for x in x_train:
#     x_result = scaler.transform(x)
#     x_train_scaled.append(x_result)

#   for x in x_val:
#     x_result = scaler.transform(x)
#     x_val_scaled.append(x_result)

#   return np.array(x_train_scaled), np.array(x_val_scaled)

# In generator
# train_generator, validation_generator, test_generator = loadGenerator()

# In vector
# x_train_scaled, x_val_scaled = scaleVector()

print(x_train.shape)
print(x_val.shape)
# Out:
# (372, 20)
# (124, 20)

# %%
def plot_result(model, history):
  # list all data in history
  print(history.history.keys())

  # summarize history for accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss') 
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

def save_model(model, filename):
  checkAndCreateDirectory("/content/model/test.txt")
  model.summary()

  plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

  with open("/content/model/" + filename + ".json", "w") as json_file:
    model_json = model.to_json()
    json_file.write(model_json)

def buildModel():
  model_input = Input(shape=(352, 235, 3))
  model_input = Input(shape=(20, 1))

  model = Conv1D(32, kernel_size=3, strides=1, padding='valid', trainable=True)(model_input)
  # model = BatchNormalization()(model)
  # model = Activation('relu')(model)

  # model = MaxPooling2D(2)(model)

  model = Conv1D(64, kernel_size=5, strides=1, padding='valid', trainable=True)(model)
  # model = BatchNormalization()(model)
  # model = Activation('relu')(model)

  # model = MaxPooling2D(2)(model)

  model = Conv1D(128, kernel_size=7, strides=1, padding='valid', trainable=True)(model)
  # model = BatchNormalization()(model)
  # model = Activation('relu')(model)

  # model = MaxPooling2D(2)(model)

  model = Flatten()(model)

  model = Dense(4096)(model)
  model = Dense(4096)(model)

  model = Dense(4, activation='softmax')(model)
  
  # Model compile
  model = Model(inputs=[model_input], outputs=[model])
  model.compile(optimizer="adam", loss=tf.keras.losses.CategoricalCrossentropy(), metrics=["accuracy"])
  
  # Visualize & Save Model
  save_model(model, "struct_model")

  # Checkpoint
  basepath = '/content/model/weight_model'
  best_checkpoint = ModelCheckpoint(basepath +'_{epoch:02d}_{loss:.2f}_{accuracy:.2f}_{val_loss:.2f}_{val_accuracy:.2f}.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
  callback_list = [best_checkpoint]

  history = model.fit(
    x_train, 
    y_train, 
    validation_data=(x_val, y_val),
    batch_size=1, 
    epochs=10000,
    callbacks=callback_list
  )

  # history = model.fit_generator(
  #   generator=train_generator,
  #   validation_data=validation_generator,
  #   epochs=100,
  #   callbacks=callback_list
  # )

  return model, history

# !sudo chmod 777 /mnt
# !rm -rf model
# !rm -rf /mnt/model
# !rm -rf ../.local/share/Trash/files

# device = cuda.get_current_device()
# device.reset()

model, history = buildModel()
plot_result(model, history)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Epoch 03247: val_accuracy did not improve from 0.54839
# Epoch 3248/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1241 - accuracy: 0.4911 - val_loss: 1.2227 - val_accuracy: 0.4516
#
# Epoch 03248: val_accuracy did not improve from 0.54839
# Epoch 3249/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0362 - accuracy: 0.5225 - val_loss: 1.3807 - val_accuracy: 0.3952
#
# Epoch 03249: val_accuracy did not improve from 0.54839
# Epoch 3250/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2742 - accuracy: 0.4433 - val_loss: 1.2637 - val_accuracy: 0.4274
#
# Epoch 03250: val_accuracy did not improve from 0.54839
# Epoch 3251/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1332 - accuracy: 0.4639 - val_loss: 1.1856 - val_accuracy: 0.4355
#
# Epoch 03251: val_accuracy did not improve from 0.54839
# Epoch 3252/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1453 - accuracy: 0.4774 - val_loss: 1.6507 - val_accuracy: 0.4274
#
# Epoch 03252: val_accuracy did not improve from 0.54839
# Epoch 3253/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2514 - accuracy: 0.4704 - val_loss: 1.1746 - val_accuracy: 0.4677
#
# Epoch 03253: val_accuracy did not improve from 0.54839
# Epoch 3254/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1100 - accuracy: 0.4923 - val_loss: 1.2349 - val_accuracy: 0.4597
#
# Epoch 03254: val_accuracy did not improve from 0.54839
# Epoch 3255/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1484 - accuracy: 0.4472 - val_loss: 1.2706 - val_accuracy: 0.4355
#
# Epoch 03255: val_accuracy did not improve from 0.54839
# Epoch 3256/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1719 - accuracy: 0.4568 - val_loss: 1.1957 - val_accuracy: 0.4516
#
# Epoch 03256: val_accuracy did not improve from 0.54839
# Epoch 3257/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1598 - accuracy: 0.4461 - val_loss: 1.2664 - val_accuracy: 0.4516
#
# Epoch 03257: val_accuracy did not improve from 0.54839
# Epoch 3258/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1454 - accuracy: 0.5144 - val_loss: 1.3170 - val_accuracy: 0.4516
#
# Epoch 03258: val_accuracy did not improve from 0.54839
# Epoch 3259/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1575 - accuracy: 0.4164 - val_loss: 1.3508 - val_accuracy: 0.4032
#
# Epoch 03259: val_accuracy did not improve from 0.54839
# Epoch 3260/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0845 - accuracy: 0.4993 - val_loss: 1.2742 - val_accuracy: 0.4194
#
# Epoch 03260: val_accuracy did not improve from 0.54839
# Epoch 3261/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1735 - accuracy: 0.4396 - val_loss: 1.3224 - val_accuracy: 0.4597
#
# Epoch 03261: val_accuracy did not improve from 0.54839
# Epoch 3262/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2204 - accuracy: 0.4649 - val_loss: 1.2427 - val_accuracy: 0.4516
#
# Epoch 03262: val_accuracy did not improve from 0.54839
# Epoch 3263/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1755 - accuracy: 0.4561 - val_loss: 1.4061 - val_accuracy: 0.3871
#
# Epoch 03263: val_accuracy did not improve from 0.54839
# Epoch 3264/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 136.2067 - accuracy: 0.3758 - val_loss: 2.0233 - val_accuracy: 0.3710
#
# Epoch 03264: val_accuracy did not improve from 0.54839
# Epoch 3265/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3614 - accuracy: 0.3890 - val_loss: 1.1969 - val_accuracy: 0.4435
#
# Epoch 03265: val_accuracy did not improve from 0.54839
# Epoch 3266/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0920 - accuracy: 0.5386 - val_loss: 1.2200 - val_accuracy: 0.4677
#
# Epoch 03266: val_accuracy did not improve from 0.54839
# Epoch 3267/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1376 - accuracy: 0.4813 - val_loss: 1.3745 - val_accuracy: 0.3629
#
# Epoch 03267: val_accuracy did not improve from 0.54839
# Epoch 3268/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1882 - accuracy: 0.4285 - val_loss: 1.2395 - val_accuracy: 0.4355
#
# Epoch 03268: val_accuracy did not improve from 0.54839
# Epoch 3269/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1027 - accuracy: 0.4808 - val_loss: 1.4494 - val_accuracy: 0.4274
#
# Epoch 03269: val_accuracy did not improve from 0.54839
# Epoch 3270/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1505 - accuracy: 0.5197 - val_loss: 1.6986 - val_accuracy: 0.3790
#
# Epoch 03270: val_accuracy did not improve from 0.54839
# Epoch 3271/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1352 - accuracy: 0.4860 - val_loss: 1.2211 - val_accuracy: 0.4597
#
# Epoch 03271: val_accuracy did not improve from 0.54839
# Epoch 3272/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1521 - accuracy: 0.4886 - val_loss: 1.3223 - val_accuracy: 0.4758
#
# Epoch 03272: val_accuracy did not improve from 0.54839
# Epoch 3273/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1930 - accuracy: 0.4615 - val_loss: 1.1910 - val_accuracy: 0.5000
#
# Epoch 03273: val_accuracy did not improve from 0.54839
# Epoch 3274/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2042 - accuracy: 0.4751 - val_loss: 1.3881 - val_accuracy: 0.3710
#
# Epoch 03274: val_accuracy did not improve from 0.54839
# Epoch 3275/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1880 - accuracy: 0.4751 - val_loss: 1.2829 - val_accuracy: 0.4355
#
# Epoch 03275: val_accuracy did not improve from 0.54839
# Epoch 3276/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1304 - accuracy: 0.5073 - val_loss: 1.2543 - val_accuracy: 0.4677
#
# Epoch 03276: val_accuracy did not improve from 0.54839
# Epoch 3277/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2604 - accuracy: 0.4752 - val_loss: 1.3291 - val_accuracy: 0.4355
#
# Epoch 03277: val_accuracy did not improve from 0.54839
# Epoch 3278/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1579 - accuracy: 0.4834 - val_loss: 1.3394 - val_accuracy: 0.4194
#
# Epoch 03278: val_accuracy did not improve from 0.54839
# Epoch 3279/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2775 - accuracy: 0.4482 - val_loss: 1.2673 - val_accuracy: 0.3952
#
# Epoch 03279: val_accuracy did not improve from 0.54839
# Epoch 3280/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1667 - accuracy: 0.4295 - val_loss: 1.3329 - val_accuracy: 0.4355
#
# Epoch 03280: val_accuracy did not improve from 0.54839
# Epoch 3281/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1604 - accuracy: 0.5331 - val_loss: 1.3485 - val_accuracy: 0.4516
#
# Epoch 03281: val_accuracy did not improve from 0.54839
# Epoch 3282/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1049 - accuracy: 0.4734 - val_loss: 1.7177 - val_accuracy: 0.3871
#
# Epoch 03282: val_accuracy did not improve from 0.54839
# Epoch 3283/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1858 - accuracy: 0.4966 - val_loss: 1.3014 - val_accuracy: 0.4274
#
# Epoch 03283: val_accuracy did not improve from 0.54839
# Epoch 3284/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2308 - accuracy: 0.4679 - val_loss: 1.3142 - val_accuracy: 0.4677
#
# Epoch 03284: val_accuracy did not improve from 0.54839
# Epoch 3285/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1542 - accuracy: 0.4970 - val_loss: 1.7732 - val_accuracy: 0.3790
#
# Epoch 03285: val_accuracy did not improve from 0.54839
# Epoch 3286/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2248 - accuracy: 0.4728 - val_loss: 1.4602 - val_accuracy: 0.4355
#
# Epoch 03286: val_accuracy did not improve from 0.54839
# Epoch 3287/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2071 - accuracy: 0.4497 - val_loss: 1.4555 - val_accuracy: 0.3871
#
# Epoch 03287: val_accuracy did not improve from 0.54839
# Epoch 3288/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 26.9111 - accuracy: 0.3819 - val_loss: 1.3415 - val_accuracy: 0.3629
#
# Epoch 03288: val_accuracy did not improve from 0.54839
# Epoch 3289/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2304 - accuracy: 0.4375 - val_loss: 1.3060 - val_accuracy: 0.4194
#
# Epoch 03289: val_accuracy did not improve from 0.54839
# Epoch 3290/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1292 - accuracy: 0.4997 - val_loss: 1.1980 - val_accuracy: 0.4274
#
# Epoch 03290: val_accuracy did not improve from 0.54839
# Epoch 3291/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1080 - accuracy: 0.5081 - val_loss: 1.2330 - val_accuracy: 0.4435
#
# Epoch 03291: val_accuracy did not improve from 0.54839
# Epoch 3292/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1044 - accuracy: 0.4647 - val_loss: 1.2144 - val_accuracy: 0.4516
#
# Epoch 03292: val_accuracy did not improve from 0.54839
# Epoch 3293/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0375 - accuracy: 0.5294 - val_loss: 1.2704 - val_accuracy: 0.4597
#
# Epoch 03293: val_accuracy did not improve from 0.54839
# Epoch 3294/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0897 - accuracy: 0.5182 - val_loss: 1.2368 - val_accuracy: 0.3871
#
# Epoch 03294: val_accuracy did not improve from 0.54839
# Epoch 3295/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1200 - accuracy: 0.4683 - val_loss: 1.3437 - val_accuracy: 0.4435
#
# Epoch 03295: val_accuracy did not improve from 0.54839
# Epoch 3296/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1658 - accuracy: 0.4356 - val_loss: 1.2540 - val_accuracy: 0.4677
#
# Epoch 03296: val_accuracy did not improve from 0.54839
# Epoch 3297/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0926 - accuracy: 0.5008 - val_loss: 1.2544 - val_accuracy: 0.4435
#
# Epoch 03297: val_accuracy did not improve from 0.54839
# Epoch 3298/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1140 - accuracy: 0.4942 - val_loss: 1.3805 - val_accuracy: 0.3306
#
# Epoch 03298: val_accuracy did not improve from 0.54839
# Epoch 3299/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1198 - accuracy: 0.5016 - val_loss: 1.5792 - val_accuracy: 0.3548
#
# Epoch 03299: val_accuracy did not improve from 0.54839
# Epoch 3300/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1760 - accuracy: 0.4544 - val_loss: 1.3587 - val_accuracy: 0.4516
#
# Epoch 03300: val_accuracy did not improve from 0.54839
# Epoch 3301/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2269 - accuracy: 0.4723 - val_loss: 1.3303 - val_accuracy: 0.3952
#
# Epoch 03301: val_accuracy did not improve from 0.54839
# Epoch 3302/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1767 - accuracy: 0.4245 - val_loss: 1.3046 - val_accuracy: 0.4113
#
# Epoch 03302: val_accuracy did not improve from 0.54839
# Epoch 3303/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1815 - accuracy: 0.4964 - val_loss: 1.2742 - val_accuracy: 0.4435
#
# Epoch 03303: val_accuracy did not improve from 0.54839
# Epoch 3304/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2075 - accuracy: 0.4736 - val_loss: 1.2207 - val_accuracy: 0.4597
#
# Epoch 03304: val_accuracy did not improve from 0.54839
# Epoch 3305/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2040 - accuracy: 0.4306 - val_loss: 1.3100 - val_accuracy: 0.4194
#
# Epoch 03305: val_accuracy did not improve from 0.54839
# Epoch 3306/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 40.4900 - accuracy: 0.3904 - val_loss: 20.3830 - val_accuracy: 0.3710
#
# Epoch 03306: val_accuracy did not improve from 0.54839
# Epoch 3307/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 3.8245 - accuracy: 0.4017 - val_loss: 1.3225 - val_accuracy: 0.3871
#
# Epoch 03307: val_accuracy did not improve from 0.54839
# Epoch 3308/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1925 - accuracy: 0.4612 - val_loss: 1.2452 - val_accuracy: 0.4194
#
# Epoch 03308: val_accuracy did not improve from 0.54839
# Epoch 3309/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1629 - accuracy: 0.5310 - val_loss: 1.3772 - val_accuracy: 0.3468
#
# Epoch 03309: val_accuracy did not improve from 0.54839
# Epoch 3310/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1447 - accuracy: 0.4791 - val_loss: 1.4231 - val_accuracy: 0.4194
#
# Epoch 03310: val_accuracy did not improve from 0.54839
# Epoch 3311/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1853 - accuracy: 0.4764 - val_loss: 1.2179 - val_accuracy: 0.4597
#
# Epoch 03311: val_accuracy did not improve from 0.54839
# Epoch 3312/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1379 - accuracy: 0.4811 - val_loss: 1.2503 - val_accuracy: 0.4355
#
# Epoch 03312: val_accuracy did not improve from 0.54839
# Epoch 3313/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1451 - accuracy: 0.5085 - val_loss: 1.2907 - val_accuracy: 0.4597
#
# Epoch 03313: val_accuracy did not improve from 0.54839
# Epoch 3314/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2863 - accuracy: 0.4841 - val_loss: 1.2783 - val_accuracy: 0.4113
#
# Epoch 03314: val_accuracy did not improve from 0.54839
# Epoch 3315/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2217 - accuracy: 0.4142 - val_loss: 1.3215 - val_accuracy: 0.4516
#
# Epoch 03315: val_accuracy did not improve from 0.54839
# Epoch 3316/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1749 - accuracy: 0.4887 - val_loss: 1.2570 - val_accuracy: 0.4435
#
# Epoch 03316: val_accuracy did not improve from 0.54839
# Epoch 3317/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1805 - accuracy: 0.4291 - val_loss: 1.2973 - val_accuracy: 0.4435
#
# Epoch 03317: val_accuracy did not improve from 0.54839
# Epoch 3318/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1665 - accuracy: 0.4844 - val_loss: 1.2371 - val_accuracy: 0.3952
#
# Epoch 03318: val_accuracy did not improve from 0.54839
# Epoch 3319/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2499 - accuracy: 0.4113 - val_loss: 1.2790 - val_accuracy: 0.4435
#
# Epoch 03319: val_accuracy did not improve from 0.54839
# Epoch 3320/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1063 - accuracy: 0.4634 - val_loss: 1.3114 - val_accuracy: 0.4355
#
# Epoch 03320: val_accuracy did not improve from 0.54839
# Epoch 3321/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3181 - accuracy: 0.4380 - val_loss: 1.8311 - val_accuracy: 0.3952
#
# Epoch 03321: val_accuracy did not improve from 0.54839
# Epoch 3322/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1977 - accuracy: 0.4745 - val_loss: 1.2631 - val_accuracy: 0.4113
#
# Epoch 03322: val_accuracy did not improve from 0.54839
# Epoch 3323/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1662 - accuracy: 0.4994 - val_loss: 1.2070 - val_accuracy: 0.4435
#
# Epoch 03323: val_accuracy did not improve from 0.54839
# Epoch 3324/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1321 - accuracy: 0.5395 - val_loss: 1.1901 - val_accuracy: 0.4597
#
# Epoch 03324: val_accuracy did not improve from 0.54839
# Epoch 3325/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1129 - accuracy: 0.5152 - val_loss: 1.2460 - val_accuracy: 0.4113
#
# Epoch 03325: val_accuracy did not improve from 0.54839
# Epoch 3326/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1844 - accuracy: 0.4660 - val_loss: 1.1969 - val_accuracy: 0.4113
#
# Epoch 03326: val_accuracy did not improve from 0.54839
# Epoch 3327/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1645 - accuracy: 0.4818 - val_loss: 3.9281 - val_accuracy: 0.2581
#
# Epoch 03327: val_accuracy did not improve from 0.54839
# Epoch 3328/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 154.0797 - accuracy: 0.3391 - val_loss: 2.5444 - val_accuracy: 0.2903
#
# Epoch 03328: val_accuracy did not improve from 0.54839
# Epoch 3329/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 2.5111 - accuracy: 0.3485 - val_loss: 1.4207 - val_accuracy: 0.4194
#
# Epoch 03329: val_accuracy did not improve from 0.54839
# Epoch 3330/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3276 - accuracy: 0.3993 - val_loss: 1.3383 - val_accuracy: 0.3629
#
# Epoch 03330: val_accuracy did not improve from 0.54839
# Epoch 3331/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2694 - accuracy: 0.4508 - val_loss: 1.3562 - val_accuracy: 0.3952
#
# Epoch 03331: val_accuracy did not improve from 0.54839
# Epoch 3332/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2078 - accuracy: 0.4762 - val_loss: 1.2910 - val_accuracy: 0.4355
#
# Epoch 03332: val_accuracy did not improve from 0.54839
# Epoch 3333/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1486 - accuracy: 0.4763 - val_loss: 1.2372 - val_accuracy: 0.4435
#
# Epoch 03333: val_accuracy did not improve from 0.54839
# Epoch 3334/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1574 - accuracy: 0.4865 - val_loss: 1.5563 - val_accuracy: 0.3065
#
# Epoch 03334: val_accuracy did not improve from 0.54839
# Epoch 3335/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.5180 - accuracy: 0.4862 - val_loss: 1.4955 - val_accuracy: 0.3306
#
# Epoch 03335: val_accuracy did not improve from 0.54839
# Epoch 3336/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3420 - accuracy: 0.4117 - val_loss: 1.8893 - val_accuracy: 0.4435
#
# Epoch 03336: val_accuracy did not improve from 0.54839
# Epoch 3337/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3024 - accuracy: 0.4059 - val_loss: 1.2097 - val_accuracy: 0.4113
#
# Epoch 03337: val_accuracy did not improve from 0.54839
# Epoch 3338/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3342 - accuracy: 0.4751 - val_loss: 1.3729 - val_accuracy: 0.3629
#
# Epoch 03338: val_accuracy did not improve from 0.54839
# Epoch 3339/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2251 - accuracy: 0.4963 - val_loss: 1.2637 - val_accuracy: 0.4597
#
# Epoch 03339: val_accuracy did not improve from 0.54839
# Epoch 3340/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1705 - accuracy: 0.4891 - val_loss: 1.2524 - val_accuracy: 0.4032
#
# Epoch 03340: val_accuracy did not improve from 0.54839
# Epoch 3341/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2772 - accuracy: 0.5166 - val_loss: 1.3623 - val_accuracy: 0.3871
#
# Epoch 03341: val_accuracy did not improve from 0.54839
# Epoch 3342/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 31.4245 - accuracy: 0.3284 - val_loss: 1.3999 - val_accuracy: 0.4677
#
# Epoch 03342: val_accuracy did not improve from 0.54839
# Epoch 3343/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2212 - accuracy: 0.4284 - val_loss: 1.2484 - val_accuracy: 0.4677
#
# Epoch 03343: val_accuracy did not improve from 0.54839
# Epoch 3344/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0996 - accuracy: 0.4910 - val_loss: 1.2108 - val_accuracy: 0.4516
#
# Epoch 03344: val_accuracy did not improve from 0.54839
# Epoch 3345/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1394 - accuracy: 0.4741 - val_loss: 1.2691 - val_accuracy: 0.4274
#
# Epoch 03345: val_accuracy did not improve from 0.54839
# Epoch 3346/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1719 - accuracy: 0.4723 - val_loss: 1.2488 - val_accuracy: 0.4677
#
# Epoch 03346: val_accuracy did not improve from 0.54839
# Epoch 3347/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0858 - accuracy: 0.4619 - val_loss: 1.1783 - val_accuracy: 0.4597
#
# Epoch 03347: val_accuracy did not improve from 0.54839
# Epoch 3348/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1177 - accuracy: 0.5023 - val_loss: 1.2180 - val_accuracy: 0.4355
#
# Epoch 03348: val_accuracy did not improve from 0.54839
# Epoch 3349/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1831 - accuracy: 0.4559 - val_loss: 1.2167 - val_accuracy: 0.4919
#
# Epoch 03349: val_accuracy did not improve from 0.54839
# Epoch 3350/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1408 - accuracy: 0.4353 - val_loss: 1.2042 - val_accuracy: 0.4839
#
# Epoch 03350: val_accuracy did not improve from 0.54839
# Epoch 3351/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1548 - accuracy: 0.4709 - val_loss: 1.2021 - val_accuracy: 0.4194
#
# Epoch 03351: val_accuracy did not improve from 0.54839
# Epoch 3352/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1081 - accuracy: 0.5309 - val_loss: 1.2637 - val_accuracy: 0.4355
#
# Epoch 03352: val_accuracy did not improve from 0.54839
# Epoch 3353/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1311 - accuracy: 0.4878 - val_loss: 1.2326 - val_accuracy: 0.4516
#
# Epoch 03353: val_accuracy did not improve from 0.54839
# Epoch 3354/10000
# 372/372 [==============================] - 2s 7ms/step - loss: 1.1939 - accuracy: 0.4501 - val_loss: 1.2214 - val_accuracy: 0.4677
#
# Epoch 03354: val_accuracy did not improve from 0.54839
# Epoch 3355/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1243 - accuracy: 0.5070 - val_loss: 1.2169 - val_accuracy: 0.4516
#
# Epoch 03355: val_accuracy did not improve from 0.54839
# Epoch 3356/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0921 - accuracy: 0.5092 - val_loss: 1.5250 - val_accuracy: 0.3790
#
# Epoch 03356: val_accuracy did not improve from 0.54839
# Epoch 3357/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1799 - accuracy: 0.4591 - val_loss: 2.9549 - val_accuracy: 0.3387
#
# Epoch 03357: val_accuracy did not improve from 0.54839
# Epoch 3358/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 369.5206 - accuracy: 0.3409 - val_loss: 1.8355 - val_accuracy: 0.4194
#
# Epoch 03358: val_accuracy did not improve from 0.54839
# Epoch 3359/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3923 - accuracy: 0.4554 - val_loss: 1.4113 - val_accuracy: 0.4677
#
# Epoch 03359: val_accuracy did not improve from 0.54839
# Epoch 3360/10000
# 372/372 [==============================] - 2s 7ms/step - loss: 1.2524 - accuracy: 0.4518 - val_loss: 1.3239 - val_accuracy: 0.4032
#
# Epoch 03360: val_accuracy did not improve from 0.54839
# Epoch 3361/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1074 - accuracy: 0.4951 - val_loss: 1.2951 - val_accuracy: 0.4032
#
# Epoch 03361: val_accuracy did not improve from 0.54839
# Epoch 3362/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1566 - accuracy: 0.4727 - val_loss: 1.2464 - val_accuracy: 0.4194
#
# Epoch 03362: val_accuracy did not improve from 0.54839
# Epoch 3363/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1207 - accuracy: 0.4469 - val_loss: 1.2204 - val_accuracy: 0.4274
#
# Epoch 03363: val_accuracy did not improve from 0.54839
# Epoch 3364/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1141 - accuracy: 0.4984 - val_loss: 1.2150 - val_accuracy: 0.4597
#
# Epoch 03364: val_accuracy did not improve from 0.54839
# Epoch 3365/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1597 - accuracy: 0.5063 - val_loss: 1.2406 - val_accuracy: 0.4274
#
# Epoch 03365: val_accuracy did not improve from 0.54839
# Epoch 3366/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1238 - accuracy: 0.4887 - val_loss: 1.6377 - val_accuracy: 0.3710
#
# Epoch 03366: val_accuracy did not improve from 0.54839
# Epoch 3367/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2068 - accuracy: 0.4735 - val_loss: 1.5160 - val_accuracy: 0.3548
#
# Epoch 03367: val_accuracy did not improve from 0.54839
# Epoch 3368/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0448 - accuracy: 0.5555 - val_loss: 1.4335 - val_accuracy: 0.4355
#
# Epoch 03368: val_accuracy did not improve from 0.54839
# Epoch 3369/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1919 - accuracy: 0.4971 - val_loss: 1.2904 - val_accuracy: 0.4839
#
# Epoch 03369: val_accuracy did not improve from 0.54839
# Epoch 3370/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1613 - accuracy: 0.4249 - val_loss: 1.3542 - val_accuracy: 0.4516
#
# Epoch 03370: val_accuracy did not improve from 0.54839
# Epoch 3371/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2184 - accuracy: 0.4413 - val_loss: 1.3925 - val_accuracy: 0.4032
#
# Epoch 03371: val_accuracy did not improve from 0.54839
# Epoch 3372/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1857 - accuracy: 0.4815 - val_loss: 1.2592 - val_accuracy: 0.4194
#
# Epoch 03372: val_accuracy did not improve from 0.54839
# Epoch 3373/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2009 - accuracy: 0.4369 - val_loss: 1.6593 - val_accuracy: 0.4194
#
# Epoch 03373: val_accuracy did not improve from 0.54839
# Epoch 3374/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1216 - accuracy: 0.4462 - val_loss: 1.1991 - val_accuracy: 0.4597
#
# Epoch 03374: val_accuracy did not improve from 0.54839
# Epoch 3375/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1610 - accuracy: 0.4567 - val_loss: 1.2221 - val_accuracy: 0.4194
#
# Epoch 03375: val_accuracy did not improve from 0.54839
# Epoch 3376/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1954 - accuracy: 0.4546 - val_loss: 1.5600 - val_accuracy: 0.4597
#
# Epoch 03376: val_accuracy did not improve from 0.54839
# Epoch 3377/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3026 - accuracy: 0.4301 - val_loss: 1.2590 - val_accuracy: 0.4274
#
# Epoch 03377: val_accuracy did not improve from 0.54839
# Epoch 3378/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2326 - accuracy: 0.4742 - val_loss: 1.5358 - val_accuracy: 0.3952
#
# Epoch 03378: val_accuracy did not improve from 0.54839
# Epoch 3379/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2561 - accuracy: 0.4079 - val_loss: 1.5404 - val_accuracy: 0.4113
#
# Epoch 03379: val_accuracy did not improve from 0.54839
# Epoch 3380/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1625 - accuracy: 0.5202 - val_loss: 1.3528 - val_accuracy: 0.4274
#
# Epoch 03380: val_accuracy did not improve from 0.54839
# Epoch 3381/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2583 - accuracy: 0.4338 - val_loss: 1.3042 - val_accuracy: 0.4435
#
# Epoch 03381: val_accuracy did not improve from 0.54839
# Epoch 3382/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2251 - accuracy: 0.4723 - val_loss: 1.7284 - val_accuracy: 0.3065
#
# Epoch 03382: val_accuracy did not improve from 0.54839
# Epoch 3383/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3887 - accuracy: 0.4165 - val_loss: 1.3826 - val_accuracy: 0.4758
#
# Epoch 03383: val_accuracy did not improve from 0.54839
# Epoch 3384/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1969 - accuracy: 0.4461 - val_loss: 1.3916 - val_accuracy: 0.3629
#
# Epoch 03384: val_accuracy did not improve from 0.54839
# Epoch 3385/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1671 - accuracy: 0.4878 - val_loss: 1.9075 - val_accuracy: 0.3871
#
# Epoch 03385: val_accuracy did not improve from 0.54839
# Epoch 3386/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1013.8519 - accuracy: 0.4024 - val_loss: 4.9370 - val_accuracy: 0.4113
#
# Epoch 03386: val_accuracy did not improve from 0.54839
# Epoch 3387/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 3.3841 - accuracy: 0.4255 - val_loss: 1.9647 - val_accuracy: 0.3629
#
# Epoch 03387: val_accuracy did not improve from 0.54839
# Epoch 3388/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.7917 - accuracy: 0.4596 - val_loss: 2.1760 - val_accuracy: 0.4597
#
# Epoch 03388: val_accuracy did not improve from 0.54839
# Epoch 3389/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3994 - accuracy: 0.5418 - val_loss: 1.6387 - val_accuracy: 0.4274
#
# Epoch 03389: val_accuracy did not improve from 0.54839
# Epoch 3390/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.4641 - accuracy: 0.4537 - val_loss: 1.4207 - val_accuracy: 0.4516
#
# Epoch 03390: val_accuracy did not improve from 0.54839
# Epoch 3391/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3022 - accuracy: 0.4951 - val_loss: 1.6825 - val_accuracy: 0.4355
#
# Epoch 03391: val_accuracy did not improve from 0.54839
# Epoch 3392/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3777 - accuracy: 0.4125 - val_loss: 1.2702 - val_accuracy: 0.4758
#
# Epoch 03392: val_accuracy did not improve from 0.54839
# Epoch 3393/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3215 - accuracy: 0.4908 - val_loss: 1.4727 - val_accuracy: 0.4274
#
# Epoch 03393: val_accuracy did not improve from 0.54839
# Epoch 3394/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1844 - accuracy: 0.5232 - val_loss: 1.3258 - val_accuracy: 0.4597
#
# Epoch 03394: val_accuracy did not improve from 0.54839
# Epoch 3395/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3077 - accuracy: 0.4643 - val_loss: 1.3149 - val_accuracy: 0.4435
#
# Epoch 03395: val_accuracy did not improve from 0.54839
# Epoch 3396/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2879 - accuracy: 0.4561 - val_loss: 1.8348 - val_accuracy: 0.3790
#
# Epoch 03396: val_accuracy did not improve from 0.54839
# Epoch 3397/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2056 - accuracy: 0.3986 - val_loss: 1.2687 - val_accuracy: 0.4032
#
# Epoch 03397: val_accuracy did not improve from 0.54839
# Epoch 3398/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1749 - accuracy: 0.5268 - val_loss: 1.3149 - val_accuracy: 0.4194
#
# Epoch 03398: val_accuracy did not improve from 0.54839
# Epoch 3399/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3097 - accuracy: 0.4702 - val_loss: 1.2364 - val_accuracy: 0.4032
#
# Epoch 03399: val_accuracy did not improve from 0.54839
# Epoch 3400/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1233 - accuracy: 0.5160 - val_loss: 1.3722 - val_accuracy: 0.4194
#
# Epoch 03400: val_accuracy did not improve from 0.54839
# Epoch 3401/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2155 - accuracy: 0.4514 - val_loss: 1.4760 - val_accuracy: 0.4274
#
# Epoch 03401: val_accuracy did not improve from 0.54839
# Epoch 3402/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2722 - accuracy: 0.4735 - val_loss: 1.3291 - val_accuracy: 0.4677
#
# Epoch 03402: val_accuracy did not improve from 0.54839
# Epoch 3403/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1718 - accuracy: 0.4954 - val_loss: 1.1596 - val_accuracy: 0.4677
#
# Epoch 03403: val_accuracy did not improve from 0.54839
# Epoch 3404/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1637 - accuracy: 0.5091 - val_loss: 1.3769 - val_accuracy: 0.4355
#
# Epoch 03404: val_accuracy did not improve from 0.54839
# Epoch 3405/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 18.6138 - accuracy: 0.4099 - val_loss: 1.4602 - val_accuracy: 0.4355
#
# Epoch 03405: val_accuracy did not improve from 0.54839
# Epoch 3406/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1263 - accuracy: 0.5375 - val_loss: 1.3362 - val_accuracy: 0.3468
#
# Epoch 03406: val_accuracy did not improve from 0.54839
# Epoch 3407/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1987 - accuracy: 0.4905 - val_loss: 1.2550 - val_accuracy: 0.4355
#
# Epoch 03407: val_accuracy did not improve from 0.54839
# Epoch 3408/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1246 - accuracy: 0.4709 - val_loss: 1.3053 - val_accuracy: 0.4435
#
# Epoch 03408: val_accuracy did not improve from 0.54839
# Epoch 3409/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0820 - accuracy: 0.5194 - val_loss: 1.2224 - val_accuracy: 0.4677
#
# Epoch 03409: val_accuracy did not improve from 0.54839
# Epoch 3410/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1377 - accuracy: 0.4508 - val_loss: 1.2035 - val_accuracy: 0.4919
#
# Epoch 03410: val_accuracy did not improve from 0.54839
# Epoch 3411/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0723 - accuracy: 0.5303 - val_loss: 1.2048 - val_accuracy: 0.4274
#
# Epoch 03411: val_accuracy did not improve from 0.54839
# Epoch 3412/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1553 - accuracy: 0.5186 - val_loss: 1.2256 - val_accuracy: 0.4839
#
# Epoch 03412: val_accuracy did not improve from 0.54839
# Epoch 3413/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1044 - accuracy: 0.4970 - val_loss: 1.1522 - val_accuracy: 0.4355
#
# Epoch 03413: val_accuracy did not improve from 0.54839
# Epoch 3414/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0355 - accuracy: 0.5349 - val_loss: 1.2170 - val_accuracy: 0.4839
#
# Epoch 03414: val_accuracy did not improve from 0.54839
# Epoch 3415/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0971 - accuracy: 0.5448 - val_loss: 1.1961 - val_accuracy: 0.4355
#
# Epoch 03415: val_accuracy did not improve from 0.54839
# Epoch 3416/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1399 - accuracy: 0.5097 - val_loss: 1.2213 - val_accuracy: 0.4758
#
# Epoch 03416: val_accuracy did not improve from 0.54839
# Epoch 3417/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0691 - accuracy: 0.5570 - val_loss: 1.2098 - val_accuracy: 0.4516
#
# Epoch 03417: val_accuracy did not improve from 0.54839
# Epoch 3418/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1083 - accuracy: 0.5084 - val_loss: 1.2034 - val_accuracy: 0.4516
#
# Epoch 03418: val_accuracy did not improve from 0.54839
# Epoch 3419/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0628 - accuracy: 0.5265 - val_loss: 1.5005 - val_accuracy: 0.3145
#
# Epoch 03419: val_accuracy did not improve from 0.54839
# Epoch 3420/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1538 - accuracy: 0.4896 - val_loss: 1.2650 - val_accuracy: 0.4516
#
# Epoch 03420: val_accuracy did not improve from 0.54839
# Epoch 3421/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1156 - accuracy: 0.4963 - val_loss: 1.1886 - val_accuracy: 0.4597
#
# Epoch 03421: val_accuracy did not improve from 0.54839
# Epoch 3422/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1665 - accuracy: 0.4786 - val_loss: 2.2076 - val_accuracy: 0.3468
#
# Epoch 03422: val_accuracy did not improve from 0.54839
# Epoch 3423/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 275.3906 - accuracy: 0.2554 - val_loss: 2.2179 - val_accuracy: 0.3629
#
# Epoch 03423: val_accuracy did not improve from 0.54839
# Epoch 3424/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.8680 - accuracy: 0.4397 - val_loss: 1.3776 - val_accuracy: 0.4194
#
# Epoch 03424: val_accuracy did not improve from 0.54839
# Epoch 3425/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3126 - accuracy: 0.4470 - val_loss: 1.2398 - val_accuracy: 0.4677
#
# Epoch 03425: val_accuracy did not improve from 0.54839
# Epoch 3426/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2192 - accuracy: 0.4852 - val_loss: 1.1242 - val_accuracy: 0.5323
#
# Epoch 03426: val_accuracy did not improve from 0.54839
# Epoch 3427/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2094 - accuracy: 0.5016 - val_loss: 1.5988 - val_accuracy: 0.2581
#
# Epoch 03427: val_accuracy did not improve from 0.54839
# Epoch 3428/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3106 - accuracy: 0.4298 - val_loss: 1.6400 - val_accuracy: 0.2984
#
# Epoch 03428: val_accuracy did not improve from 0.54839
# Epoch 3429/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2368 - accuracy: 0.4938 - val_loss: 1.8866 - val_accuracy: 0.3952
#
# Epoch 03429: val_accuracy did not improve from 0.54839
# Epoch 3430/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2807 - accuracy: 0.4467 - val_loss: 1.3132 - val_accuracy: 0.3952
#
# Epoch 03430: val_accuracy did not improve from 0.54839
# Epoch 3431/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2628 - accuracy: 0.4469 - val_loss: 1.3340 - val_accuracy: 0.4274
#
# Epoch 03431: val_accuracy did not improve from 0.54839
# Epoch 3432/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1333 - accuracy: 0.4938 - val_loss: 1.3091 - val_accuracy: 0.3952
#
# Epoch 03432: val_accuracy did not improve from 0.54839
# Epoch 3433/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1931 - accuracy: 0.4644 - val_loss: 1.3124 - val_accuracy: 0.4758
#
# Epoch 03433: val_accuracy did not improve from 0.54839
# Epoch 3434/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2836 - accuracy: 0.4354 - val_loss: 1.5336 - val_accuracy: 0.3145
#
# Epoch 03434: val_accuracy did not improve from 0.54839
# Epoch 3435/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2388 - accuracy: 0.4915 - val_loss: 1.4324 - val_accuracy: 0.4274
#
# Epoch 03435: val_accuracy did not improve from 0.54839
# Epoch 3436/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2698 - accuracy: 0.4085 - val_loss: 1.3954 - val_accuracy: 0.3952
#
# Epoch 03436: val_accuracy did not improve from 0.54839
# Epoch 3437/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1749 - accuracy: 0.4467 - val_loss: 1.2233 - val_accuracy: 0.4597
#
# Epoch 03437: val_accuracy did not improve from 0.54839
# Epoch 3438/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1113 - accuracy: 0.5152 - val_loss: 1.4658 - val_accuracy: 0.4516
#
# Epoch 03438: val_accuracy did not improve from 0.54839
# Epoch 3439/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2661 - accuracy: 0.4817 - val_loss: 1.3759 - val_accuracy: 0.3629
#
# Epoch 03439: val_accuracy did not improve from 0.54839
# Epoch 3440/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2208 - accuracy: 0.4292 - val_loss: 1.3052 - val_accuracy: 0.4597
#
# Epoch 03440: val_accuracy did not improve from 0.54839
# Epoch 3441/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0954 - accuracy: 0.4916 - val_loss: 1.2506 - val_accuracy: 0.4194
#
# Epoch 03441: val_accuracy did not improve from 0.54839
# Epoch 3442/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1247 - accuracy: 0.5380 - val_loss: 1.2649 - val_accuracy: 0.4194
#
# Epoch 03442: val_accuracy did not improve from 0.54839
# Epoch 3443/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2275 - accuracy: 0.4608 - val_loss: 1.2811 - val_accuracy: 0.4032
#
# Epoch 03443: val_accuracy did not improve from 0.54839
# Epoch 3444/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1763 - accuracy: 0.4646 - val_loss: 1.3370 - val_accuracy: 0.3871
#
# Epoch 03444: val_accuracy did not improve from 0.54839
# Epoch 3445/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1544 - accuracy: 0.5039 - val_loss: 1.3180 - val_accuracy: 0.4113
#
# Epoch 03445: val_accuracy did not improve from 0.54839
# Epoch 3446/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1972 - accuracy: 0.4643 - val_loss: 1.2508 - val_accuracy: 0.4274
#
# Epoch 03446: val_accuracy did not improve from 0.54839
# Epoch 3447/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.4525 - accuracy: 0.4741 - val_loss: 227.8658 - val_accuracy: 0.2500
#
# Epoch 03447: val_accuracy did not improve from 0.54839
# Epoch 3448/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 152.3141 - accuracy: 0.3099 - val_loss: 1.4227 - val_accuracy: 0.4274
#
# Epoch 03448: val_accuracy did not improve from 0.54839
# Epoch 3449/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2288 - accuracy: 0.4961 - val_loss: 1.4320 - val_accuracy: 0.3226
#
# Epoch 03449: val_accuracy did not improve from 0.54839
# Epoch 3450/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1342 - accuracy: 0.5345 - val_loss: 1.3453 - val_accuracy: 0.4032
#
# Epoch 03450: val_accuracy did not improve from 0.54839
# Epoch 3451/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2029 - accuracy: 0.5148 - val_loss: 1.2522 - val_accuracy: 0.4597
#
# Epoch 03451: val_accuracy did not improve from 0.54839
# Epoch 3452/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1551 - accuracy: 0.4756 - val_loss: 1.3676 - val_accuracy: 0.4435
#
# Epoch 03452: val_accuracy did not improve from 0.54839
# Epoch 3453/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1050 - accuracy: 0.5105 - val_loss: 1.2008 - val_accuracy: 0.4113
#
# Epoch 03453: val_accuracy did not improve from 0.54839
# Epoch 3454/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1516 - accuracy: 0.5049 - val_loss: 1.1886 - val_accuracy: 0.5000
#
# Epoch 03454: val_accuracy did not improve from 0.54839
# Epoch 3455/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1493 - accuracy: 0.4982 - val_loss: 1.2073 - val_accuracy: 0.4435
#
# Epoch 03455: val_accuracy did not improve from 0.54839
# Epoch 3456/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1096 - accuracy: 0.4699 - val_loss: 1.1770 - val_accuracy: 0.5000
#
# Epoch 03456: val_accuracy did not improve from 0.54839
# Epoch 3457/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0969 - accuracy: 0.5119 - val_loss: 1.2337 - val_accuracy: 0.4032
#
# Epoch 03457: val_accuracy did not improve from 0.54839
# Epoch 3458/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0686 - accuracy: 0.5288 - val_loss: 1.1542 - val_accuracy: 0.4516
#
# Epoch 03458: val_accuracy did not improve from 0.54839
# Epoch 3459/10000
# 372/372 [==============================] - 2s 7ms/step - loss: 1.1846 - accuracy: 0.4521 - val_loss: 1.3320 - val_accuracy: 0.4194
#
# Epoch 03459: val_accuracy did not improve from 0.54839
# Epoch 3460/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1698 - accuracy: 0.4868 - val_loss: 1.4675 - val_accuracy: 0.3952
#
# Epoch 03460: val_accuracy did not improve from 0.54839
# Epoch 3461/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0757 - accuracy: 0.5157 - val_loss: 1.2845 - val_accuracy: 0.4597
#
# Epoch 03461: val_accuracy did not improve from 0.54839
# Epoch 3462/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1329 - accuracy: 0.4796 - val_loss: 1.2313 - val_accuracy: 0.4435
#
# Epoch 03462: val_accuracy did not improve from 0.54839
# Epoch 3463/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1617 - accuracy: 0.4679 - val_loss: 1.1833 - val_accuracy: 0.4597
#
# Epoch 03463: val_accuracy did not improve from 0.54839
# Epoch 3464/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2097 - accuracy: 0.4696 - val_loss: 1.1801 - val_accuracy: 0.4758
#
# Epoch 03464: val_accuracy did not improve from 0.54839
# Epoch 3465/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1714 - accuracy: 0.4378 - val_loss: 1.2747 - val_accuracy: 0.4516
#
# Epoch 03465: val_accuracy did not improve from 0.54839
# Epoch 3466/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 54.8960 - accuracy: 0.4203 - val_loss: 2.0822 - val_accuracy: 0.3145
#
# Epoch 03466: val_accuracy did not improve from 0.54839
# Epoch 3467/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 2.1263 - accuracy: 0.3202 - val_loss: 1.2972 - val_accuracy: 0.3548
#
# Epoch 03467: val_accuracy did not improve from 0.54839
# Epoch 3468/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2030 - accuracy: 0.4352 - val_loss: 1.2116 - val_accuracy: 0.3871
#
# Epoch 03468: val_accuracy did not improve from 0.54839
# Epoch 3469/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1187 - accuracy: 0.5193 - val_loss: 1.3153 - val_accuracy: 0.4355
#
# Epoch 03469: val_accuracy did not improve from 0.54839
# Epoch 3470/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1083 - accuracy: 0.4896 - val_loss: 1.1734 - val_accuracy: 0.4597
#
# Epoch 03470: val_accuracy did not improve from 0.54839
# Epoch 3471/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1424 - accuracy: 0.4755 - val_loss: 1.1788 - val_accuracy: 0.4839
#
# Epoch 03471: val_accuracy did not improve from 0.54839
# Epoch 3472/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1357 - accuracy: 0.5055 - val_loss: 1.2876 - val_accuracy: 0.4516
#
# Epoch 03472: val_accuracy did not improve from 0.54839
# Epoch 3473/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1336 - accuracy: 0.4707 - val_loss: 1.2520 - val_accuracy: 0.4355
#
# Epoch 03473: val_accuracy did not improve from 0.54839
# Epoch 3474/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1017 - accuracy: 0.5030 - val_loss: 1.4744 - val_accuracy: 0.4194
#
# Epoch 03474: val_accuracy did not improve from 0.54839
# Epoch 3475/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1794 - accuracy: 0.4625 - val_loss: 1.4719 - val_accuracy: 0.3790
#
# Epoch 03475: val_accuracy did not improve from 0.54839
# Epoch 3476/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1129 - accuracy: 0.4807 - val_loss: 1.2573 - val_accuracy: 0.4597
#
# Epoch 03476: val_accuracy did not improve from 0.54839
# Epoch 3477/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0966 - accuracy: 0.5312 - val_loss: 1.2081 - val_accuracy: 0.4677
#
# Epoch 03477: val_accuracy did not improve from 0.54839
# Epoch 3478/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1391 - accuracy: 0.4391 - val_loss: 1.2106 - val_accuracy: 0.4435
#
# Epoch 03478: val_accuracy did not improve from 0.54839
# Epoch 3479/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2198 - accuracy: 0.4036 - val_loss: 2.0288 - val_accuracy: 0.3387
#
# Epoch 03479: val_accuracy did not improve from 0.54839
# Epoch 3480/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3716 - accuracy: 0.4463 - val_loss: 1.3155 - val_accuracy: 0.4113
#
# Epoch 03480: val_accuracy did not improve from 0.54839
# Epoch 3481/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1746 - accuracy: 0.4478 - val_loss: 1.2180 - val_accuracy: 0.4677
#
# Epoch 03481: val_accuracy did not improve from 0.54839
# Epoch 3482/10000
# ...
#
# Epoch 04419: val_accuracy did not improve from 0.54839
# Epoch 4420/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1763 - accuracy: 0.4820 - val_loss: 1.1810 - val_accuracy: 0.4758
#
# Epoch 04420: val_accuracy did not improve from 0.54839
# Epoch 4421/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1914 - accuracy: 0.5126 - val_loss: 1.5151 - val_accuracy: 0.3629
#
# Epoch 04421: val_accuracy did not improve from 0.54839
# Epoch 4422/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2951 - accuracy: 0.4460 - val_loss: 1.6214 - val_accuracy: 0.3952
#
# Epoch 04422: val_accuracy did not improve from 0.54839
# Epoch 4423/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2738 - accuracy: 0.4504 - val_loss: 1.5764 - val_accuracy: 0.3952
#
# Epoch 04423: val_accuracy did not improve from 0.54839
# Epoch 4424/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3909 - accuracy: 0.4697 - val_loss: 1.2907 - val_accuracy: 0.4113
#
# Epoch 04424: val_accuracy did not improve from 0.54839
# Epoch 4425/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2013 - accuracy: 0.4756 - val_loss: 1.3813 - val_accuracy: 0.4113
#
# Epoch 04425: val_accuracy did not improve from 0.54839
# Epoch 4426/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1201 - accuracy: 0.4810 - val_loss: 1.1979 - val_accuracy: 0.4435
#
# Epoch 04426: val_accuracy did not improve from 0.54839
# Epoch 4427/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2464 - accuracy: 0.4182 - val_loss: 1.4117 - val_accuracy: 0.4194
#
# Epoch 04427: val_accuracy did not improve from 0.54839
# Epoch 4428/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2217 - accuracy: 0.4606 - val_loss: 1.1685 - val_accuracy: 0.5000
#
# Epoch 04428: val_accuracy did not improve from 0.54839
# Epoch 4429/10000
# 372/372 [==============================] - 2s 7ms/step - loss: 1.2000 - accuracy: 0.4686 - val_loss: 1.2124 - val_accuracy: 0.4677
#
# Epoch 04429: val_accuracy did not improve from 0.54839
# Epoch 4430/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1715 - accuracy: 0.4521 - val_loss: 1.3015 - val_accuracy: 0.4032
#
# Epoch 04430: val_accuracy did not improve from 0.54839
# Epoch 4431/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1968 - accuracy: 0.4603 - val_loss: 1.2480 - val_accuracy: 0.4355
#
# Epoch 04431: val_accuracy did not improve from 0.54839
# Epoch 4432/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2119 - accuracy: 0.4452 - val_loss: 1.2861 - val_accuracy: 0.4516
#
# Epoch 04432: val_accuracy did not improve from 0.54839
# Epoch 4433/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1593 - accuracy: 0.4735 - val_loss: 1.2234 - val_accuracy: 0.4194
#
# Epoch 04433: val_accuracy did not improve from 0.54839
# Epoch 4434/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1622 - accuracy: 0.4567 - val_loss: 1.7680 - val_accuracy: 0.3387
#
# Epoch 04434: val_accuracy did not improve from 0.54839
# Epoch 4435/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2074 - accuracy: 0.4374 - val_loss: 1.5808 - val_accuracy: 0.3952
#
# Epoch 04435: val_accuracy did not improve from 0.54839
# Epoch 4436/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1863 - accuracy: 0.4375 - val_loss: 1.2799 - val_accuracy: 0.4435
#
# Epoch 04436: val_accuracy did not improve from 0.54839
# Epoch 4437/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1659 - accuracy: 0.4232 - val_loss: 1.2359 - val_accuracy: 0.4516
#
# Epoch 04437: val_accuracy did not improve from 0.54839
# Epoch 4438/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1761 - accuracy: 0.4751 - val_loss: 1.5003 - val_accuracy: 0.3387
#
# Epoch 04438: val_accuracy did not improve from 0.54839
# Epoch 4439/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 266.6269 - accuracy: 0.3560 - val_loss: 7.5793 - val_accuracy: 0.2339
#
# Epoch 04439: val_accuracy did not improve from 0.54839
# Epoch 4440/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 2.9444 - accuracy: 0.3397 - val_loss: 1.5312 - val_accuracy: 0.4113
#
# Epoch 04440: val_accuracy did not improve from 0.54839
# Epoch 4441/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3395 - accuracy: 0.4674 - val_loss: 1.4814 - val_accuracy: 0.4355
#
# Epoch 04441: val_accuracy did not improve from 0.54839
# Epoch 4442/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2190 - accuracy: 0.4871 - val_loss: 1.1847 - val_accuracy: 0.4597
#
# Epoch 04442: val_accuracy did not improve from 0.54839
# Epoch 4443/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1811 - accuracy: 0.4379 - val_loss: 1.2384 - val_accuracy: 0.4758
#
# Epoch 04443: val_accuracy did not improve from 0.54839
# Epoch 4444/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1637 - accuracy: 0.5293 - val_loss: 1.3249 - val_accuracy: 0.4839
#
# Epoch 04444: val_accuracy did not improve from 0.54839
# Epoch 4445/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1201 - accuracy: 0.5064 - val_loss: 1.2655 - val_accuracy: 0.4274
#
# Epoch 04445: val_accuracy did not improve from 0.54839
# Epoch 4446/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1156 - accuracy: 0.5391 - val_loss: 1.8103 - val_accuracy: 0.4435
#
# Epoch 04446: val_accuracy did not improve from 0.54839
# Epoch 4447/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2979 - accuracy: 0.4926 - val_loss: 1.2946 - val_accuracy: 0.5000
#
# Epoch 04447: val_accuracy did not improve from 0.54839
# Epoch 4448/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1354 - accuracy: 0.4638 - val_loss: 1.3340 - val_accuracy: 0.4597
#
# Epoch 04448: val_accuracy did not improve from 0.54839
# Epoch 4449/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2143 - accuracy: 0.4443 - val_loss: 1.5562 - val_accuracy: 0.4032
#
# Epoch 04449: val_accuracy did not improve from 0.54839
# Epoch 4450/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1940 - accuracy: 0.4779 - val_loss: 1.7653 - val_accuracy: 0.3548
#
# Epoch 04450: val_accuracy did not improve from 0.54839
# Epoch 4451/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3381 - accuracy: 0.4791 - val_loss: 1.4019 - val_accuracy: 0.4435
#
# Epoch 04451: val_accuracy did not improve from 0.54839
# Epoch 4452/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1413 - accuracy: 0.5048 - val_loss: 1.3071 - val_accuracy: 0.3952
#
# Epoch 04452: val_accuracy did not improve from 0.54839
# Epoch 4453/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1343 - accuracy: 0.5162 - val_loss: 1.3277 - val_accuracy: 0.4435
#
# Epoch 04453: val_accuracy did not improve from 0.54839
# Epoch 4454/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1857 - accuracy: 0.4585 - val_loss: 1.2774 - val_accuracy: 0.4194
#
# Epoch 04454: val_accuracy did not improve from 0.54839
# Epoch 4455/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2119 - accuracy: 0.5081 - val_loss: 1.2483 - val_accuracy: 0.4032
#
# Epoch 04455: val_accuracy did not improve from 0.54839
# Epoch 4456/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2758 - accuracy: 0.3552 - val_loss: 1.5089 - val_accuracy: 0.4113
#
# Epoch 04456: val_accuracy did not improve from 0.54839
# Epoch 4457/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2024 - accuracy: 0.4948 - val_loss: 1.3047 - val_accuracy: 0.4032
#
# Epoch 04457: val_accuracy did not improve from 0.54839
# Epoch 4458/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1068 - accuracy: 0.5067 - val_loss: 1.2432 - val_accuracy: 0.4435
#
# Epoch 04458: val_accuracy did not improve from 0.54839
# Epoch 4459/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1209 - accuracy: 0.4857 - val_loss: 1.2563 - val_accuracy: 0.4677
#
# Epoch 04459: val_accuracy did not improve from 0.54839
# Epoch 4460/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1574 - accuracy: 0.5042 - val_loss: 1.5114 - val_accuracy: 0.4677
#
# Epoch 04460: val_accuracy did not improve from 0.54839
# Epoch 4461/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2644 - accuracy: 0.4206 - val_loss: 2.1167 - val_accuracy: 0.3468
#
# Epoch 04461: val_accuracy did not improve from 0.54839
# Epoch 4462/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.6416 - accuracy: 0.4403 - val_loss: 1.3116 - val_accuracy: 0.3710
#
# Epoch 04462: val_accuracy did not improve from 0.54839
# Epoch 4463/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2421 - accuracy: 0.4480 - val_loss: 1.2787 - val_accuracy: 0.4516
#
# Epoch 04463: val_accuracy did not improve from 0.54839
# Epoch 4464/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2455 - accuracy: 0.4175 - val_loss: 1.7617 - val_accuracy: 0.3871
#
# Epoch 04464: val_accuracy did not improve from 0.54839
# Epoch 4465/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2148 - accuracy: 0.5113 - val_loss: 1.5071 - val_accuracy: 0.3387
#
# Epoch 04465: val_accuracy did not improve from 0.54839
# Epoch 4466/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 142.1370 - accuracy: 0.3578 - val_loss: 1.4721 - val_accuracy: 0.4032
#
# Epoch 04466: val_accuracy did not improve from 0.54839
# Epoch 4467/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.4505 - accuracy: 0.3897 - val_loss: 1.3144 - val_accuracy: 0.4355
#
# Epoch 04467: val_accuracy did not improve from 0.54839
# Epoch 4468/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1290 - accuracy: 0.5204 - val_loss: 1.1978 - val_accuracy: 0.4677
#
# Epoch 04468: val_accuracy did not improve from 0.54839
# Epoch 4469/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1585 - accuracy: 0.4837 - val_loss: 1.1530 - val_accuracy: 0.4839
#
# Epoch 04469: val_accuracy did not improve from 0.54839
# Epoch 4470/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0899 - accuracy: 0.5249 - val_loss: 1.2601 - val_accuracy: 0.4113
#
# Epoch 04470: val_accuracy did not improve from 0.54839
# Epoch 4471/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1556 - accuracy: 0.4233 - val_loss: 1.2623 - val_accuracy: 0.4435
#
# Epoch 04471: val_accuracy did not improve from 0.54839
# Epoch 4472/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1187 - accuracy: 0.4704 - val_loss: 1.1917 - val_accuracy: 0.4758
#
# Epoch 04472: val_accuracy did not improve from 0.54839
# Epoch 4473/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1011 - accuracy: 0.5247 - val_loss: 1.2599 - val_accuracy: 0.5081
#
# Epoch 04473: val_accuracy did not improve from 0.54839
# Epoch 4474/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2132 - accuracy: 0.4675 - val_loss: 1.2604 - val_accuracy: 0.4435
#
# Epoch 04474: val_accuracy did not improve from 0.54839
# Epoch 4475/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1388 - accuracy: 0.5254 - val_loss: 1.4506 - val_accuracy: 0.4113
#
# Epoch 04475: val_accuracy did not improve from 0.54839
# Epoch 4476/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2116 - accuracy: 0.4523 - val_loss: 1.1819 - val_accuracy: 0.4355
#
# Epoch 04476: val_accuracy did not improve from 0.54839
# Epoch 4477/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1655 - accuracy: 0.4843 - val_loss: 1.2871 - val_accuracy: 0.4032
#
# Epoch 04477: val_accuracy did not improve from 0.54839
# Epoch 4478/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.3335 - accuracy: 0.4396 - val_loss: 1.2503 - val_accuracy: 0.4274
#
# Epoch 04478: val_accuracy did not improve from 0.54839
# Epoch 4479/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2087 - accuracy: 0.5118 - val_loss: 1.2957 - val_accuracy: 0.4032
#
# Epoch 04479: val_accuracy did not improve from 0.54839
# Epoch 4480/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1606 - accuracy: 0.4757 - val_loss: 1.4418 - val_accuracy: 0.4194
#
# Epoch 04480: val_accuracy did not improve from 0.54839
# Epoch 4481/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2538 - accuracy: 0.4238 - val_loss: 1.3292 - val_accuracy: 0.3790
#
# Epoch 04481: val_accuracy did not improve from 0.54839
# Epoch 4482/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1669 - accuracy: 0.4966 - val_loss: 1.2728 - val_accuracy: 0.4516
#
# Epoch 04482: val_accuracy did not improve from 0.54839
# Epoch 4483/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1594 - accuracy: 0.5207 - val_loss: 1.2703 - val_accuracy: 0.4516
#
# Epoch 04483: val_accuracy did not improve from 0.54839
# Epoch 4484/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2558 - accuracy: 0.4582 - val_loss: 1.2869 - val_accuracy: 0.4113
#
# Epoch 04484: val_accuracy did not improve from 0.54839
# Epoch 4485/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1480 - accuracy: 0.5179 - val_loss: 1.3349 - val_accuracy: 0.4274
#
# Epoch 04485: val_accuracy did not improve from 0.54839
# Epoch 4486/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.5183 - accuracy: 0.4208 - val_loss: 1.2965 - val_accuracy: 0.4274
#
# Epoch 04486: val_accuracy did not improve from 0.54839
# Epoch 4487/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2847 - accuracy: 0.4610 - val_loss: 1.3958 - val_accuracy: 0.3790
#
# Epoch 04487: val_accuracy did not improve from 0.54839
# Epoch 4488/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1382 - accuracy: 0.4913 - val_loss: 1.2006 - val_accuracy: 0.4355
#
# Epoch 04488: val_accuracy did not improve from 0.54839
# Epoch 4489/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1834 - accuracy: 0.5035 - val_loss: 1.3688 - val_accuracy: 0.4355
#
# Epoch 04489: val_accuracy did not improve from 0.54839
# Epoch 4490/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1442 - accuracy: 0.4944 - val_loss: 1.1617 - val_accuracy: 0.4919
#
# Epoch 04490: val_accuracy did not improve from 0.54839
# Epoch 4491/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 22.6001 - accuracy: 0.4247 - val_loss: 39.0820 - val_accuracy: 0.2258
#
# Epoch 04491: val_accuracy did not improve from 0.54839
# Epoch 4492/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 25.0648 - accuracy: 0.2955 - val_loss: 1.3041 - val_accuracy: 0.4274
#
# Epoch 04492: val_accuracy did not improve from 0.54839
# Epoch 4493/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.2495 - accuracy: 0.4369 - val_loss: 1.2921 - val_accuracy: 0.4677
#
# Epoch 04493: val_accuracy did not improve from 0.54839
# Epoch 4494/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1545 - accuracy: 0.5049 - val_loss: 1.1494 - val_accuracy: 0.5484
#
# Epoch 04494: val_accuracy did not improve from 0.54839
# Epoch 4495/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.1450 - accuracy: 0.5063 - val_loss: 1.3463 - val_accuracy: 0.4113
#
# Epoch 04495: val_accuracy did not improve from 0.54839
# Epoch 4496/10000
# 372/372 [==============================] - 3s 7ms/step - loss: 1.0835 - accuracy: 0.4769 - val_loss: 1.3354 - val_accuracy: 0.4113
#
# Epoch 04496: val_accuracy did not improve from 0.54839
# Epoch 4497/10000
# 366/372 [============================>.] - ETA: 0s - loss: 1.1569 - accuracy: 0.5085

# %%
def load_model(struct, weight):
  json_file = open("/content/model/" + struct + ".json", "r")
  loaded_model_json = json_file.read()
  json_file.close()

  loaded_model = model_from_json(loaded_model_json)
  loaded_model.load_weights("/content/model/" + weight + ".hdf5")
  loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  return loaded_model

lastCheckpoint = sorted(Path("/content/model").iterdir(), key=os.path.getmtime)[-1].stem
print("Model is " + lastCheckpoint)

loaded_model = load_model("struct_model", lastCheckpoint)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-89-9678e4d755e4> in <module>()
#      10   return loaded_model
#      11
# ---> 12 lastCheckpoint = sorted(Path("/content/model").iterdir(), key=os.path.getmtime)[-1].stem
#      13 print("Model is " + lastCheckpoint)
#      14
#
# /usr/lib/python3.6/pathlib.py in iterdir(self)
#    1079         if self._closed:
#    1080             self._raise_closed()
# -> 1081         for name in self._accessor.listdir(self):
#    1082             if name in {'.', '..'}:
#    1083                 # Yielding a path object for these makes little sense
#
# /usr/lib/python3.6/pathlib.py in wrapped(pathobj, *args)
#     385         @functools.wraps(strfunc)
#     386         def wrapped(pathobj, *args):
# --> 387             return strfunc(str(pathobj), *args)
#     388         return staticmethod(wrapped)
#     389
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/model'

# %% [markdown]
# # Testing

# %%
train_loss, train_accuracy = loaded_model.evaluate(x_train, y_train)
val_loss, val_accuracy = loaded_model.evaluate(x_val, y_val)
test_loss, test_accuracy = loaded_model.evaluate(x_test, y_test)

print(
    ""
    "\n"
    "Train Loss: " + str(train_loss) + "\n"
    "Train Accuracy: " + str(train_accuracy * 100) + "%\n"
    "\n"
    "Validation Loss: " + str(val_loss) + "\n"
    "Validation Accuracy: " + str(val_accuracy * 100) + "%\n"
    "\n"
    "Test Loss: " + str(test_loss) + "\n"
    "Test Accuracy: " + str(test_accuracy * 100) + "%"
    "")
# Out:
# 7/7 [==============================] - 1s 27ms/step - loss: 289.8031 - accuracy: 0.6088
# 3/3 [==============================] - 0s 12ms/step - loss: 1940.7678 - accuracy: 0.5538
# 3/3 [==============================] - 0s 46ms/step - loss: 782.9440 - accuracy: 0.4203
#
# Train Loss: 403.8134765625
# Train Accuracy: 61.538463830947876%
#
# Validation Loss: 1940.767822265625
# Validation Accuracy: 55.384618043899536%
#
# Test Loss: 782.9440307617188
# Test Accuracy: 42.02898442745209%

# %%
loss, accuracy = loaded_model.evaluate_generator(generator=test_data)
print(
    ""
    "Prediction Loss: %2d\n"
    "Prediction Accuracy: %2d%%"
    ""
    % (loss, accuracy * 100))
# Out:
# Found 336 images belonging to 4 classes.
# Prediction Loss:  6
# Prediction Accuracy: 51%

# %% [markdown]
# # Analysis

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

y_decoded = []
for pred in y_test:
  decoded = np.where(pred == 1)[0][0]
  y_decoded.append(decoded)

print('Confusion Matrix')
print(target_names)
print(confusion_matrix(y_decoded, y_pred))
print(x_test.shape)

print('\n\nClassification Report')
print(classification_report(y_decoded, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# ['neu', 'ang', 'hap', 'sad']
# [[ 3  2  7  3]
#  [ 2  6  6  3]
#  [ 7  3  5  3]
#  [ 3  0  4 10]]
# (67, 128, 50)
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#          neu       0.20      0.20      0.20        15
#          ang       0.55      0.35      0.43        17
#          hap       0.23      0.28      0.25        18
#          sad       0.53      0.59      0.56        17
#
#     accuracy                           0.36        67
#    macro avg       0.37      0.35      0.36        67
# weighted avg       0.38      0.36      0.36        67

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_data.classes, y_pred))

print('\n\nClassification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
