# %% [markdown]
# # Prepare Data

# %%
import tensorflow as tf
import cv2

from numba import cuda 

from keras.models import Model, Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input, Softmax, Conv1D, MaxPooling1D
from keras.engine.saving import model_from_json
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils.vis_utils import plot_model
from keras_preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from skimage.restoration import denoise_wavelet

from pathlib import Path

from google.colab import files
from google.colab import drive

import os
import sys

import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

import librosa
import librosa.display

# %%
drive.mount('/content/gdrive', force_remount=True)
iemocap = "gdrive/My Drive/Public/IEMOCAP_full_release"

print("GPU Name: ", tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Mounted at /content/gdrive
# GPU Name:  /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# # Convert into CSV

# %%
sessions = ["Session1", "Session2", "Session3", "Session4", "Session5"]

def convertSession(session_name):
  session_file = iemocap + "/Duration/Processed/" + session_name + ".txt"
  tokenized_lines = []

  with open(session_file) as f:
    lines = f.readlines()
    tokenizedLines = [x.split() for x in lines]

  session_csv = iemocap + "/Duration/Processed/" + session_name + ".csv"
  with open(session_csv, "w") as csv:
    audio_name = ''

    for line in tokenizedLines:
      if line[0] == "Recording":
        audio_name = line[1]
      else:
        csv.write(audio_name + ";" + line[0] + ";" + line[1] + "\n")

def convertRawToCsv():
  for session in sessions:
    convertSession(session)

# convertRawToCsv()

# %% [markdown]
# # Convert into data frame

# %%
def getSessionData(session_name):
  df = pd.read_csv(iemocap + "/Duration/Processed/" + session_name + ".csv", delimiter=";", header=None)
  df.columns = ["Audio Name", "Part", "Duration"]
  print(session_name + " count: " + str(len(df.index)))

  return df

def getDataFrame():
  result = pd.DataFrame()

  for session in sessions:
    df = getSessionData(session)
    result = result.append(df, ignore_index=True)

  return result

result = getDataFrame()
result["Duration"] = result["Duration"].apply(np.floor).astype(int)
result
# Out:
# Session1 count: 1819
# Session2 count: 1811
# Session3 count: 2136
# Session4 count: 2103
# Session5 count: 2170
#               Audio Name  Part  Duration
# 0         Ses01F_impro01  F000         1
# 1         Ses01F_impro01  F001         1
# 2         Ses01F_impro01  F002         3
# 3         Ses01F_impro01  F003         1
# 4         Ses01F_impro01  F004         3
# ...                  ...   ...       ...
# 10034  Ses05M_script03_2  M041         8
# 10035  Ses05M_script03_2  M042         1
# 10036  Ses05M_script03_2  M043         2
# 10037  Ses05M_script03_2  M044         4
# 10038  Ses05M_script03_2  M045         6
#
# [10039 rows x 3 columns]

# %% [markdown]
# # Plot

# %%
plot = seaborn.countplot(x='Duration', data=result)
plot.figure.set_size_inches(13,13)

for p in plot.patches:
  height = p.get_height()
  plot.text(p.get_x() + p.get_width()/2., height + 10, '{:1.0f}'.format(height), ha="center")

# %%
print("Original data: " + str(result.count()))

count_data = result.value_counts(subset=['Duration'], sort=False).values
count_normalize = result.value_counts(subset=['Duration'], sort=False, normalize=True).values
duration = sorted(result.Duration.unique())

count_df = pd.DataFrame({"Duration": duration, "Count": count_data, "Percentage": count_normalize})
count_df.Percentage = (count_df.Percentage * 100).round(3)
# Out:
# Original data: Audio Name     10039
# Part           10039
# Duration       10039
# Evaluation1        0
# Evaluation2        0
# Evaluation3        0
# Evaluation4        0
# Evaluation5        0
# Evaluation6        0
# Emotion        10039
# dtype: int64
#     Duration  Count  Percentage
# 0          0     50       0.498
# 1          1   1650      16.436
# 2          2   2341      23.319
# 3          3   1717      17.103
# 4          4   1148      11.435
# 5          5    828       8.248
# 6          6    682       6.794
# 7          7    449       4.473
# 8          8    322       3.207
# 9          9    249       2.480
# 10        10    175       1.743
# 11        11    116       1.155
# 12        12    101       1.006
# 13        13     52       0.518
# 14        14     51       0.508
# 15        15     38       0.379
# 16        16     21       0.209
# 17        17     12       0.120
# 18        18     11       0.110
# 19        19      5       0.050
# 20        20      4       0.040
# 21        21      2       0.020
# 22        22      2       0.020
# 23        23      4       0.040
# 24        24      2       0.020
# 25        25      1       0.010
# 26        26      2       0.020
# 27        29      2       0.020
# 28        31      1       0.010
# 29        34      1       0.010

# %% [markdown]
# # Labeling

# %%
def resetEvaluation():
  result["Emotion"] = None

def goLabeling():
  for session in sessions:
    emotion_path = iemocap + "/" + session + "/dialog/EmoEvaluation/"

    recordings = [file.name for file in os.scandir(emotion_path) if ".txt" in file.name]
    recordings.sort()
    
    for recording in recordings:
      with open(emotion_path + recording) as f:
        lines = f.readlines()
        tokenizedLines = [x.split() for x in lines if "Ses0" in x]

        for part in tokenizedLines:
          line_name = part[3]
          line_label = part[4]
          line_queries = line_name.split("_")
          
          line_part = line_queries[-1]
          line_queries.remove(line_part)

          line_name = "_".join(line_queries)

          search_query_name = ""
          search_query_part = line_queries[-1]
          search_result = result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"]
          search_count = search_result.shape[0]
          
          if search_count == 0:
            print("ERROR: No audio part found: ")
          elif search_count > 1:
            print("ERROR: Multiple audio found: ")
          else:
            result.loc[(result["Audio Name"] == line_name) & (result["Part"] == line_part), "Emotion"] = line_label

def getClassificationReport():
  max_duration = 7

  categorical_data = result.loc[
    (result["Duration"] < max_duration + 1) &
    (
      (result["Emotion"] == 'neu') |
      (result["Emotion"] == 'ang') |
      (result["Emotion"] == 'hap') |
      (result["Emotion"] == 'sad') 
    )
  ]
  
  categorical_plot = seaborn.countplot(x="Emotion", hue="Duration", data=categorical_data)
  categorical_plot.figure.set_size_inches(13,13)

  for p in categorical_plot.patches:
    height = p.get_height()
    categorical_plot.text(p.get_x() + p.get_width()/2., height + 3, '{:1.0f}'.format(height), ha="center") 

  return categorical_data

resetEvaluation()
goLabeling()
categorical_data = getClassificationReport()

# %% [markdown]
# # Selection and Splitting

# %%
def checkAndCreateDirectory(filename):
  if not os.path.exists(os.path.dirname(filename)):
    try:
        os.makedirs(os.path.dirname(filename))
    except OSError as exc: # Guard against race condition
        print(exc.errno)
        if exc.errno != errno.EEXIST:
            raise

def getMfccValue(audio_path, row, dataset_type):
  audio_file, sample_rate = librosa.load(audio_path)
  audio_file = denoise_wavelet(audio_file, method='VisuShrink', rescale_sigma=True)

  S = librosa.feature.melspectrogram(y=audio_file, sr=48000)
  S[S < (np.average(S) / 1)] = 0.0

  librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

  filename = "image/" + dataset_type + "/" + row["Emotion"] + "/" + row["Audio Name"] + "_" + row["Part"] + '.png'
  checkAndCreateDirectory(filename)

  plt.gca().set_axis_off()
  plt.savefig(filename, dpi=100, bbox_inches='tight',pad_inches=0)
  # plt.show()
  plt.clf()
  plt.close('all')

  return S

def getEncodedLabel(label):
  label_hot = [0, 0, 0, 0]
  
  if    (label == "neu"): label_hot = [1, 0, 0, 0]
  elif  (label == "ang"): label_hot = [0, 1, 0, 0]
  elif  (label == "hap"): label_hot = [0, 0, 1, 0]
  elif  (label == "sad"): label_hot = [0, 0, 0, 1]

  np.where(np.array(label_hot) == 1)[0][0]
  return np.array(label_hot)

def getAudioPath(row):
  audio_prefix = row["Audio Name"][:5]
  audio_session = "Error"

  if    (audio_prefix == 'Ses01'): audio_session = "Session1"
  elif  (audio_prefix == 'Ses02'): audio_session = "Session2"
  elif  (audio_prefix == 'Ses03'): audio_session = "Session3"
  elif  (audio_prefix == 'Ses04'): audio_session = "Session4"
  elif  (audio_prefix == 'Ses05'): audio_session = "Session5"

  audio_path = iemocap + '/' + audio_session + '/sentences/wav/' + row["Audio Name"] + '/' + row["Audio Name"] + '_' + row["Part"] + '.wav'
  return audio_path

def getVectorAudio(base_duration, durationed_data, dataset_type):
  X = [] # Data
  Y = [] # Label

  durationed_length = len(durationed_data)

  # Iterate every data
  for index, row in durationed_data.iterrows():
    print("Saving " + str(durationed_length) + " " + str(index), end=" | ")

    if durationed_length % 30 == 0: print("\n")
    durationed_length -= 1

    # Get Label
    label = row["Emotion"]
    label_hot = getEncodedLabel(label)

    # Get Mfcc
    audio_path = getAudioPath(row)
    mfcc = getMfccValue(audio_path, row, dataset_type)
    mfcc_length = mfcc.shape[1]

    mfcc_slice = 50 * base_duration

    for mfcc_partial in range(int(mfcc_length/mfcc_slice)):
      start = mfcc_partial * mfcc_slice
      end = (mfcc_partial + 1) * mfcc_slice

      mfcc_partial_result = np.pad(mfcc, pad_width=((0,0), (0, (mfcc_slice - (mfcc_length % mfcc_slice)))), mode='constant')
      mfcc_partial_result = mfcc_partial_result[:,start:end]

      if (mfcc_partial_result.shape[1] != mfcc_slice) | (mfcc_partial_result.shape[0] != 128):
        print("ERROR Mfcc " + str(index) + str(row))
        print("ERROR Mfcc " + index + row)
        break
      
      X.append(mfcc_partial_result)
      Y.append(label_hot)

  return np.array(X), np.array(Y)

def testDuration():
  audio_file, sample_rate = librosa.load('/content/gdrive/My Drive/Public/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro04/Ses01F_impro04_M008.wav')
  duration = librosa.get_duration(y=audio_file, sr=sample_rate)
  print(duration)

  S = librosa.feature.mfcc(y=audio_file, sr=48000)
  print(S.shape)

def getEmotionSplitting(base_duration, max_duration):
  train_data    = pd.DataFrame()
  val_data      = pd.DataFrame()
  test_data     = pd.DataFrame()

  for iterate_index in range(base_duration, max_duration + 1):
    neutral_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'neu')
    ]

    angry_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'ang')
    ]

    sad_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'sad')
    ]

    happy_duration = result.loc[
      (result["Duration"] == iterate_index) &
      (result["Emotion"]  == 'hap')
    ]
    
    print("Duration " + str(iterate_index))
    print("Neutral " + str(neutral_duration.shape[0]))
    print("Angry " + str(angry_duration.shape[0]))
    print("Sad " + str(sad_duration.shape[0]))
    print("Happy " + str(happy_duration.shape[0]))
    print()

    sample_lowest = min(neutral_duration.shape[0], angry_duration.shape[0], sad_duration.shape[0], happy_duration.shape[0])

    neutral_duration  = neutral_duration.sample(sample_lowest)
    angry_duration    = angry_duration.sample(sample_lowest)
    sad_duration      = sad_duration.sample(sample_lowest)
    happy_duration    = happy_duration.sample(sample_lowest)

    # Splitting # 0,6 : 0,8 : 1,0 (60%, 20%, 20%)
    data_training_percent   = int(0.6 * sample_lowest)
    data_validation_percent = int(0.8 * sample_lowest)

    train_data = train_data.append(neutral_duration [:data_training_percent])
    train_data = train_data.append(angry_duration   [:data_training_percent])
    train_data = train_data.append(sad_duration     [:data_training_percent])
    train_data = train_data.append(happy_duration   [:data_training_percent])

    val_data = val_data.append(neutral_duration   [data_training_percent:data_validation_percent])
    val_data = val_data.append(angry_duration     [data_training_percent:data_validation_percent])
    val_data = val_data.append(sad_duration       [data_training_percent:data_validation_percent])
    val_data = val_data.append(happy_duration     [data_training_percent:data_validation_percent])

    test_data = test_data.append(neutral_duration     [data_validation_percent:sample_lowest])
    test_data = test_data.append(angry_duration       [data_validation_percent:sample_lowest])
    test_data = test_data.append(sad_duration         [data_validation_percent:sample_lowest])
    test_data = test_data.append(happy_duration       [data_validation_percent:sample_lowest])

  return train_data.sample(frac=1), val_data.sample(frac=1), test_data.sample(frac=1)

base_duration = 1
max_duration = 3

train_data, val_data, test_data = getEmotionSplitting(base_duration, max_duration)
# !rm -rf image

# In vector and save image
x_train, y_train  = getVectorAudio(base_duration, train_data, "train")
x_val, y_val      = getVectorAudio(base_duration, val_data, "val")
x_test, y_test    = getVectorAudio(base_duration, test_data, "test")
# Out:
# Duration 1
# Neutral 374
# Angry 153
# Sad 110
# Happy 86
#
# Duration 2
# Neutral 419
# Angry 266
# Sad 221
# Happy 156
#
# Duration 3
# Neutral 285
# Angry 204
# Sad 181
# Happy 110
#
# Saving 840 7083 |
#
# Saving 839 2989 | Saving 838 9555 | Saving 837 3697 | Saving 836 8188 | Saving 835 9167 | Saving 834 4176 | Saving 833 9454 | Saving 832 109 | Saving 831 5687 | Saving 830 5812 | Saving 829 4365 | Saving 828 2502 | Saving 827 7942 | Saving 826 3418 | Saving 825 300 | Saving 824 6704 | Saving 823 8349 | Saving 822 1200 | Saving 821 922 | Saving 820 6938 | Saving 819 8052 | Saving 818 8040 | Saving 817 4931 | Saving 816 4236 | Saving 815 1093 | Saving 814 3942 | Saving 813 7476 | Saving 812 5371 | Saving 811 1711 | Saving 810 5553 |
#
# Saving 809 5794 | Saving 808 526 | Saving 807 9198 | Saving 806 6638 | Saving 805 2913 | Saving 804 9515 | Saving 803 1221 | Saving 802 9133 | Saving 801 6322 | Saving 800 3581 | Saving 799 8369 | Saving 798 2910 | Saving 797 2570 | Saving 796 9434 | Saving 795 5703 | Saving 794 8480 | Saving 793 8045 | Saving 792 4618 | Saving 791 8145 | Saving 790 2506 | Saving 789 3274 | Saving 788 8151 | Saving 787 3423 | Saving 786 5147 | Saving 785 2501 | Saving 784 3215 | Saving 783 10025 | Saving 782 1665 | Saving 781 2599 | Saving 780 1199 |
#
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

# %%
def loadGenerator():
  train_image_generator = ImageDataGenerator()
  train_data = train_image_generator.flow_from_directory(
      directory="image/train/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )
    
  validation_image_generator = ImageDataGenerator()
  validation_data = validation_image_generator.flow_from_directory(
      directory="image/val/",
      class_mode="categorical",
      batch_size=1,
      shuffle=True,
      target_size=(256, 256)
  )

  test_image_generator = ImageDataGenerator()
  test_data = test_image_generator.flow_from_directory(
      directory="image/test/",
      batch_size=1,
      class_mode="categorical",
      shuffle=True,
      target_size=(256, 256)
  )

  return train_data, validation_data, test_data

# In generator
train_generator, validation_generator, test_generator = loadGenerator()

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# Found 840 images belonging to 4 classes.
# Found 280 images belonging to 4 classes.
# Found 288 images belonging to 4 classes.
# (1480, 128, 50)
# (498, 128, 50)
# (508, 128, 50)

# %%
def plot_result(model, history):
  # list all data in history
  print(history.history.keys())

  # summarize history for accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

def save_model(model, filename):
  checkAndCreateDirectory("/content/model/test.txt")
  model.summary()

  plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

  with open("/content/model/" + filename + ".json", "w") as json_file:
    model_json = model.to_json()
    json_file.write(model_json)

def buildModel():
  model_input = Input(shape=(256, 256, 3))
  model_input = Input(shape=(128, 50, 1))

  model = Conv1D(16, kernel_size=9, strides=1)(model_input)
  model = Conv1D(32, kernel_size=7, strides=1)(model)
  model = Conv1D(64, kernel_size=5, strides=1)(model)

  # model = Conv1D(1, kernel_size=17, strides=1)(model)
  # model = Conv1D(1, kernel_size=13, strides=1)(model)
  # model = Conv1D(3, kernel_size=9, strides=1)(model)

  model = Flatten()(model)

  model = Dense(512)(model)
  model = Dense(256)(model)
  model = Dense(128)(model)

  model = Dense(512)(model)
  model = Dense(256)(model)
  model = Dense(128)(model)

  model = Dense(4, activation='softmax')(model)
  
#   model = Sequential()
#   eff = tf.keras.applications.EfficientNetB3(
#     weights=None,
#     classes=4,
#     input_shape=(256,256,3)
#   )

#   model.add(eff)

  # Model compile
  model = Model(inputs=[model_input], outputs=[model])
  model.compile(optimizer="adam", loss=tf.keras.losses.CategoricalCrossentropy(), metrics=["accuracy"])
  
  # Visualize & Save Model
  save_model(model, "struct_model")

  # Checkpoint
  basepath = '/content/model/weight_model'
  best_checkpoint = ModelCheckpoint(basepath +'_{epoch:02d}_{loss:.2f}_{accuracy:.2f}_{val_loss:.2f}_{val_accuracy:.2f}.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
  callback_list = [best_checkpoint]

  history = model.fit(
    x_train, 
    y_train, 
    validation_data=(x_val, y_val),
    batch_size=8, 
    epochs=100,
    callbacks=callback_list
  )

  # history = model.fit_generator(
  #   generator=train_generator,
  #   validation_data=validation_generator,
  #   epochs=100,
  #   callbacks=callback_list
  # )

  return model, history

# !sudo chmod 777 /mnt
# !rm -rf model
# !rm -rf /mnt/model
# !rm -rf ../.local/share/Trash/files

# device = cuda.get_current_device()
# device.reset()

model, history = buildModel()
plot_result(model, history)
# Out:
# Model: "model_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_59 (InputLayer)        [(None, 128, 50, 1)]      0
# _________________________________________________________________
# conv1d_73 (Conv1D)           (None, 128, 42, 16)       160
# _________________________________________________________________
# conv1d_74 (Conv1D)           (None, 128, 36, 32)       3616
# _________________________________________________________________
# conv1d_75 (Conv1D)           (None, 128, 32, 64)       10304
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 262144)            0
# _________________________________________________________________
# dense_87 (Dense)             (None, 512)               134218240
# _________________________________________________________________
# dense_88 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_89 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_90 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dense_91 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_92 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_93 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 134,627,332
# Trainable params: 134,627,332
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 185/185 [==============================] - 7s 37ms/step - loss: 72.8140 - accuracy: 0.3136 - val_loss: 18.0387 - val_accuracy: 0.4337
#
# Epoch 00001: val_accuracy improved from -inf to 0.43373, saving model to /content/model/weight_model_01_89.88_0.31_18.04_0.43.hdf5
# Epoch 2/100
# 185/185 [==============================] - 7s 35ms/step - loss: 146.4008 - accuracy: 0.3195 - val_loss: 43.9032 - val_accuracy: 0.3253
#
# Epoch 00002: val_accuracy did not improve from 0.43373
# Epoch 3/100
# 185/185 [==============================] - 7s 35ms/step - loss: 80.9057 - accuracy: 0.3244 - val_loss: 14.7860 - val_accuracy: 0.4498
#
# Epoch 00003: val_accuracy improved from 0.43373 to 0.44980, saving model to /content/model/weight_model_03_52.09_0.35_14.79_0.45.hdf5
# Epoch 4/100
# 185/185 [==============================] - 7s 35ms/step - loss: 52.5319 - accuracy: 0.3425 - val_loss: 17.0774 - val_accuracy: 0.3735
#
# Epoch 00004: val_accuracy did not improve from 0.44980
# Epoch 5/100
# 185/185 [==============================] - 7s 35ms/step - loss: 15.4864 - accuracy: 0.3965 - val_loss: 5.9618 - val_accuracy: 0.3855
#
# Epoch 00005: val_accuracy did not improve from 0.44980
# Epoch 6/100
# 185/185 [==============================] - 7s 35ms/step - loss: 4.0846 - accuracy: 0.4258 - val_loss: 3.5264 - val_accuracy: 0.3313
#
# Epoch 00006: val_accuracy did not improve from 0.44980
# Epoch 7/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.4985 - accuracy: 0.4473 - val_loss: 3.1242 - val_accuracy: 0.3193
#
# Epoch 00007: val_accuracy did not improve from 0.44980
# Epoch 8/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.7478 - accuracy: 0.4529 - val_loss: 3.4504 - val_accuracy: 0.2851
#
# Epoch 00008: val_accuracy did not improve from 0.44980
# Epoch 9/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2.7774 - accuracy: 0.3855 - val_loss: 6.7440 - val_accuracy: 0.3133
#
# Epoch 00009: val_accuracy did not improve from 0.44980
# Epoch 10/100
# 185/185 [==============================] - 7s 35ms/step - loss: 3.6621 - accuracy: 0.4161 - val_loss: 12.5915 - val_accuracy: 0.2751
#
# Epoch 00010: val_accuracy did not improve from 0.44980
# Epoch 11/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2.0417 - accuracy: 0.4524 - val_loss: 4.2320 - val_accuracy: 0.3956
#
# Epoch 00011: val_accuracy did not improve from 0.44980
# Epoch 12/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.1034 - accuracy: 0.5595 - val_loss: 3.3560 - val_accuracy: 0.4217
#
# Epoch 00012: val_accuracy did not improve from 0.44980
# Epoch 13/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.9528 - accuracy: 0.5667 - val_loss: 71.8647 - val_accuracy: 0.2811
#
# Epoch 00013: val_accuracy did not improve from 0.44980
# Epoch 14/100
# 185/185 [==============================] - 7s 35ms/step - loss: 604.0107 - accuracy: 0.3063 - val_loss: 53.4200 - val_accuracy: 0.2751
#
# Epoch 00014: val_accuracy did not improve from 0.44980
# Epoch 15/100
# 185/185 [==============================] - 7s 35ms/step - loss: 83.3988 - accuracy: 0.2857 - val_loss: 136.0920 - val_accuracy: 0.3594
#
# Epoch 00015: val_accuracy did not improve from 0.44980
# Epoch 16/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1946.1045 - accuracy: 0.2617 - val_loss: 117.6335 - val_accuracy: 0.3695
#
# Epoch 00016: val_accuracy did not improve from 0.44980
# Epoch 17/100
# 185/185 [==============================] - 7s 35ms/step - loss: 887.9124 - accuracy: 0.2813 - val_loss: 21.3147 - val_accuracy: 0.2369
#
# Epoch 00017: val_accuracy did not improve from 0.44980
# Epoch 18/100
# 185/185 [==============================] - 7s 35ms/step - loss: 178.6136 - accuracy: 0.2871 - val_loss: 78.4018 - val_accuracy: 0.3635
#
# Epoch 00018: val_accuracy did not improve from 0.44980
# Epoch 19/100
# 185/185 [==============================] - 7s 36ms/step - loss: 52.5361 - accuracy: 0.3391 - val_loss: 88.8287 - val_accuracy: 0.4076
#
# Epoch 00019: val_accuracy did not improve from 0.44980
# Epoch 20/100
# 185/185 [==============================] - 7s 36ms/step - loss: 29.9668 - accuracy: 0.3627 - val_loss: 30.7819 - val_accuracy: 0.3614
#
# Epoch 00020: val_accuracy did not improve from 0.44980
# Epoch 21/100
# 185/185 [==============================] - 7s 35ms/step - loss: 19.7948 - accuracy: 0.3692 - val_loss: 9.8110 - val_accuracy: 0.3494
#
# Epoch 00021: val_accuracy did not improve from 0.44980
# Epoch 22/100
# 185/185 [==============================] - 7s 36ms/step - loss: 4.6738 - accuracy: 0.3758 - val_loss: 4.3446 - val_accuracy: 0.4317
#
# Epoch 00022: val_accuracy did not improve from 0.44980
# Epoch 23/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.9066 - accuracy: 0.3883 - val_loss: 3.1799 - val_accuracy: 0.3293
#
# Epoch 00023: val_accuracy did not improve from 0.44980
# Epoch 24/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.4891 - accuracy: 0.4162 - val_loss: 2.4955 - val_accuracy: 0.4177
#
# Epoch 00024: val_accuracy did not improve from 0.44980
# Epoch 25/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2.0680 - accuracy: 0.4609 - val_loss: 3.4324 - val_accuracy: 0.4317
#
# Epoch 00025: val_accuracy did not improve from 0.44980
# Epoch 26/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.6227 - accuracy: 0.4551 - val_loss: 2.8211 - val_accuracy: 0.4418
#
# Epoch 00026: val_accuracy did not improve from 0.44980
# Epoch 27/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.2478 - accuracy: 0.4746 - val_loss: 2.3787 - val_accuracy: 0.4418
#
# Epoch 00027: val_accuracy did not improve from 0.44980
# Epoch 28/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.2623 - accuracy: 0.4967 - val_loss: 2.2623 - val_accuracy: 0.4538
#
# Epoch 00028: val_accuracy improved from 0.44980 to 0.45382, saving model to /content/model/weight_model_28_1.20_0.49_2.26_0.45.hdf5
# Epoch 29/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.1465 - accuracy: 0.4901 - val_loss: 2.2228 - val_accuracy: 0.4197
#
# Epoch 00029: val_accuracy did not improve from 0.45382
# Epoch 30/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.2156 - accuracy: 0.4688 - val_loss: 2.0346 - val_accuracy: 0.4217
#
# Epoch 00030: val_accuracy did not improve from 0.45382
# Epoch 31/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0690 - accuracy: 0.5275 - val_loss: 1.8850 - val_accuracy: 0.4177
#
# Epoch 00031: val_accuracy did not improve from 0.45382
# Epoch 32/100
# 185/185 [==============================] - 7s 37ms/step - loss: 1.0684 - accuracy: 0.5121 - val_loss: 1.7662 - val_accuracy: 0.4016
#
# Epoch 00032: val_accuracy did not improve from 0.45382
# Epoch 33/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0587 - accuracy: 0.5200 - val_loss: 1.8119 - val_accuracy: 0.4116
#
# Epoch 00033: val_accuracy did not improve from 0.45382
# Epoch 34/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0575 - accuracy: 0.5315 - val_loss: 1.9193 - val_accuracy: 0.4398
#
# Epoch 00034: val_accuracy did not improve from 0.45382
# Epoch 35/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0802 - accuracy: 0.5212 - val_loss: 2.0040 - val_accuracy: 0.4257
#
# Epoch 00035: val_accuracy did not improve from 0.45382
# Epoch 36/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0212 - accuracy: 0.5471 - val_loss: 1.8047 - val_accuracy: 0.4137
#
# Epoch 00036: val_accuracy did not improve from 0.45382
# Epoch 37/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0030 - accuracy: 0.5431 - val_loss: 1.6623 - val_accuracy: 0.4116
#
# Epoch 00037: val_accuracy did not improve from 0.45382
# Epoch 38/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.9997 - accuracy: 0.5435 - val_loss: 1.7679 - val_accuracy: 0.4137
#
# Epoch 00038: val_accuracy did not improve from 0.45382
# Epoch 39/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.6026 - accuracy: 0.5154 - val_loss: 3.6790 - val_accuracy: 0.4297
#
# Epoch 00039: val_accuracy did not improve from 0.45382
# Epoch 40/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.5071 - accuracy: 0.4952 - val_loss: 2.7315 - val_accuracy: 0.4237
#
# Epoch 00040: val_accuracy did not improve from 0.45382
# Epoch 41/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0356 - accuracy: 0.5474 - val_loss: 2.3679 - val_accuracy: 0.4297
#
# Epoch 00041: val_accuracy did not improve from 0.45382
# Epoch 42/100
# 185/185 [==============================] - 7s 35ms/step - loss: 116.3902 - accuracy: 0.4135 - val_loss: 968.5497 - val_accuracy: 0.3213
#
# Epoch 00042: val_accuracy did not improve from 0.45382
# Epoch 43/100
# 185/185 [==============================] - 7s 36ms/step - loss: 44599.0920 - accuracy: 0.2760 - val_loss: 789.8891 - val_accuracy: 0.3273
#
# Epoch 00043: val_accuracy did not improve from 0.45382
# Epoch 44/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2022.2711 - accuracy: 0.3007 - val_loss: 190.5293 - val_accuracy: 0.4357
#
# Epoch 00044: val_accuracy did not improve from 0.45382
# Epoch 45/100
# 185/185 [==============================] - 7s 36ms/step - loss: 178.1346 - accuracy: 0.3855 - val_loss: 143.7573 - val_accuracy: 0.3695
#
# Epoch 00045: val_accuracy did not improve from 0.45382
# Epoch 46/100
# 185/185 [==============================] - 7s 36ms/step - loss: 191.7295 - accuracy: 0.4029 - val_loss: 344.2122 - val_accuracy: 0.3313
#
# Epoch 00046: val_accuracy did not improve from 0.45382
# Epoch 47/100
# 185/185 [==============================] - 7s 36ms/step - loss: 139.0170 - accuracy: 0.3946 - val_loss: 105.5093 - val_accuracy: 0.3173
#
# Epoch 00047: val_accuracy did not improve from 0.45382
# Epoch 48/100
# 185/185 [==============================] - 7s 36ms/step - loss: 154.9104 - accuracy: 0.3673 - val_loss: 79.6058 - val_accuracy: 0.3936
#
# Epoch 00048: val_accuracy did not improve from 0.45382
# Epoch 49/100
# 185/185 [==============================] - 7s 36ms/step - loss: 56.5680 - accuracy: 0.4010 - val_loss: 39.0640 - val_accuracy: 0.4056
#
# Epoch 00049: val_accuracy did not improve from 0.45382
# Epoch 50/100
# 185/185 [==============================] - 7s 36ms/step - loss: 57.4496 - accuracy: 0.4331 - val_loss: 234.4947 - val_accuracy: 0.2851
#
# Epoch 00050: val_accuracy did not improve from 0.45382
# Epoch 51/100
# 185/185 [==============================] - 7s 36ms/step - loss: 122.3948 - accuracy: 0.3957 - val_loss: 77.1831 - val_accuracy: 0.3253
#
# Epoch 00051: val_accuracy did not improve from 0.45382
# Epoch 52/100
# 185/185 [==============================] - 7s 36ms/step - loss: 22.3162 - accuracy: 0.4137 - val_loss: 55.6373 - val_accuracy: 0.3494
#
# Epoch 00052: val_accuracy did not improve from 0.45382
# Epoch 53/100
# 185/185 [==============================] - 7s 36ms/step - loss: 11.9565 - accuracy: 0.4436 - val_loss: 135.8990 - val_accuracy: 0.2751
#
# Epoch 00053: val_accuracy did not improve from 0.45382
# Epoch 54/100
# 185/185 [==============================] - 7s 35ms/step - loss: 42.5973 - accuracy: 0.4481 - val_loss: 62.6914 - val_accuracy: 0.2912
#
# Epoch 00054: val_accuracy did not improve from 0.45382
# Epoch 55/100
# 185/185 [==============================] - 7s 36ms/step - loss: 9.3365 - accuracy: 0.4566 - val_loss: 48.4071 - val_accuracy: 0.3434
#
# Epoch 00055: val_accuracy did not improve from 0.45382
# Epoch 56/100
# 185/185 [==============================] - 7s 35ms/step - loss: 6.6476 - accuracy: 0.4500 - val_loss: 39.2184 - val_accuracy: 0.3775
#
# Epoch 00056: val_accuracy did not improve from 0.45382
# Epoch 57/100
# 185/185 [==============================] - 7s 36ms/step - loss: 4.9773 - accuracy: 0.4811 - val_loss: 32.7980 - val_accuracy: 0.3876
#
# Epoch 00057: val_accuracy did not improve from 0.45382
# Epoch 58/100
# 185/185 [==============================] - 7s 36ms/step - loss: 3.7796 - accuracy: 0.4787 - val_loss: 28.3249 - val_accuracy: 0.3956
#
# Epoch 00058: val_accuracy did not improve from 0.45382
# Epoch 59/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2.9645 - accuracy: 0.4817 - val_loss: 24.5687 - val_accuracy: 0.3815
#
# Epoch 00059: val_accuracy did not improve from 0.45382
# Epoch 60/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2.6043 - accuracy: 0.4829 - val_loss: 21.8163 - val_accuracy: 0.3815
#
# Epoch 00060: val_accuracy did not improve from 0.45382
# Epoch 61/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2.4689 - accuracy: 0.4963 - val_loss: 18.3148 - val_accuracy: 0.3896
#
# Epoch 00061: val_accuracy did not improve from 0.45382
# Epoch 62/100
# 185/185 [==============================] - 7s 35ms/step - loss: 2.0741 - accuracy: 0.4951 - val_loss: 16.4598 - val_accuracy: 0.3815
#
# Epoch 00062: val_accuracy did not improve from 0.45382
# Epoch 63/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.6511 - accuracy: 0.5443 - val_loss: 14.6233 - val_accuracy: 0.3916
#
# Epoch 00063: val_accuracy did not improve from 0.45382
# Epoch 64/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.6737 - accuracy: 0.4990 - val_loss: 13.0363 - val_accuracy: 0.3876
#
# Epoch 00064: val_accuracy did not improve from 0.45382
# Epoch 65/100
# 185/185 [==============================] - 7s 36ms/step - loss: 47.6697 - accuracy: 0.5143 - val_loss: 2007.0608 - val_accuracy: 0.2510
#
# Epoch 00065: val_accuracy did not improve from 0.45382
# Epoch 66/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1211.3530 - accuracy: 0.3171 - val_loss: 127.9751 - val_accuracy: 0.2189
#
# Epoch 00066: val_accuracy did not improve from 0.45382
# Epoch 67/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1107.1213 - accuracy: 0.2847 - val_loss: 654.9009 - val_accuracy: 0.2349
#
# Epoch 00067: val_accuracy did not improve from 0.45382
# Epoch 68/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1297.4012 - accuracy: 0.3147 - val_loss: 427.0001 - val_accuracy: 0.4217
#
# Epoch 00068: val_accuracy did not improve from 0.45382
# Epoch 69/100
# 185/185 [==============================] - 7s 36ms/step - loss: 250.3150 - accuracy: 0.3610 - val_loss: 587.8433 - val_accuracy: 0.3052
#
# Epoch 00069: val_accuracy did not improve from 0.45382
# Epoch 70/100
# 185/185 [==============================] - 7s 35ms/step - loss: 271.2052 - accuracy: 0.3751 - val_loss: 24.6338 - val_accuracy: 0.4378
#
# Epoch 00070: val_accuracy did not improve from 0.45382
# Epoch 71/100
# 185/185 [==============================] - 7s 36ms/step - loss: 23.0415 - accuracy: 0.4020 - val_loss: 13.7919 - val_accuracy: 0.3534
#
# Epoch 00071: val_accuracy did not improve from 0.45382
# Epoch 72/100
# 185/185 [==============================] - 7s 35ms/step - loss: 6.5958 - accuracy: 0.4082 - val_loss: 7.0647 - val_accuracy: 0.4357
#
# Epoch 00072: val_accuracy did not improve from 0.45382
# Epoch 73/100
# 185/185 [==============================] - 7s 36ms/step - loss: 4.0735 - accuracy: 0.3913 - val_loss: 13.2006 - val_accuracy: 0.4317
#
# Epoch 00073: val_accuracy did not improve from 0.45382
# Epoch 74/100
# 185/185 [==============================] - 7s 36ms/step - loss: 8.8512 - accuracy: 0.4144 - val_loss: 6.3153 - val_accuracy: 0.4237
#
# Epoch 00074: val_accuracy did not improve from 0.45382
# Epoch 75/100
# 185/185 [==============================] - 7s 36ms/step - loss: 2.9234 - accuracy: 0.4744 - val_loss: 4.3552 - val_accuracy: 0.4116
#
# Epoch 00075: val_accuracy did not improve from 0.45382
# Epoch 76/100
# 185/185 [==============================] - 7s 36ms/step - loss: 2.0969 - accuracy: 0.5019 - val_loss: 23.1053 - val_accuracy: 0.4277
#
# Epoch 00076: val_accuracy did not improve from 0.45382
# Epoch 77/100
# 185/185 [==============================] - 7s 35ms/step - loss: 12.5016 - accuracy: 0.4129 - val_loss: 8.2327 - val_accuracy: 0.4036
#
# Epoch 00077: val_accuracy did not improve from 0.45382
# Epoch 78/100
# 185/185 [==============================] - 7s 36ms/step - loss: 2.6953 - accuracy: 0.4600 - val_loss: 5.8955 - val_accuracy: 0.3052
#
# Epoch 00078: val_accuracy did not improve from 0.45382
# Epoch 79/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.7644 - accuracy: 0.4609 - val_loss: 4.4994 - val_accuracy: 0.3394
#
# Epoch 00079: val_accuracy did not improve from 0.45382
# Epoch 80/100
# 185/185 [==============================] - 7s 35ms/step - loss: 1.5860 - accuracy: 0.5045 - val_loss: 4.1272 - val_accuracy: 0.4096
#
# Epoch 00080: val_accuracy did not improve from 0.45382
# Epoch 81/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.2988 - accuracy: 0.4937 - val_loss: 3.4496 - val_accuracy: 0.4257
#
# Epoch 00081: val_accuracy did not improve from 0.45382
# Epoch 82/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.1137 - accuracy: 0.5454 - val_loss: 3.2139 - val_accuracy: 0.4116
#
# Epoch 00082: val_accuracy did not improve from 0.45382
# Epoch 83/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.1240 - accuracy: 0.5094 - val_loss: 2.7924 - val_accuracy: 0.4257
#
# Epoch 00083: val_accuracy did not improve from 0.45382
# Epoch 84/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0515 - accuracy: 0.5166 - val_loss: 2.6961 - val_accuracy: 0.4137
#
# Epoch 00084: val_accuracy did not improve from 0.45382
# Epoch 85/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0187 - accuracy: 0.5441 - val_loss: 2.9363 - val_accuracy: 0.4016
#
# Epoch 00085: val_accuracy did not improve from 0.45382
# Epoch 86/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.2938 - accuracy: 0.5451 - val_loss: 13.4538 - val_accuracy: 0.4157
#
# Epoch 00086: val_accuracy did not improve from 0.45382
# Epoch 87/100
# 185/185 [==============================] - 7s 36ms/step - loss: 5.9507 - accuracy: 0.4555 - val_loss: 5.7635 - val_accuracy: 0.4116
#
# Epoch 00087: val_accuracy did not improve from 0.45382
# Epoch 88/100
# 185/185 [==============================] - 7s 37ms/step - loss: 3.1114 - accuracy: 0.4843 - val_loss: 5.0103 - val_accuracy: 0.4096
#
# Epoch 00088: val_accuracy did not improve from 0.45382
# Epoch 89/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.1953 - accuracy: 0.5322 - val_loss: 3.3281 - val_accuracy: 0.4116
#
# Epoch 00089: val_accuracy did not improve from 0.45382
# Epoch 90/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.0504 - accuracy: 0.5653 - val_loss: 2.7474 - val_accuracy: 0.4016
#
# Epoch 00090: val_accuracy did not improve from 0.45382
# Epoch 91/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.9841 - accuracy: 0.5801 - val_loss: 2.8590 - val_accuracy: 0.4116
#
# Epoch 00091: val_accuracy did not improve from 0.45382
# Epoch 92/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.9119 - accuracy: 0.6026 - val_loss: 2.5711 - val_accuracy: 0.3896
#
# Epoch 00092: val_accuracy did not improve from 0.45382
# Epoch 93/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.9214 - accuracy: 0.5878 - val_loss: 2.8569 - val_accuracy: 0.4096
#
# Epoch 00093: val_accuracy did not improve from 0.45382
# Epoch 94/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.8806 - accuracy: 0.6257 - val_loss: 2.8060 - val_accuracy: 0.4076
#
# Epoch 00094: val_accuracy did not improve from 0.45382
# Epoch 95/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.8469 - accuracy: 0.6304 - val_loss: 2.7858 - val_accuracy: 0.3976
#
# Epoch 00095: val_accuracy did not improve from 0.45382
# Epoch 96/100
# 185/185 [==============================] - 7s 36ms/step - loss: 1.8043 - accuracy: 0.5464 - val_loss: 4.2544 - val_accuracy: 0.3976
#
# Epoch 00096: val_accuracy did not improve from 0.45382
# Epoch 97/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.9593 - accuracy: 0.6032 - val_loss: 3.2221 - val_accuracy: 0.4076
#
# Epoch 00097: val_accuracy did not improve from 0.45382
# Epoch 98/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.8483 - accuracy: 0.6394 - val_loss: 2.9919 - val_accuracy: 0.3996
#
# Epoch 00098: val_accuracy did not improve from 0.45382
# Epoch 99/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.8050 - accuracy: 0.6717 - val_loss: 2.9633 - val_accuracy: 0.4157
#
# Epoch 00099: val_accuracy did not improve from 0.45382
# Epoch 100/100
# 185/185 [==============================] - 7s 36ms/step - loss: 0.7800 - accuracy: 0.6925 - val_loss: 3.1170 - val_accuracy: 0.4237
#
# Epoch 00100: val_accuracy did not improve from 0.45382
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
def load_model(struct, weight):
  json_file = open("/mnt/model/" + struct + ".json", "r")
  loaded_model_json = json_file.read()
  json_file.close()

  loaded_model = model_from_json(loaded_model_json)
  loaded_model.load_weights("/mnt/model/" + weight + ".hdf5")
  loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  return loaded_model

lastCheckpoint = sorted(Path("/mnt/model").iterdir(), key=os.path.getmtime)[-1].stem
print("Model is " + lastCheckpoint)

loaded_model = load_model("struct_model", lastCheckpoint)
# Out:
# Model is weight_model_04_10.35_0.44_5.80_0.54

# %% [markdown]
# # Testing

# %%
# train_loss, train_accuracy = loaded_model.evaluate(x_train, y_train)
# val_loss, val_accuracy = loaded_model.evaluate(x_val, y_val)
# test_loss, test_accuracy = loaded_model.evaluate(x_test, y_test)

# print(
#     ""
#     "\n"
#     "Train Loss: " + str(train_loss) + "\n"
#     "Train Accuracy: " + str(train_accuracy * 100) + "%\n"
#     "\n"
#     "Validation Loss: " + str(val_loss) + "\n"
#     "Validation Accuracy: " + str(val_accuracy * 100) + "%\n"
#     "\n"
#     "Test Loss: " + str(test_loss) + "\n"
#     "Test Accuracy: " + str(test_accuracy * 100) + "%"
#     "")

# %%
loss, accuracy = loaded_model.evaluate_generator(generator=test_data)
print(
    ""
    "Prediction Loss: %2d\n"
    "Prediction Accuracy: %2d%%"
    ""
    % (loss, accuracy * 100))
# Out:
# Found 336 images belonging to 4 classes.
# Prediction Loss:  6
# Prediction Accuracy: 51%

# %% [markdown]
# # Analysis

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)

y_decoded = []
for pred in y_test:
  decoded = np.where(pred == 1)[0][0]
  y_decoded.append(decoded)

print('Confusion Matrix')
print(target_names)
print(confusion_matrix(y_decoded, y_pred))
print(x_test.shape)

print('\n\nClassification Report')
print(classification_report(y_decoded, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# ['neu', 'ang', 'hap', 'sad']
# [[ 3  2  7  3]
#  [ 2  6  6  3]
#  [ 7  3  5  3]
#  [ 3  0  4 10]]
# (67, 128, 50)
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#          neu       0.20      0.20      0.20        15
#          ang       0.55      0.35      0.43        17
#          hap       0.23      0.28      0.25        18
#          sad       0.53      0.59      0.56        17
#
#     accuracy                           0.36        67
#    macro avg       0.37      0.35      0.36        67
# weighted avg       0.38      0.36      0.36        67

# %%
target_names = ['neu', 'ang', 'hap', "sad"]

Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_data.classes, y_pred))

print('\n\nClassification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
